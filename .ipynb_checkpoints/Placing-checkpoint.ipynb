# %% [markdown]
# # 1. Package import

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import textwrap
import itertools
import pandas.plotting._converter as pandacnv
pandacnv.register()

# %matplotlib inline

# %% [markdown]
# # 2. Data acquisition

# %%
def data_acquisition(region,use_cache):
    
    ''' 
    Create a fundamental dictionary with all the data available
    '''

    if use_cache is True:

        data_dict={}

        adj_ABO_df=pd.read_csv(r'C:\Users\Eric.Li\Documents\Post result code\{0}_ABO.csv'.format(region))   
        price_df=pd.read_csv(r'C:\Users\Eric.Li\Documents\Post result code\{0}_price.csv'.format(region))
        abs_return_df=pd.read_csv(r'C:\Users\Eric.Li\Documents\Post result code\{0}_abs_return.csv'.format(region))
        price_orig_df=pd.read_csv(r'C:\Users\Eric.Li\Documents\Post result code\{0}_price_orig.csv'.format(region))
        volume_df=pd.read_csv(r'C:\Users\Eric.Li\Documents\Post result code\{0}_volume.csv'.format(region))
        VWAP_df=pd.read_csv(r'C:\Users\Eric.Li\Documents\Post result code\{0}_VWAP.csv'.format(region))
        VWAP_orig_df=pd.read_csv(r'C:\Users\Eric.Li\Documents\Post result code\{0}_VWAP_orig.csv'.format(region))

        adj_ABO_df.index=pd.MultiIndex.from_tuples(list(zip(adj_ABO_df['Unnamed: 0'],\
                                                            adj_ABO_df.apply(lambda x:pd.\
                                                                             Timestamp(x[adj_ABO_df.iloc[:,1].name]),axis=1),\
                                                            adj_ABO_df.apply(lambda x:pd.\
                                                                             Timestamp(x[adj_ABO_df.iloc[:,2].name]),axis=1))))
        data_dict['ABO_df']=adj_ABO_df.iloc[:,3:]

        price_df.index=price_df.apply(lambda x:pd.Timestamp(x[price_df.iloc[:,0].name]),axis=1)
        data_dict['price_df']=price_df.iloc[:,1:]

        abs_return_df.index=abs_return_df.apply(lambda x:pd.Timestamp(x[abs_return_df.iloc[:,0].name]),axis=1)
        data_dict['abs_return_df']=abs_return_df.iloc[:,1:]

        price_orig_df.index=price_orig_df.apply(lambda x:pd.Timestamp(x[price_orig_df.iloc[:,0].name]),axis=1)
        data_dict['price_orig_df']=price_orig_df.iloc[:,1:]

        volume_df.index=volume_df.apply(lambda x:pd.Timestamp(x[volume_df.iloc[:,0].name]),axis=1)
        data_dict['volume_df']=volume_df.iloc[:,1:]

        VWAP_df.index=VWAP_df.apply(lambda x:pd.Timestamp(x[VWAP_df.iloc[:,0].name]),axis=1)
        data_dict['VWAP_df']=VWAP_df.iloc[:,1:]

        VWAP_orig_df.index=VWAP_orig_df.apply(lambda x:pd.Timestamp(x[VWAP_orig_df.iloc[:,0].name]),axis=1)
        data_dict['VWAP_orig_df']=VWAP_orig_df.iloc[:,1:]

        try:
            adj_IPO_df=pd.read_csv(r'C:\Users\Eric.Li\Documents\Post result code\{0}_IPO.csv'.format(region))
            
            adj_IPO_df.index=pd.MultiIndex.from_tuples(list(zip(adj_IPO_df['Unnamed: 0'],\
                                                                adj_IPO_df.apply(lambda x:pd.Timestamp(x[adj_IPO_df.iloc[:,1].\
                                                                                                         name]),axis=1),\
                                                                adj_IPO_df.apply(lambda x:pd.\
                                                                                 Timestamp(x[adj_IPO_df.iloc[:,2].name]),\
                                                                                 axis=1))))
            data_dict['IPO_df']=adj_IPO_df.iloc[:,3:] 
            
        except:
            pass
            

    
    else:
        data_dict={}
        ABO_df=pd.read_excel(r'C:\Users\Eric.Li\Documents\Post result data\ABO {0}.xlsx'.format(region),\
                                           sheet_name='ABO',header=1).dropna(how='all',axis=1)



        adj_ABO_df=ABO_df.set_index(pd.MultiIndex.from_tuples(list(zip(ABO_df["Ticker"],\
                                                                                   ABO_df["Announced Date"],\
                                                                                   ABO_df["Listing date"])))).\
        dropna(how='all',axis=1)



        price_df=pd.read_excel(r'C:\Users\Eric.Li\Documents\Post result data\ABO {0}.xlsx'.format(region),\
                                           sheet_name='Price',header=1).set_index('Ticker').drop_duplicates().\
        T.dropna(how='all',axis=1)

        abs_return_df=price_df/price_df.shift(1)-1

        price_orig_df=pd.read_excel(r'C:\Users\Eric.Li\Documents\Post result data\ABO {0}.xlsx'.format(region),\
                                           sheet_name='Price_orig',header=1).set_index('Ticker').drop_duplicates()\
        .T.dropna(how='all',axis=1)  

        volume_df=pd.read_excel(r'C:\Users\Eric.Li\Documents\Post result data\ABO {0}.xlsx'.format(region),\
                                           sheet_name='Volume',header=1).set_index('Ticker').drop_duplicates().T\
        .dropna(how='all',axis=1)

        VWAP_df=pd.read_excel(r'C:\Users\Eric.Li\Documents\Post result data\ABO {0}.xlsx'.format(region),\
                                           sheet_name='VWAP',header=1).set_index('Ticker').drop_duplicates().T\
        .dropna(how='all',axis=1)
        
        VWAP_orig_df=pd.read_excel(r'C:\Users\Eric.Li\Documents\Post result data\ABO {0}.xlsx'.format(region),\
                                           sheet_name='VWAP_orig',header=1).set_index('Ticker').drop_duplicates().\
        T.dropna(how='all',axis=1)
        
        adj_ABO_df.to_csv(r'C:\Users\Eric.Li\Documents\Post result code\{0}_ABO.csv'.format(region))   
        price_df.to_csv(r'C:\Users\Eric.Li\Documents\Post result code\{0}_price.csv'.format(region))
        abs_return_df.to_csv(r'C:\Users\Eric.Li\Documents\Post result code\{0}_abs_return.csv'.format(region))
        price_orig_df.to_csv(r'C:\Users\Eric.Li\Documents\Post result code\{0}_price_orig.csv'.format(region))
        volume_df.to_csv(r'C:\Users\Eric.Li\Documents\Post result code\{0}_volume.csv'.format(region))
        VWAP_df.to_csv(r'C:\Users\Eric.Li\Documents\Post result code\{0}_VWAP.csv'.format(region))
        VWAP_orig_df.to_csv(r'C:\Users\Eric.Li\Documents\Post result code\{0}_VWAP_orig.csv'.format(region))
        
        data_dict['ABO_df']=adj_ABO_df
        data_dict['price_df']=price_df
        data_dict['abs_return_df']=abs_return_df
        data_dict['price_orig_df']=price_orig_df
        data_dict['volume_df']=volume_df
        data_dict['VWAP_df']=VWAP_df
        data_dict['VWAP_orig_df']=VWAP_orig_df
        
        try:
            IPO_df=pd.read_excel(r'C:\Users\Eric.Li\Documents\Post result data\ABO {0}.xlsx'.format(region),\
                                               sheet_name='IPO',header=1).dropna(how='all',axis=1)
            
            adj_IPO_df=IPO_df.set_index(pd.MultiIndex.from_tuples(list(zip(IPO_df["Ticker"],\
                                                                                       IPO_df["Announced Date"],\
                                                                                       IPO_df["Listing date"])))).\
            dropna(how='all',axis=1)            
            
            adj_IPO_df.to_csv(r'C:\Users\Eric.Li\Documents\Post result code\{0}_IPO.csv'.format(region))
            data_dict['IPO_df']=adj_IPO_df

        except:
            pass
        
        
    return data_dict

# %%
Europe_dict=data_acquisition('Europe',use_cache=False)

# %%
US_dict=data_acquisition('US',use_cache=True)

# %%
Canada_dict=data_acquisition('Canada',use_cache=True)

# %%
##Consider the fact that we get in at close but exit the index over the day

adj_US_return_df=US_dict['VWAP_df']/US_dict['price_df'].shift(1)-1

# %%
adj_Canada_return_df=Canada_dict['VWAP_df']/Canada_dict['price_df'].shift(1)-1

# %% [markdown]
# # 3. Enrich the dataframe

# %%
def adj_df(fundamental_df,price_orig_df,VWAP_orig_df):
    ''' 
    Add some more data on the raw dataframe
    '''
    
    if 'ADV' in fundamental_df.columns:
        adj_df=fundamental_df[(fundamental_df["Market cap"]>500) & (fundamental_df["ADV"]>1)& (fundamental_df["Offer price"]>0)]
    else:
        adj_df=fundamental_df[(fundamental_df["Market cap"]>500)&(fundamental_df["Offer price"]>0)]
        adj_df["ADV"]=1000000
    
    adj_df=adj_df.dropna(how='all',axis=1)
    
    if 'Security type' in fundamental_df.columns:
        del adj_df['Security type']
    else:
        pass
    
    adj_df["listing_price"]=adj_df.apply(lambda x:VWAP_orig_df.loc[:,x.name[0]][x["Listing date"]] \
                                              if x.name[0] in VWAP_orig_df.columns and \
                                              x.name[2] in VWAP_orig_df.index else None,axis=1)
        
    adj_df=adj_df[np.isfinite(adj_df['listing_price'])]
    
    adj_df["announce_price"]=adj_df.apply(lambda x:price_orig_df.loc[:, x.name[0]][x["Announced Date"]] \
                                              if x.name[0] in price_orig_df.columns and \
                                              x.name[1] in price_orig_df.index else None,axis=1)    
    
    adj_df["discount"]=adj_df['Offer price']/adj_df['announce_price']-1
    
    adj_df["firstday_return"]=adj_df['listing_price']/adj_df['Offer price']-1
        
    adj_df['Bookrunner']=adj_df.apply(lambda x:x['Bookrunner'].split(', ') #
                                              if type(x['Bookrunner'])==str else [None],axis=1)
    
    adj_df["Broker_broad"]=adj_df.apply(lambda x:len(set(['Goldman Sachs','JP Morgan','Morgan Stanley','UBS',\
                                                         'Barclays','Bank of America Merrill Lynch','Deutsche Bank',\
                                                         'Credit Suisse','Jefferies','Citi']).\
                                                            intersection(set(x['Bookrunner'])))>0,axis=1)    
    
    adj_df["Broker_core"]=adj_df.apply(lambda x:len(set(['Goldman Sachs','JP Morgan','Morgan Stanley']).\
                                                            intersection(set(x['Bookrunner'])))>0,axis=1)
    
    adj_df_core=adj_df[adj_df["Broker_core"]==True]
    adj_df_broad=adj_df[adj_df["Broker_broad"]==True]
    
    return adj_df_broad,adj_df_core

# %%
Europe_ABO_df,Europe_ABO_core_df=adj_df(Europe_dict['ABO_df'],Europe_dict['price_orig_df'],Europe_dict['VWAP_orig_df'])

# %%
Europe_ABO_core_df_stocks=Europe_ABO_core_df[Europe_ABO_core_df['Type']=='Stocks']

# %%
Europe_ABO_core_df_REIT=Europe_ABO_core_df[Europe_ABO_core_df['Type']=='REIT']

# %%
Europe_IPO_df,Europe_IPO_core_df=adj_df(Europe_dict['IPO_df'],Europe_dict['price_orig_df'],Europe_dict['VWAP_orig_df'])

# %%
Europe_df=Europe_ABO_df.append(Europe_IPO_df,sort=True)

# %%
Europe_core_df=Europe_ABO_core_df.append(Europe_IPO_core_df,sort=True)

# %%
US_ABO_df,US_ABO_core_df=adj_df(US_dict['ABO_df'],US_dict['price_orig_df'],US_dict['VWAP_orig_df'])

# %%
US_ABO_core_df_stocks=US_ABO_core_df[US_ABO_core_df['Type']=='Stocks']

# %%
US_ABO_core_df_REIT=US_ABO_core_df[US_ABO_core_df['Type']=='REIT']

# %%
US_IPO_df,US_IPO_core_df=adj_df(US_dict['IPO_df'],US_dict['price_orig_df'],US_dict['VWAP_orig_df'])
# Out:
# C:\Users\eric.li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
US_df=US_ABO_df.append(US_IPO_df,sort=True)

# %%
US_core_df=US_ABO_core_df.append(US_IPO_core_df,sort=True)

# %%
Canada_ABO_df,Canada_ABO_core_df=adj_df(Canada_dict['ABO_df'],Canada_dict['price_orig_df'],Canada_dict['VWAP_orig_df'])

# %% [markdown]
# # 4. Build the signal

# %%
def sizing(sizing_scheme,target_size,capital,fundamental_df,signal_df,volume_df,liquidity_constraint,allocation_constraint,\
          max_size,exit_rate):
    ''' 
    Calculate the sizing_df for the portfolio
    '''
    if sizing_scheme=='constant':
        sizing_row=signal_df.apply(lambda x:min(target_size*capital,liquidity_constraint*fundamental_df.loc[x.name,"ADV"],\
                                    allocation_constraint*fundamental_df.loc[x.name,"Offer size"])/capital,axis=0)
        
        sizing_dict={}
        for i in signal_df.columns:
            adj_return_series=signal_df[i].bfill(limit=1).dropna()
            adj_return_series.iloc[0]=0.0
            price_scale_series=(1+adj_return_series).cumprod()
            sizing_series=sizing_row[i]*price_scale_series
            sizing_series.iloc[-1]=None
            sizing_dict[i]=sizing_series
        
        sizing_df=pd.DataFrame(sizing_dict)
        
        
    elif sizing_scheme=='fix allocation':
        sizing_row=signal_df.apply(lambda x:min(max_size,min(liquidity_constraint*fundamental_df.loc[x.name,"ADV"],\
                                    allocation_constraint*fundamental_df.loc[x.name,"Offer size"])/capital),axis=0)  
        
        sizing_dict={}
        for i in signal_df.columns:
            adj_return_series=signal_df[i].bfill(limit=1).dropna()
            adj_return_series.iloc[0]=0.0
            price_scale_series=(1+adj_return_series).cumprod()
            sizing_series=sizing_row[i]*price_scale_series
            sizing_series.iloc[-1]=None
            sizing_dict[i]=sizing_series
        
        sizing_df=pd.DataFrame(sizing_dict)     
    
    elif sizing_scheme=='constant volume exit':
        
        '''
        Essentially the idea is to exit certain percentage of volume every day, the key is to use both volume scaler
        and stock return scaler to adjust the size
        '''
        
        
        sizing_row=signal_df.apply(lambda x:min(target_size*capital,liquidity_constraint*fundamental_df.loc[x.name,"ADV"],\
                                    allocation_constraint*fundamental_df.loc[x.name,"Offer size"])/capital,axis=0)
        
        allocation=signal_df.apply(lambda x:min(target_size*capital,liquidity_constraint*fundamental_df.loc[x.name,"ADV"],\
                                     allocation_constraint*fundamental_df.loc[x.name,"Offer size"])\
                                   /fundamental_df.loc[x.name,"Offer size"]*fundamental_df.loc[x.name,"Offer shares"],axis=0)
        
        raw_volume_scaler_df=signal_df.apply(lambda x:(allocation[x.name]-volume_df.loc[x.name[2]:,x.name[0]].cumsum()\
                                                       *exit_rate/1000000)/allocation[x.name],axis=0)
        
        raw_volume_scaler_df_positive=raw_volume_scaler_df[raw_volume_scaler_df>0]
        
        sizing_dict={}        
        
        for i in signal_df.columns:
            adj_return_series=signal_df[i].bfill(limit=1).dropna()
            adj_return_series.iloc[0]=0.0
            price_scale_series=(1+adj_return_series).cumprod()
        
            if sum(raw_volume_scaler_df[i]>0)==0:
                volume_scale_series=raw_volume_scaler_df[i].shift(-1).dropna()[:2]
                volume_scale_series.iloc[0]=1.0
                volume_scale_series.iloc[-1]=None
            else:
                volume_scale_series=raw_volume_scaler_df_positive[i].ffill(limit=1).bfill(limit=1).dropna()
                volume_scale_series.iloc[0]=1.0
                volume_scale_series.iloc[-1]=None
         
            sizing_series=sizing_row[i]*price_scale_series*volume_scale_series
            sizing_dict[i]=sizing_series
        
        sizing_df=pd.DataFrame(sizing_dict)   
        
    elif sizing_scheme=='fix allocation volume exit':
        
        '''
        Essentially the idea is to exit certain percentage of volume every day, the key is to use both volume scaler
        and stock return scaler to adjust the size
        '''
        
        
        sizing_row=signal_df.apply(lambda x:min(max_size,min(liquidity_constraint*fundamental_df.loc[x.name,"ADV"],\
                                    allocation_constraint*fundamental_df.loc[x.name,"Offer size"])/capital),axis=0)  
        
        allocation=signal_df.apply(lambda x:min(target_size*capital,liquidity_constraint*fundamental_df.loc[x.name,"ADV"],\
                                     allocation_constraint*fundamental_df.loc[x.name,"Offer size"])\
                                   /fundamental_df.loc[x.name,"Offer size"]*fundamental_df.loc[x.name,"Offer shares"],axis=0)
        
        raw_volume_scaler_df=signal_df.apply(lambda x:(allocation[x.name]-volume_df.loc[x.name[2]:,x.name[0]].cumsum()\
                                                       *exit_rate/1000000)/allocation[x.name],axis=0)
        
        raw_volume_scaler_df_positive=raw_volume_scaler_df[raw_volume_scaler_df>0]
        
        sizing_dict={}        
        
        for i in signal_df.columns:
            adj_return_series=signal_df[i].bfill(limit=1).dropna()
            adj_return_series.iloc[0]=0.0
            price_scale_series=(1+adj_return_series).cumprod()
        
            if sum(raw_volume_scaler_df[i]>0)==0:
                volume_scale_series=raw_volume_scaler_df[i].shift(-1).dropna()[:2]
                volume_scale_series.iloc[0]=1.0
                volume_scale_series.iloc[-1]=None
            else:
                volume_scale_series=raw_volume_scaler_df_positive[i].ffill(limit=1).bfill(limit=1).dropna()
                volume_scale_series.iloc[0]=1.0
                volume_scale_series.iloc[-1]=None
         
            sizing_series=sizing_row[i]*price_scale_series*volume_scale_series
            sizing_dict[i]=sizing_series
        
        sizing_df=pd.DataFrame(sizing_dict)   
        
    else:
        pass
    return sizing_df

# %%
def trading_analytics_date(portfolio_cache):
    '''
    Key portfolio metrics from portfolio cache
    Feed into plot function
    '''
    
    ind_return=portfolio_cache[3]
    signal_count=len(ind_return)
    account_curve=portfolio_cache[1]
    
    if signal_count==0:
        return None,None,None,None,None,None,None
    else:
        mean_return=ind_return.mean()
        hit_rate=len(ind_return[ind_return>0])/len(ind_return)*1.0
        payoff_ratio=ind_return[ind_return>0].mean()/ind_return[ind_return<0].mean()*-1.0
        
        account_price=account_curve+1
        ann_vol=np.std(account_price.diff()/account_price.shift(1))*(260**0.5)
        ann_ret=(account_price.iloc[-1]**(1/len(account_price)))**260-1
        ann_sharpe=ann_ret/ann_vol
        
        max_dd=-((1+account_curve)-(1+account_curve).cummax(axis=0)).expanding().min().min()
        
        #low_date=(np.maximum.accumulate(account_curve)-account_curve).idxmax()
        #high_date=account_curve[:low_date].idxmax()
        #max_dd=1-(1+account_curve[low_date])/(1+account_curve[high_date])
        
        return signal_count,hit_rate,payoff_ratio,ann_ret,ann_vol,ann_sharpe,max_dd

# %%
def plot_signal(title,figsize,portfolio_cache):

    account_curve=portfolio_cache[1]
    avg_size=np.abs(portfolio_cache[2]).mean(axis=0).mean()
    ind_return=portfolio_cache[3]
    gross=portfolio_cache[4]
    turnover=portfolio_cache[5]

    fig=plt.figure(figsize=figsize)
    ax1=fig.add_subplot(1,1,1)
    ln1=ax1.plot(account_curve,label='signal',color='b')

    val1=ax1.get_yticks()
    start=val1[0]
    end=val1[-1]
    ax1.set_yticks(np.arange(start,end,0.1))  
    adj_val1=ax1.get_yticks()
    ax1.set_yticklabels(["{:.0%}".format(x) for x in adj_val1])

    ax2=ax1.twinx()
    ln2=ax2.plot(gross,label='gross',color='silver')

    val2=ax2.get_yticks()
    start=val2[0]
    end=val2[-1]
    ax2.set_yticks(np.arange(start,end,0.1))  
    adj_val2=ax2.get_yticks()
    ax2.set_yticklabels(["{:.0%}".format(x) for x in adj_val2])

    count,hit,payoff,ret,vol,sharpe,max_dd=trading_analytics_date(portfolio_cache)

    plt.title("\n".join(textwrap.wrap('count='+str(count)+
                             ',avg_size='+str("{:.1%}".format(avg_size))+
                             ',hit_rate='+str("{:.0%}".format(hit))+
                             ',payoff='+str(round(payoff,1))+
                             ',return='+str("{:.1%}".format(ret))+
                             ',vol='+str("{:.1%}".format(vol))+
                             ',sharpe='+str(round(sharpe,1))+
                             ',turnover='+str(round(turnover,1))+'x'+                             
                             ',max_drawdown='+str("{:.1%}".format(max_dd)))),fontsize=10)

    ax1.set_xlabel('Year')
    ax1.set_ylabel('Return')
    ax2.set_ylabel('Exposure')
    plt.suptitle(title,y=1.05,fontsize=16)
    plt.grid(linestyle='dashed')
    plt.legend(ln1+ln2,[l.get_label() for l in ln1+ln2],loc=2)
    ax1.axhline(y=0,color='k')

    plt.show()

# %%
class signal(object):
    ''' 
    Signal class to allow for flexibility
    '''
    def __init__(self,fundamental_df,price_VWAP_df,volume_df,holding,max_holding,sizing_scheme):
        self.fundamental_df=fundamental_df #all the fundamental_df names are part of the signal
        self.price_VWAP_df=price_VWAP_df
        self.abs_return_VWAP=self.price_VWAP_df/self.price_VWAP_df.shift(1)-1
        self.volume_df=volume_df
        self.holding=holding
        self.max_holding=max_holding #max period to build the signal_df
        self.sizing_scheme=sizing_scheme
        
    def signal_df_date(self):
        ''' 
        absolute stock return for the signals over the holding period
        use VWAP return because we enter and exit over the day
        '''
        signal_dict={}

        for i in self.fundamental_df.index:
            if 'volume' in self.sizing_scheme:
                series=self.abs_return_VWAP.loc[i[2]:,i[0]][:self.max_holding]
            else:
                series=self.abs_return_VWAP.loc[i[2]:,i[0]][:self.holding]
            series.iloc[0]=self.fundamental_df.loc[i,"firstday_return"]
            signal_dict[i]=series
            
        signal_df=pd.DataFrame(signal_dict)
        self.signal_df=signal_df
        return signal_df
        
    def signal_account(self,target_size,capital,liquidity_constraint,allocation_constraint,max_size,exit_rate,net,index_df):
        ''' 
        Build the account curve
        '''
        
        try:
            signal_df=self.signal_df.copy()
        except:
            signal_df=self.signal_df_date()
            
        self.index_df=index_df
        alpha_signal_df=pd.concat([signal_df,index_df],axis=1).iloc[:,:-1]
        
        size_df=sizing(self.sizing_scheme,target_size,capital,self.fundamental_df,alpha_signal_df,self.volume_df,\
                       liquidity_constraint,allocation_constraint,max_size,exit_rate)
        

        
        alpha_size_df=pd.concat([size_df,index_df],axis=1).iloc[:,:-1]
        alpha_daily_pnl=alpha_size_df.shift(1)*alpha_signal_df
        alpha_acct_curve=alpha_daily_pnl.cumsum().ffill().sum(axis=1)
        alpha_ind_return=alpha_daily_pnl.cumsum().ffill().iloc[-1]
                
        count_df=alpha_daily_pnl.copy()
        
        count_df=count_df.where(count_df.isnull(),1.0)
        self.adj_signal_df=alpha_signal_df*count_df
        
        alpha_cache=(alpha_daily_pnl,alpha_acct_curve,alpha_size_df,alpha_signal_df)
        
        if net=='gross':
            portfolio_gross=np.abs(alpha_size_df).sum(axis=1).sort_index()
            portfolio_turnover=(np.abs(alpha_size_df.fillna(0.0).diff(1)).sum().sum())/(alpha_size_df.shape[0]/260)
            portfolio_cache=(alpha_daily_pnl,alpha_acct_curve,alpha_size_df,alpha_ind_return,portfolio_gross,\
                             portfolio_turnover,self.adj_signal_df)
        else:
            index_size_df=(net-alpha_size_df.sum(axis=1)).to_frame(index_df.columns[0])
            index_daily_pnl=index_size_df.shift(1)*index_df


            portfolio_df=pd.concat([alpha_signal_df,index_df],axis=1)
            portfolio_size_df=pd.concat([alpha_size_df,index_size_df],axis=1).sort_index()
            portfolio_daily_pnl=pd.concat([alpha_daily_pnl,index_daily_pnl],axis=1).sort_index()
            portfolio_acct_curve=portfolio_daily_pnl.cumsum().ffill().sum(axis=1)
            portfolio_ind_return=alpha_ind_return
            portfolio_gross=np.abs(portfolio_size_df).sum(axis=1).sort_index()
            portfolio_turnover=(np.abs(alpha_size_df.fillna(0.0).diff(1)).sum().sum())/(portfolio_size_df.shape[0]/260)

            portfolio_cache=(portfolio_daily_pnl,portfolio_acct_curve,portfolio_size_df,portfolio_ind_return,portfolio_gross,\
                             portfolio_turnover,portfolio_df)
        
        self.alpha_cache=alpha_cache
        self.portfolio_cache=portfolio_cache #save for later use
        
        return alpha_cache,portfolio_cache
        
        
    def plot_account(self,title,figsize=[10,4],portfolio=None):
        '''
        Plot the account curve
        '''
        if portfolio is None:
            try:
                portfolio_cache=self.portfolio_cache

            except AttributeError:
                print("Execute the signal_account first!")  
                return None
        else:
            portfolio_cache=portfolio
        
        plot_signal(title,figsize,portfolio_cache)

# %%
def combine_signal(portfolio_list,capital_list):
    
    
    daily_pnl_list=[]
    signal_df_list=[]
    portfolio_size_list=[]
    for i in range(len(portfolio_list)):

        daily_pnl_list.append(portfolio_list[i][0]*capital_list[i]/np.sum(capital_list))
        signal_df_list.append(portfolio_list[i][-1]*capital_list[i]/np.sum(capital_list))
        portfolio_size_list.append(portfolio_list[i][2]*capital_list[i]/np.sum(capital_list))
    
    daily_pnl=pd.concat(daily_pnl_list,axis=1)
    signal_df=pd.concat(signal_df_list,axis=1)
    size_df=pd.concat(portfolio_size_list,axis=1)
    
    account_curve=daily_pnl.cumsum().ffill().sum(axis=1)
    ind_return=daily_pnl.cumsum().ffill().iloc[-1]

    gross=np.abs(size_df).sum(axis=1)
    turnover=(np.abs(size_df.fillna(0.0).diff(1)).sum().sum())/(size_df.shape[0]/260)
    
    portfolio_cache=(daily_pnl,account_curve,size_df,ind_return,gross,turnover,signal_df)
    return portfolio_cache

# %% [markdown]
# ## 4.1 Europe

# %%
Europe_placing_core=signal(fundamental_df=Europe_ABO_core_df,price_VWAP_df=Europe_dict['VWAP_df'],#
                           volume_df=Europe_dict['volume_df'],\
                      max_holding=60,holding=3,sizing_scheme='fix allocation volume exit')

# %%
_,_=Europe_placing_core.signal_account(target_size=0.2,capital=20,liquidity_constraint=0.2,allocation_constraint=0.02,\
                                  max_size=0.25,exit_rate=0.05,net=0,\
                                       index_df=Europe_dict['abs_return_df']["SX5E Index"].to_frame())

# %%
Europe_placing_core.plot_account('Europe placing - core broker market neutral')

# %%
Europe_IPO_core=signal(fundamental_df=Europe_IPO_core_df,price_VWAP_df=Europe_dict['VWAP'],volume_df=Europe_dict['volume'],\
                      max_holding=60,holding=3,sizing_scheme='fix allocation volume exit')

# %%
_,_=Europe_IPO_core.signal_account(target_size=0.2,capital=20,liquidity_constraint=0.2,allocation_constraint=0.02,\
                                  max_size=0.25,exit_rate=0.05,net=0,index_df=Europe_dict['abs_return']["SX5E Index"].to_frame())

# %%
Europe_IPO_core.plot_account('Europe IPO - core broker')

# %% [markdown]
# ## 4.2 US

# %%
US_placing_core_REIT=signal(fundamental_df=US_ABO_core_df_REIT,price_VWAP_df=US_dict['VWAP_df'],volume_df=US_dict['volume_df'],\
                      max_holding=60,holding=3,sizing_scheme='fix allocation volume exit')

# %%
_,_=US_placing_core_REIT.signal_account(target_size=0.1,capital=30,liquidity_constraint=0.2,allocation_constraint=0.02,\
                                  max_size=1/6,exit_rate=0.05,net=0,index_df=adj_US_return_df["ES1 Index"].to_frame())

# %%
US_placing_core_REIT.plot_account('US placing REIT - core broker market neutral')

# %%
US_placing_core=signal(fundamental_df=US_ABO_core_df,price_VWAP_df=US_dict['VWAP_df'],volume_df=US_dict['volume_df'],\
                      max_holding=60,holding=3,sizing_scheme='fix allocation volume exit')

# %%
_,_=US_placing_core.signal_account(target_size=0.1,capital=30,liquidity_constraint=0.2,allocation_constraint=0.02,\
                                  max_size=1/6,exit_rate=0.05,net=0,index_df=US_dict['abs_return_df']["ES1 Index"].to_frame())

# %%
US_placing_core.plot_account('US placing - core broker market neutral')

# %%
Europe_check=spot_check(Europe_ABO_core_df,Europe_placing_core.portfolio_cache[2],Europe_placing_core.adj_signal_df,\
                    Europe_dict["abs_return_df"]["SX5E Index"],20000)

# %%
US_check=spot_check(US_ABO_core_df,US_placing_core.portfolio_cache[2],US_placing_core.adj_signal_df,\
                    US_dict["abs_return_df"]["ES1 Index"],30000)

# %%
US_check[US_check['Type']=='Stocks']['rel_return'].mean()
# Out:
# 0.01600115086388431

# %%
Europe_check['waiting']=Europe_check.apply(lambda x:(pd.Timestamp(x["Listing date"])-pd.Timestamp(x["Announced Date"])).days,axis=1)

# %%
US_check['waiting']=US_check.apply(lambda x:(pd.Timestamp(x["Listing date"])-pd.Timestamp(x["Announced Date"])).days,axis=1)

# %%
US_check[US_check['waiting']==0]["rel_return"].shape
# Out:
# (117,)

# %%
US_check[US_check['waiting']==1]["rel_return"].shape
# Out:
# (921,)

# %%
US_check[(US_check['waiting']<=5)&(US_check['waiting']>1)]["rel_return"].shape
# Out:
# (530,)

# %%
US_check[US_check['waiting']>5]["rel_return"].shape
# Out:
# (258,)

# %%
Europe_check[Europe_check['waiting']==0]["rel_return"].shape
# Out:
# (164,)

# %%
Europe_check[Europe_check['waiting']==1]["rel_return"].shape
# Out:
# (306,)

# %%
Europe_check[(Europe_check['waiting']<=5)&(Europe_check['waiting']>1)]["rel_return"].shape
# Out:
# (65,)

# %%
Europe_check[Europe_check['waiting']>5]["rel_return"].shape
# Out:
# (32,)

# %%
Europe_check.to_csv("Europe_placing_check.csv")

# %%
US_check.to_csv("US_placing_check.csv")

# %%
US_IPO_core=signal(fundamental_df=US_IPO_core_df,price_VWAP_df=US_dict['VWAP'],volume_df=US_dict['volume'],\
                      max_holding=60,holding=3,sizing_scheme='fix allocation volume exit')

# %%
_,_=US_IPO_core.signal_account(target_size=0.1,capital=30,liquidity_constraint=0.2,allocation_constraint=0.02,\
                                  max_size=1/6,exit_rate=0.05,net=0,index_df=US_dict['abs_return']["SPX Index"].to_frame())

# %%
US_IPO_core.plot_account('US IPO - core broker')

# %%
comb=combine_signal([Europe_placing_core.portfolio_cache,US_placing_core.portfolio_cache],[20,30])

# %%
plot_signal('combined - 5mn USD max size',[10,4],comb)

# %% [markdown]
# ## 4.3 Canada

# %%
Canada_placing_core=signal(fundamental_df=Canada_ABO_core_df,price_VWAP_df=Canada_dict['VWAP_df'],volume_df=Canada_dict['volume_df'],\
                      max_holding=60,holding=3,sizing_scheme='fix allocation volume exit')

# %%
_,_=Canada_placing_core.signal_account(target_size=0.1,capital=5,liquidity_constraint=0.2,allocation_constraint=0.02,\
                                  max_size=1,exit_rate=0.05,net=0,index_df=adj_Canada_return_df["PT1 Index"].to_frame())

# %%
Canada_placing_core.plot_account('Canada placing - core broker market neutral')

# %%
Canada_placing_core.adj_signal_df.sum(axis=0).shape
# Out:
# (18,)

# %%
US_placing_core.plot_account('US placing - core broker no hedging')

# %% [markdown]
# # 5. fitting exercise

# %%
holding=[10,20]
target_size=[0.05,0.1,0.15]
net=[0,0.1,0.2]
sizing_scheme=['constant','fix allocation','constant volume exit','fix allocation volume exit']
max_size=[0.1,0.15,0.2]
exit_rate=[0.01,0.03,0.05]

# %%
fitting_dict={}
for i in list(itertools.product(holding,target_size,net,sizing_scheme,max_size,exit_rate)):
    placing=signal(fundamental_df=adj_Europe,price_df=Europe_price,price_VWAP_df=Europe_VWAP,volume_df=Europe_volume,\
                          max_holding=i[0],sizing_scheme=i[3])    
    cache_1,cache_2=placing.signal_account(target_size=i[1],capital=50,liquidity_constraint=0.1,\
                                                  allocation_constraint=0.05,max_size=i[4],exit_rate=i[5],net=i[2],\
                                           index_df=abs_return_Europe["SX5E Index"].to_frame())
    fitting_dict[i]=trading_analytics_date(cache_2)

# %%
''' performance for each fitting '''
fitting=pd.DataFrame(index=fitting_dict.keys())

# %%
for i in fitting_dict.keys():
    fitting.loc[i,'return']=fitting_dict[i][3]
    fitting.loc[i,'sharpe']=fitting_dict[i][5]
    fitting.loc[i,'drawdown']=fitting_dict[i][6]

# %%
fitting

# %%
fitting_rank=fitting.rank(axis=0)

# %%
adj_rank=fitting_rank['return']+fitting_rank['sharpe']-fitting_rank['drawdown']

# %%
fitting['rank']=adj_rank

# %%
fitting.to_csv('fitting_df.csv')

# %%
fitting[(fitting["sharpe"]>2)&(fitting["return"]>0.05)&(fitting["drawdown"]<0.05)]

# %%
adj_Europe.shape

# %% [markdown]
# # 6. Parameter inquiry
# 1. Offer size
# 2. Market cap
# 3. ADV
# 4. Broker_core

# %%
def perf_review(fundamental_df):
    higher_cap_stock_return=fundamental_df[fundamental_df['Market cap']>fundamental_df['Market cap'].quantile(0.67)]\
    ['cum stock return'].mean()
    mid_cap_stock_return=fundamental_df[(fundamental_df['Market cap']<fundamental_df['Market cap'].quantile(0.67))&\
                                        (fundamental_df['Market cap']>fundamental_df['Market cap'].quantile(0.33))]\
    ['cum stock return'].mean()
    lower_cap_stock_return=fundamental_df[fundamental_df['Market cap']<fundamental_df['Market cap'].quantile(0.33)]\
    ['cum stock return'].mean()
    avg_cap_stock_return=fundamental_df['cum stock return'].mean()
    
    print('stock return by cap '+str((higher_cap_stock_return,mid_cap_stock_return,lower_cap_stock_return,\
                                    avg_cap_stock_return)))
    
    
    higher_cap_contribution=fundamental_df[fundamental_df['Market cap']>fundamental_df['Market cap'].quantile(0.67)]\
    ['cum pnl contribution'].mean()
    mid_cap_contribution=fundamental_df[(fundamental_df['Market cap']<fundamental_df['Market cap'].quantile(0.67))&\
                                        (fundamental_df['Market cap']>fundamental_df['Market cap'].quantile(0.33))]\
    ['cum pnl contribution'].mean()
    lower_cap_contribution=fundamental_df[fundamental_df['Market cap']<fundamental_df['Market cap'].quantile(0.33)]\
    ['cum pnl contribution'].mean()
    avg_cap_contribution=fundamental_df['cum pnl contribution'].mean()

    print('stock contribution by cap '+str((higher_cap_contribution,mid_cap_contribution,lower_cap_contribution,\
                                    avg_cap_contribution)))
    
    
    higher_offer_stock_return=fundamental_df[fundamental_df['Offer size']>fundamental_df['Offer size'].quantile(0.67)]\
    ['cum stock return'].mean()
    mid_offer_stock_return=fundamental_df[(fundamental_df['Offer size']<fundamental_df['Offer size'].quantile(0.67))&\
                                        (fundamental_df['Offer size']>fundamental_df['Offer size'].quantile(0.33))]\
    ['cum stock return'].mean()
    lower_offer_stock_return=fundamental_df[fundamental_df['Offer size']<fundamental_df['Offer size'].quantile(0.33)]\
    ['cum stock return'].mean()
    avg_offer_stock_return=fundamental_df['cum stock return'].mean()
    
    print('stock return by offer size '+str((higher_offer_stock_return,mid_offer_stock_return,lower_offer_stock_return,\
                                    avg_offer_stock_return)))
    
    
    higher_offer_contribution=fundamental_df[fundamental_df['Offer size']>fundamental_df['Offer size'].quantile(0.67)]\
    ['cum pnl contribution'].mean()
    mid_offer_contribution=fundamental_df[(fundamental_df['Offer size']<fundamental_df['Offer size'].quantile(0.67))&\
                                        (fundamental_df['Offer size']>fundamental_df['Offer size'].quantile(0.33))]\
    ['cum pnl contribution'].mean()
    lower_offer_contribution=fundamental_df[fundamental_df['Offer size']<fundamental_df['Offer size'].quantile(0.33)]\
    ['cum pnl contribution'].mean()
    avg_offer_contribution=fundamental_df['cum pnl contribution'].mean()

    print('stock contribution by offer size '+str((higher_offer_contribution,mid_offer_contribution,lower_offer_contribution,\
                                    avg_offer_contribution)))    
    
    core_stock_return=fundamental_df[fundamental_df['Broker_core']==True]['cum stock return'].mean()  
    core_stock_contribution=fundamental_df[fundamental_df['Broker_core']==True]['cum pnl contribution'].mean()  
    non_core_stock_return=fundamental_df[fundamental_df['Broker_core']==False]['cum stock return'].mean()  
    non_core_stock_contribution=fundamental_df[fundamental_df['Broker_core']==False]['cum pnl contribution'].mean()      
    
    print('core return/contribution is '+str((core_stock_return,core_stock_contribution)))
    print('non core return/contribution is '+str((non_core_stock_return,non_core_stock_contribution)))

# %%
perf_review(adj_Europe)

# %%
perf_review(adj_US)

# %%
adj_Europe.shape

# %%
US_placing_core.alpha_cache[2].sum(axis=1).mean()

# %%
Europe_placing_core.alpha_cache[2].sum(axis=1).mean()

# %% [markdown]
# # 7. Buy the dip

# %%
Europe_ABO_df
# Out:
#                                   Announced Date Listing date       Ticker  \
# SAN SM      2015-01-08 2015-01-13     2015-01-08   2015-01-13       SAN SM
# LLOY LN     2014-03-25 2014-03-26     2014-03-25   2014-03-26      LLOY LN
#             2013-09-16 2013-09-17     2013-09-16   2013-09-17      LLOY LN
# VOLVB SS    2010-10-06 2010-10-07     2010-10-06   2010-10-07     VOLVB SS
# ELE SM      2014-11-05 2014-11-21     2014-11-05   2014-11-21       ELE SM
# DBK GR      2013-04-29 2013-04-30     2013-04-29   2013-04-30       DBK GR
# RBI AV      2014-01-21 2014-01-23     2014-01-21   2014-01-23       RBI AV
# AZN LN      2019-03-28 2019-03-29     2019-03-28   2019-03-29       AZN LN
# 1657599D SS 2013-09-24 2013-09-25     2013-09-24   2013-09-25  1657599D SS
# RBS LN      2018-06-04 2018-06-05     2018-06-04   2018-06-05       RBS LN
#             2015-08-03 2015-08-04     2015-08-03   2015-08-04       RBS LN
# 1657599D SS 2013-06-18 2013-06-19     2013-06-18   2013-06-19  1657599D SS
# AIR FP      2013-04-16 2013-04-17     2013-04-16   2013-04-17       AIR FP
#             2013-04-08 2013-04-09     2013-04-08   2013-04-09       AIR FP
# 1657599D SS 2011-02-03 2011-02-04     2011-02-03   2011-02-04  1657599D SS
# REP SM      2014-06-03 2014-06-04     2014-06-03   2014-06-04       REP SM
# 1COV GR     2018-05-03 2018-05-04     2018-05-03   2018-05-04      1COV GR
# CON GR      2011-03-28 2011-03-28     2011-03-28   2011-03-28       CON GR
# BBVA SM     2014-11-19 2014-11-24     2014-11-19   2014-11-24      BBVA SM
# GLEN LN     2015-09-07 2015-09-21     2015-09-07   2015-09-21      GLEN LN
# ADEN SW     2014-03-12 2014-03-13     2014-03-12   2014-03-13      ADEN SW
# ENEL IM     2015-02-25 2015-02-26     2015-02-25   2015-02-26      ENEL IM
# TKA GR      2011-07-07 2011-07-07     2011-07-07   2011-07-07       TKA GR
# SKY LN      2014-07-25 2014-07-30     2014-07-25   2014-07-30       SKY LN
# HEIA NA     2017-09-18 2017-09-19     2017-09-18   2017-09-19      HEIA NA
# BNP FP      2017-05-03 2017-05-04     2017-05-03   2017-05-04       BNP FP
# 1COV GR     2018-01-10 2018-01-11     2018-01-10   2018-01-11      1COV GR
# AIR FP      2012-12-06 2012-12-06     2012-12-06   2012-12-06       AIR FP
# IBE SM      2014-04-09 2014-04-10     2014-04-09   2014-04-10       IBE SM
# CON GR      2012-09-24 2012-09-25     2012-09-24   2012-09-25       CON GR
# ...                                          ...          ...          ...
# CRN LN      2016-03-21 2016-04-19     2016-03-21   2016-04-19       CRN LN
# ACTI SS     2011-01-26 2011-01-27     2011-01-26   2011-01-27      ACTI SS
# MONY LN     2015-07-30 2015-07-31     2015-07-30   2015-07-31      MONY LN
# TPZ SM      2017-05-18 2017-05-19     2017-05-18   2017-05-19       TPZ SM
# JE/ LN      2014-11-12 2014-11-12     2014-11-12   2014-11-12       JE/ LN
# BME SM      2010-02-22 2010-02-22     2010-02-22   2010-02-22       BME SM
# CRN LN      2017-05-15 2017-05-18     2017-05-15   2017-05-18       CRN LN
# AA/ LN      2015-03-25 2015-04-21     2015-03-25   2015-04-21       AA/ LN
# DC/ LN      2010-09-17 2010-09-17     2010-09-17   2010-09-17       DC/ LN
# TALK LN     2017-10-12 2017-10-13     2017-10-12   2017-10-13      TALK LN
# JLG LN      2015-10-22 2015-10-22     2015-10-22   2015-10-22       JLG LN
# CRN LN      2015-12-01 2015-12-02     2015-12-01   2015-12-02       CRN LN
# EQN LN      2016-12-12 2016-12-13     2016-12-12   2016-12-13       EQN LN
# JLG LN      2016-04-20 2016-04-20     2016-04-20   2016-04-20       JLG LN
# TBCG LN     2017-06-27 2017-06-28     2017-06-27   2017-06-28      TBCG LN
# BAVA DC     2015-01-26 2015-01-26     2015-01-26   2015-01-26      BAVA DC
# RCH LN      2015-10-28 2015-10-30     2015-10-28   2015-10-30       RCH LN
# JST GR      2019-06-25 2019-06-26     2019-06-25   2019-06-26       JST GR
# MONI LN     2014-06-10 2014-06-11     2014-06-10   2014-06-11      MONI LN
# NDX SS      2016-11-14 2016-11-15     2016-11-14   2016-11-15       NDX SS
# SANN SW     2015-12-01 2015-12-03     2015-12-01   2015-12-03      SANN SW
# ACX SM      2013-09-16 2013-09-17     2013-09-16   2013-09-17       ACX SM
# LTG LN      2018-10-08 2018-10-08     2018-10-08   2018-10-08       LTG LN
# SMP LN      2014-04-02 2014-04-03     2014-04-02   2014-04-03       SMP LN
# 1684417D LN 2010-10-22 2010-10-22     2010-10-22   2010-10-22  1684417D LN
# HOC LN      2017-03-16 2017-03-17     2017-03-16   2017-03-17       HOC LN
# TALK LN     2011-11-23 2011-11-23     2011-11-23   2011-11-23      TALK LN
# GRG LN      2014-07-07 2014-07-08     2014-07-07   2014-07-08       GRG LN
# IMG LN      2015-02-12 2015-02-12     2015-02-12   2015-02-12       IMG LN
# CPI LN      2018-05-25 2018-05-25     2018-05-25   2018-05-25       CPI LN
#
#                                                       Issuer Name  Offer size  \
# SAN SM      2015-01-08 2015-01-13              Banco Santander SA   8862.7500
# LLOY LN     2014-03-25 2014-03-26        Lloyds Banking Group PLC   6932.4000
#             2013-09-16 2013-09-17        Lloyds Banking Group PLC   5111.1400
# VOLVB SS    2010-10-06 2010-10-07                        Volvo AB   4198.7700
# ELE SM      2014-11-05 2014-11-21                       Endesa SA   3913.6800
# DBK GR      2013-04-29 2013-04-30                Deutsche Bank AG   3874.4700
# RBI AV      2014-01-21 2014-01-23   Raiffeisen Bank International   3764.2000
# AZN LN      2019-03-28 2019-03-29                 AstraZeneca PLC   3510.3100
# 1657599D SS 2013-09-24 2013-09-25                  Nordea Bank AB   3380.5700
# RBS LN      2018-06-04 2018-06-05  Royal Bank of Scotland Group P   3337.2400
#             2015-08-03 2015-08-04  Royal Bank of Scotland Group P   3241.1600
# 1657599D SS 2013-06-18 2013-06-19                  Nordea Bank AB   3024.3300
# AIR FP      2013-04-16 2013-04-17                       Airbus SE   2978.8600
#             2013-04-08 2013-04-09                       Airbus SE   2969.4400
# 1657599D SS 2011-02-03 2011-02-04                  Nordea Bank AB   2939.1100
# REP SM      2014-06-03 2014-06-04                       Repsol SA   2851.4100
# 1COV GR     2018-05-03 2018-05-04                     Covestro AG   2607.5800
# CON GR      2011-03-28 2011-03-28                  Continental AG   2510.3200
# BBVA SM     2014-11-19 2014-11-24  Banco Bilbao Vizcaya Argentari   2510.0000
# GLEN LN     2015-09-07 2015-09-21                    Glencore PLC   2498.5300
# ADEN SW     2014-03-12 2014-03-13                 Adecco Group AG   2470.8300
# ENEL IM     2015-02-25 2015-02-26                        Enel SpA   2454.9400
# TKA GR      2011-07-07 2011-07-07                 thyssenkrupp AG   2339.1600
# SKY LN      2014-07-25 2014-07-30                         Sky Ltd   2304.8500
# HEIA NA     2017-09-18 2017-09-19                     Heineken NV   2267.4400
# BNP FP      2017-05-03 2017-05-04                  BNP Paribas SA   2217.2600
# 1COV GR     2018-01-10 2018-01-11                     Covestro AG   2166.2500
# AIR FP      2012-12-06 2012-12-06                       Airbus SE   2155.2300
# IBE SM      2014-04-09 2014-04-10                    Iberdrola SA   2108.9200
# CON GR      2012-09-24 2012-09-25                  Continental AG   2079.6400
# ...                                                           ...         ...
# CRN LN      2016-03-21 2016-04-19                 Cairn Homes PLC     59.0573
# ACTI SS     2011-01-26 2011-01-27               Active Biotech AB     57.9312
# MONY LN     2015-07-30 2015-07-31  Moneysupermarket.com Group PLC     57.9115
# TPZ SM      2017-05-18 2017-05-19              Telepizza Group SA     57.8519
# JE/ LN      2014-11-12 2014-11-12                    Just Eat PLC     57.8492
# BME SM      2010-02-22 2010-02-22  Bolsas y Mercados Espanoles SH     57.0841
# CRN LN      2017-05-15 2017-05-18                 Cairn Homes PLC     56.9742
# AA/ LN      2015-03-25 2015-04-21                          AA PLC     56.2718
# DC/ LN      2010-09-17 2010-09-17             Dixons Carphone PLC     55.8098
# TALK LN     2017-10-12 2017-10-13      TalkTalk Telecom Group PLC     55.7699
# JLG LN      2015-10-22 2015-10-22            John Laing Group PLC     55.6741
# CRN LN      2015-12-01 2015-12-02                 Cairn Homes PLC     55.2973
# EQN LN      2016-12-12 2016-12-13              Equiniti Group PLC     54.9410
# JLG LN      2016-04-20 2016-04-20            John Laing Group PLC     54.8974
# TBCG LN     2017-06-27 2017-06-28              TBC Bank Group PLC     54.7741
# BAVA DC     2015-01-26 2015-01-26             Bavarian Nordic A/S     54.3145
# RCH LN      2015-10-28 2015-10-30                       Reach PLC     54.2227
# JST GR      2019-06-25 2019-06-26                   JOST Werke AG     53.8982
# MONI LN     2014-06-10 2014-06-11                    Monitise Ltd     53.7784
# NDX SS      2016-11-14 2016-11-15                 Nordax Group AB     53.5197
# SANN SW     2015-12-01 2015-12-03  Santhera Pharmaceuticals Holdi     53.2925
# ACX SM      2013-09-16 2013-09-17                     Acerinox SA     53.2780
# LTG LN      2018-10-08 2018-10-08  Learning Technologies Group PL     53.2141
# SMP LN      2014-04-02 2014-04-03        St Modwen Properties PLC     52.2550
# 1684417D LN 2010-10-22 2010-10-22          Phoenix Group Holdings     51.9675
# HOC LN      2017-03-16 2017-03-17           Hochschild Mining PLC     51.6931
# TALK LN     2011-11-23 2011-11-23      TalkTalk Telecom Group PLC     51.0402
# GRG LN      2014-07-07 2014-07-08                      Greggs PLC     50.5529
# IMG LN      2015-02-12 2015-02-12  Imagination Technologies Group     50.4597
# CPI LN      2018-05-25 2018-05-25                      Capita PLC     50.2368
#
#                                    Offer shares  Offer price  \
# SAN SM      2015-01-08 2015-01-13    1213.59000         6.18
# LLOY LN     2014-03-25 2014-03-26    5555.41000        75.50
#             2013-09-16 2013-09-17    4282.03000        75.00
# VOLVB SS    2010-10-06 2010-10-07     302.91600        93.00
# ELE SM      2014-11-05 2014-11-21     201.80000        13.50
# DBK GR      2013-04-29 2013-04-30      90.00000        32.90
# RBI AV      2014-01-21 2014-01-23      97.47390        28.50
# AZN LN      2019-03-28 2019-03-29      44.38620      6050.00
# 1657599D SS 2013-09-24 2013-09-25     284.18200        76.00
# RBS LN      2018-06-04 2018-06-05     925.00000       271.00
#             2015-08-03 2015-08-04     630.00000       330.00
# 1657599D SS 2013-06-18 2013-06-19     260.00000        75.00
# AIR FP      2013-04-16 2013-04-17      61.11260        37.00
#             2013-04-08 2013-04-09      61.11390        37.35
# 1657599D SS 2011-02-03 2011-02-04     200.00000        74.50
# REP SM      2014-06-03 2014-06-04     104.05700        20.10
# 1COV GR     2018-05-03 2018-05-04      28.81000        75.50
# CON GR      2011-03-28 2011-03-28      29.67920        60.00
# BBVA SM     2014-11-19 2014-11-24     242.42400         8.25
# GLEN LN     2015-09-07 2015-09-21    1307.79000       125.00
# ADEN SW     2014-03-12 2014-03-13      30.21330        71.50
# ENEL IM     2015-02-25 2015-02-26     540.11600         4.00
# TKA GR      2011-07-07 2011-07-07      49.48480        32.95
# SKY LN      2014-07-25 2014-07-30     156.13200       870.00
# HEIA NA     2017-09-18 2017-09-19      22.48500        84.50
# BNP FP      2017-05-03 2017-05-04      31.19840        65.10
# 1COV GR     2018-01-10 2018-01-11      21.00000        86.25
# AIR FP      2012-12-06 2012-12-06      61.10000        27.23
# IBE SM      2014-04-09 2014-04-10     314.88800         4.85
# CON GR      2012-09-24 2012-09-25      20.77910        77.50
# ...                                         ...          ...
# CRN LN      2016-03-21 2016-04-19      46.87500         1.12
# ACTI SS     2011-01-26 2011-01-27       2.50000       150.00
# MONY LN     2015-07-30 2015-07-31      13.27090       280.00
# TPZ SM      2017-05-18 2017-05-19      11.30370         4.60
# JE/ LN      2014-11-12 2014-11-12      12.50000       293.00
# BME SM      2010-02-22 2010-02-22       2.09976        20.00
# CRN LN      2017-05-15 2017-05-18      33.71260         1.54
# AA/ LN      2015-03-25 2015-04-21       9.82130       385.00
# DC/ LN      2010-09-17 2010-09-17      15.00000       238.00
# TALK LN     2017-10-12 2017-10-13      20.00000       210.50
# JLG LN      2015-10-22 2015-10-22      18.99470       190.50
# CRN LN      2015-12-01 2015-12-02      46.92670         1.11
# EQN LN      2016-12-12 2016-12-13      23.64900       183.00
# JLG LN      2016-04-20 2016-04-20      17.75390       215.00
# TBCG LN     2017-06-27 2017-06-28       2.81000      1525.00
# BAVA DC     2015-01-26 2015-01-26       1.79390       200.00
# RCH LN      2015-10-28 2015-10-30      22.39800       158.00
# JST GR      2019-06-25 2019-06-26       1.53010        31.00
# MONI LN     2014-06-10 2014-06-11      49.00000        65.50
# NDX SS      2016-11-14 2016-11-15      10.00000        49.00
# SANN SW     2015-12-01 2015-12-03       0.59000        93.00
# ACX SM      2013-09-16 2013-09-17       4.90080         8.15
# LTG LN      2018-10-08 2018-10-08      31.30940       130.00
# SMP LN      2014-04-02 2014-04-03       8.26650       380.00
# 1684417D LN 2010-10-22 2010-10-22       5.02000       660.00
# HOC LN      2017-03-16 2017-03-17      15.50000       270.00
# TALK LN     2011-11-23 2011-11-23      26.09050       126.00
# GRG LN      2014-07-07 2014-07-08       5.50070       536.50
# IMG LN      2015-02-12 2015-02-12      13.40000       245.00
# CPI LN      2018-05-25 2018-05-25      27.53560       137.00
#
#                                                                           Offer Type  \
# SAN SM      2015-01-08 2015-01-13  ADDL,Primary Share Offering,Accelerated Bookbu...
# LLOY LN     2014-03-25 2014-03-26  ADDL,Secondary Share Offering,Accelerated Book...
#             2013-09-16 2013-09-17  ADDL,Secondary Share Offering,Accelerated Book...
# VOLVB SS    2010-10-06 2010-10-07  ADDL,Secondary Share Offering,Accelerated Book...
# ELE SM      2014-11-05 2014-11-21                      ADDL,Secondary Share Offering
# DBK GR      2013-04-29 2013-04-30  ADDL,Primary Share Offering,Accelerated Bookbuild
# RBI AV      2014-01-21 2014-01-23  ADDL,Primary Share Offering,Accelerated Bookbuild
# AZN LN      2019-03-28 2019-03-29  ADDL,Primary Share Offering,Accelerated Bookbu...
# 1657599D SS 2013-09-24 2013-09-25  ADDL,Secondary Share Offering,Accelerated Book...
# RBS LN      2018-06-04 2018-06-05  ADDL,Secondary Share Offering,Accelerated Book...
#             2015-08-03 2015-08-04  ADDL,Secondary Share Offering,Accelerated Book...
# 1657599D SS 2013-06-18 2013-06-19  ADDL,Secondary Share Offering,Accelerated Book...
# AIR FP      2013-04-16 2013-04-17  ADDL,Secondary Share Offering,Accelerated Book...
#             2013-04-08 2013-04-09  ADDL,Secondary Share Offering,Accelerated Book...
# 1657599D SS 2011-02-03 2011-02-04  ADDL,Secondary Share Offering,Accelerated Book...
# REP SM      2014-06-03 2014-06-04  ADDL,Secondary Share Offering,Block,Government...
# 1COV GR     2018-05-03 2018-05-04  ADDL,Secondary Share Offering,Accelerated Book...
# CON GR      2011-03-28 2011-03-28  ADDL,Secondary Share Offering,Accelerated Book...
# BBVA SM     2014-11-19 2014-11-24  ADDL,Primary Share Offering,Accelerated Bookbu...
# GLEN LN     2015-09-07 2015-09-21  ADDL,Primary Share Offering,Accelerated Bookbu...
# ADEN SW     2014-03-12 2014-03-13  ADDL,Secondary Share Offering,Accelerated Book...
# ENEL IM     2015-02-25 2015-02-26  ADDL,Secondary Share Offering,Accelerated Book...
# TKA GR      2011-07-07 2011-07-07                  ADDL,Primary Share Offering,Block
# SKY LN      2014-07-25 2014-07-30  ADDL,Primary Share Offering,Accelerated Bookbuild
# HEIA NA     2017-09-18 2017-09-19  ADDL,Secondary Share Offering,Accelerated Book...
# BNP FP      2017-05-03 2017-05-04  ADDL,Secondary Share Offering,Accelerated Book...
# 1COV GR     2018-01-10 2018-01-11  ADDL,Secondary Share Offering,Accelerated Book...
# AIR FP      2012-12-06 2012-12-06  ADDL,Secondary Share Offering,Accelerated Book...
# IBE SM      2014-04-09 2014-04-10  ADDL,Secondary Share Offering,Accelerated Book...
# CON GR      2012-09-24 2012-09-25  ADDL,Secondary Share Offering,Accelerated Book...
# ...                                                                              ...
# CRN LN      2016-03-21 2016-04-19  ADDL,Primary Share Offering,Accelerated Bookbu...
# ACTI SS     2011-01-26 2011-01-27  ADDL,Primary Share Offering,Accelerated Bookbuild
# MONY LN     2015-07-30 2015-07-31  ADDL,Secondary Share Offering,Accelerated Book...
# TPZ SM      2017-05-18 2017-05-19  ADDL,Secondary Share Offering,PE Backed,PE Exi...
# JE/ LN      2014-11-12 2014-11-12  ADDL,Secondary Share Offering,VC Backed,VC Exi...
# BME SM      2010-02-22 2010-02-22  ADDL,Secondary Share Offering,Accelerated Book...
# CRN LN      2017-05-15 2017-05-18  ADDL,Primary Share Offering,Accelerated Bookbu...
# AA/ LN      2015-03-25 2015-04-21                        ADDL,Primary Share Offering
# DC/ LN      2010-09-17 2010-09-17  ADDL,Primary Share Offering,Accelerated Bookbuild
# TALK LN     2017-10-12 2017-10-13  ADDL,Secondary Share Offering,Accelerated Book...
# JLG LN      2015-10-22 2015-10-22  ADDL,Secondary Share Offering,Accelerated Book...
# CRN LN      2015-12-01 2015-12-02  ADDL,Primary Share Offering,Accelerated Bookbuild
# EQN LN      2016-12-12 2016-12-13  ADDL,Secondary Share Offering,PE Backed,PE Exi...
# JLG LN      2016-04-20 2016-04-20  ADDL,Secondary Share Offering,Accelerated Book...
# TBCG LN     2017-06-27 2017-06-28  ADDL,Secondary Share Offering,Accelerated Book...
# BAVA DC     2015-01-26 2015-01-26  ADDL,Secondary Share Offering,Accelerated Book...
# RCH LN      2015-10-28 2015-10-30  ADDL,Primary Share Offering,Accelerated Bookbu...
# JST GR      2019-06-25 2019-06-26  ADDL,Secondary Share Offering,PE Backed,PE Exi...
# MONI LN     2014-06-10 2014-06-11  ADDL,Secondary Share Offering,Accelerated Book...
# NDX SS      2016-11-14 2016-11-15  ADDL,Secondary Share Offering,PE Backed,PE Exi...
# SANN SW     2015-12-01 2015-12-03  ADDL,Primary Share Offering,Accelerated Bookbu...
# ACX SM      2013-09-16 2013-09-17  ADDL,Secondary Share Offering,Accelerated Book...
# LTG LN      2018-10-08 2018-10-08  ADDL,Secondary Share Offering,Best Efforts,Sub...
# SMP LN      2014-04-02 2014-04-03  ADDL,Secondary Share Offering,Accelerated Book...
# 1684417D LN 2010-10-22 2010-10-22  ADDL,Primary Share Offering,Accelerated Bookbuild
# HOC LN      2017-03-16 2017-03-17  ADDL,Secondary Share Offering,Accelerated Book...
# TALK LN     2011-11-23 2011-11-23  ADDL,Secondary Share Offering,Accelerated Book...
# GRG LN      2014-07-07 2014-07-08  ADDL,Secondary Share Offering,Accelerated Book...
# IMG LN      2015-02-12 2015-02-12  ADDL,Secondary Share Offering,Accelerated Book...
# CPI LN      2018-05-25 2018-05-25         ADDL,Primary Share Offering,Rump Placement
#
#                                    Market Cap at Offer (M)  Offer To 1st Open  \
# SAN SM      2015-01-08 2015-01-13                    0.000          -3.608412
# LLOY LN     2014-03-25 2014-03-26                89275.500          -0.662252
#             2013-09-16 2013-09-17                85158.900           0.160000
# VOLVB SS    2010-10-06 2010-10-07                    0.000          -1.236559
# ELE SM      2014-11-05 2014-11-21                 3928.410           7.333333
# DBK GR      2013-04-29 2013-04-30                    0.000           5.927047
# RBI AV      2014-01-21 2014-01-23                    0.000          12.118782
# AZN LN      2019-03-28 2019-03-29               103114.000           1.818182
# 1657599D SS 2013-09-24 2013-09-25                    0.000           1.907895
# RBS LN      2018-06-04 2018-06-05                43617.300          -1.586716
#             2015-08-03 2015-08-04                33372.900           3.272727
# 1657599D SS 2013-06-18 2013-06-19                47523.300          -0.666667
# AIR FP      2013-04-16 2013-04-17                    0.000           5.405406
#             2013-04-08 2013-04-09                    0.000           1.204823
# 1657599D SS 2011-02-03 2011-02-04                    0.000           0.201342
# REP SM      2014-06-03 2014-06-04                36227.900           0.248754
# 1COV GR     2018-05-03 2018-05-04                18328.200          -0.556291
# CON GR      2011-03-28 2011-03-28                    0.000           5.216667
# BBVA SM     2014-11-19 2014-11-24                    0.000           2.787879
# GLEN LN     2015-09-07 2015-09-21                27859.200          -4.640000
# ADEN SW     2014-03-12 2014-03-13                    0.000           1.818182
# ENEL IM     2015-02-25 2015-02-26                42108.400           0.900000
# TKA GR      2011-07-07 2011-07-07                    0.000          -0.485587
# SKY LN      2014-07-25 2014-07-30                    0.000           1.034483
# HEIA NA     2017-09-18 2017-09-19                58280.200          -0.449704
# BNP FP      2017-05-03 2017-05-04                89153.800           1.305686
# 1COV GR     2018-01-10 2018-01-11                21025.100           3.489855
# AIR FP      2012-12-06 2012-12-06                    0.000           8.189499
# IBE SM      2014-04-09 2014-04-10                42926.800          -0.927833
# CON GR      2012-09-24 2012-09-25                    0.000           0.348387
# ...                                                    ...                ...
# CRN LN      2016-03-21 2016-04-19                  847.368           0.892857
# ACTI SS     2011-01-26 2011-01-27                 1594.480           2.333333
# MONY LN     2015-07-30 2015-07-31                 2394.620           4.607143
# TPZ SM      2017-05-18 2017-05-19                  518.498           4.565219
# JE/ LN      2014-11-12 2014-11-12                 2627.740           9.795222
# BME SM      2010-02-22 2010-02-22                    0.000           0.500000
# CRN LN      2017-05-15 2017-05-18                    0.000           0.974028
# AA/ LN      2015-03-25 2015-04-21                 3471.760           1.974026
# DC/ LN      2010-09-17 2010-09-17                    0.000          -3.361345
# TALK LN     2017-10-12 2017-10-13                 2664.730          -2.660332
# JLG LN      2015-10-22 2015-10-22                 1075.470           1.417323
# CRN LN      2015-12-01 2015-12-02                    0.000           5.405404
# EQN LN      2016-12-12 2016-12-13                  696.206           2.185792
# JLG LN      2016-04-20 2016-04-20                    0.000           0.000000
# TBCG LN     2017-06-27 2017-06-28                 1040.910           1.770492
# BAVA DC     2015-01-26 2015-01-26                  837.810           4.000000
# RCH LN      2015-10-28 2015-10-30                  678.060           8.386076
# JST GR      2019-06-25 2019-06-26                  525.781          -1.612903
# MONI LN     2014-06-10 2014-06-11                 2029.820          -1.526718
# NDX SS      2016-11-14 2016-11-15                  592.492           0.612245
# SANN SW     2015-12-01 2015-12-03                  568.947           1.075269
# ACX SM      2013-09-16 2013-09-17                    0.000           0.269943
# LTG LN      2018-10-08 2018-10-08                 1131.510           1.923077
# SMP LN      2014-04-02 2014-04-03                    0.000           2.368421
# 1684417D LN 2010-10-22 2010-10-22                    0.000           3.712121
# HOC LN      2017-03-16 2017-03-17                 1697.400          -1.333333
# TALK LN     2011-11-23 2011-11-23                    0.000           2.777778
# GRG LN      2014-07-07 2014-07-08                    0.000           1.304753
# IMG LN      2015-02-12 2015-02-12                 1020.200           2.448980
# CPI LN      2018-05-25 2018-05-25                    0.000           5.839416
#
#                                    Offer To 1st Close   Market cap  \
# SAN SM      2015-01-08 2015-01-13           -3.737861  101955.5983
# LLOY LN     2014-03-25 2014-03-26           -0.158940   89275.5000
#             2013-09-16 2013-09-17            1.666667   85158.9000
# VOLVB SS    2010-10-06 2010-10-07           -0.967742   30388.2101
# ELE SM      2014-11-05 2014-11-21           10.296296    3928.4100
# DBK GR      2013-04-29 2013-04-30            8.814585   40866.0064
# RBI AV      2014-01-21 2014-01-23           12.485183    7920.7925
# AZN LN      2019-03-28 2019-03-29            1.966942  103114.0000
# 1657599D SS 2013-09-24 2013-09-25            2.565789   50206.0153
# RBS LN      2018-06-04 2018-06-05           -0.147601   43617.3000
#             2015-08-03 2015-08-04            5.060606   33372.9000
# 1657599D SS 2013-06-18 2013-06-19           -2.266667   47523.3000
# AIR FP      2013-04-16 2013-04-17            4.851351   40725.7548
#             2013-04-08 2013-04-09            3.012052   41853.7143
# 1657599D SS 2011-02-03 2011-02-04            0.536913   49033.1156
# REP SM      2014-06-03 2014-06-04            0.199003   36227.9000
# 1COV GR     2018-05-03 2018-05-04            0.900662   18328.2000
# CON GR      2011-03-28 2011-03-28            3.966667   17799.4059
# BBVA SM     2014-11-19 2014-11-24            3.624242   64310.7286
# GLEN LN     2015-09-07 2015-09-21          -14.920000   27859.2000
# ADEN SW     2014-03-12 2014-03-13            2.167832   17014.8821
# ENEL IM     2015-02-25 2015-02-26            2.950000   42108.4000
# TKA GR      2011-07-07 2011-07-07           -1.396057   24283.0274
# SKY LN      2014-07-25 2014-07-30            1.034483   23190.8942
# HEIA NA     2017-09-18 2017-09-19            0.000000   58280.2000
# BNP FP      2017-05-03 2017-05-04            4.270356   89153.8000
# 1COV GR     2018-01-10 2018-01-11            5.530435   21025.1000
# AIR FP      2012-12-06 2012-12-06            9.419760   31500.0203
# IBE SM      2014-04-09 2014-04-10           -1.237111   42926.8000
# CON GR      2012-09-24 2012-09-25           -1.690323   20247.1763
# ...                                               ...          ...
# CRN LN      2016-03-21 2016-04-19            1.785714     847.3680
# ACTI SS     2011-01-26 2011-01-27            2.666667    1594.4800
# MONY LN     2015-07-30 2015-07-31            5.785714    2394.6200
# TPZ SM      2017-05-18 2017-05-19           10.652176     518.4980
# JE/ LN      2014-11-12 2014-11-12            9.215017    2627.7400
# BME SM      2010-02-22 2010-02-22           -1.200000    2360.1226
# CRN LN      2017-05-15 2017-05-18            0.000002    1198.9098
# AA/ LN      2015-03-25 2015-04-21            5.194805    3471.7600
# DC/ LN      2010-09-17 2010-09-17            1.260504    1709.4716
# TALK LN     2017-10-12 2017-10-13            1.900238    2664.7300
# JLG LN      2015-10-22 2015-10-22            1.207349    1075.4700
# CRN LN      2015-12-01 2015-12-02            5.180179     563.5005
# EQN LN      2016-12-12 2016-12-13            2.185792     696.2060
# JLG LN      2016-04-20 2016-04-20           -1.581395    1142.4894
# TBCG LN     2017-06-27 2017-06-28            2.557377    1040.9100
# BAVA DC     2015-01-26 2015-01-26            1.500000     837.8100
# RCH LN      2015-10-28 2015-10-30            9.177216     678.0600
# JST GR      2019-06-25 2019-06-26           -1.612903     525.7810
# MONI LN     2014-06-10 2014-06-11           -2.290076    2029.8200
# NDX SS      2016-11-14 2016-11-15            0.816327     592.4920
# SANN SW     2015-12-01 2015-12-03           -1.290323     568.9470
# ACX SM      2013-09-16 2013-09-17            0.858900    2829.8101
# LTG LN      2018-10-08 2018-10-08           -0.384615    1131.5100
# SMP LN      2014-04-02 2014-04-03            1.421053    1455.3905
# 1684417D LN 2010-10-22 2010-10-22            2.196970    1386.8514
# HOC LN      2017-03-16 2017-03-17           -0.407407    1697.4000
# TALK LN     2011-11-23 2011-11-23            1.666667    1812.3751
# GRG LN      2014-07-07 2014-07-08           -0.745573     978.1659
# IMG LN      2015-02-12 2015-02-12            5.306122    1020.2000
# CPI LN      2018-05-25 2018-05-25            1.751825    3240.2758
#
#                                           ADV  \
# SAN SM      2015-01-08 2015-01-13  680.123369
# LLOY LN     2014-03-25 2014-03-26  184.349436
#             2013-09-16 2013-09-17  152.965022
# VOLVB SS    2010-10-06 2010-10-07   94.513279
# ELE SM      2014-11-05 2014-11-21   29.560442
# DBK GR      2013-04-29 2013-04-30  293.236953
# RBI AV      2014-01-21 2014-01-23    9.665246
# AZN LN      2019-03-28 2019-03-29  168.770458
# 1657599D SS 2013-09-24 2013-09-25   92.365653
# RBS LN      2018-06-04 2018-06-05   64.381835
#             2015-08-03 2015-08-04   66.223664
# 1657599D SS 2013-06-18 2013-06-19   80.988533
# AIR FP      2013-04-16 2013-04-17  194.138734
#             2013-04-08 2013-04-09  191.522962
# 1657599D SS 2011-02-03 2011-02-04   85.015387
# REP SM      2014-06-03 2014-06-04  319.463840
# 1COV GR     2018-05-03 2018-05-04  100.425950
# CON GR      2011-03-28 2011-03-28   39.850667
# BBVA SM     2014-11-19 2014-11-24  516.440790
# GLEN LN     2015-09-07 2015-09-21  221.249368
# ADEN SW     2014-03-12 2014-03-13   43.678339
# ENEL IM     2015-02-25 2015-02-26  211.350852
# TKA GR      2011-07-07 2011-07-07  118.720977
# SKY LN      2014-07-25 2014-07-30   47.005963
# HEIA NA     2017-09-18 2017-09-19   41.558785
# BNP FP      2017-05-03 2017-05-04  313.852509
# 1COV GR     2018-01-10 2018-01-11   62.375300
# AIR FP      2012-12-06 2012-12-06   76.185050
# IBE SM      2014-04-09 2014-04-10  278.830241
# CON GR      2012-09-24 2012-09-25   50.337786
# ...                                       ...
# CRN LN      2016-03-21 2016-04-19    1.948901
# ACTI SS     2011-01-26 2011-01-27    2.112035
# MONY LN     2015-07-30 2015-07-31    3.030364
# TPZ SM      2017-05-18 2017-05-19    1.272512
# JE/ LN      2014-11-12 2014-11-12    5.627119
# BME SM      2010-02-22 2010-02-22   28.994338
# CRN LN      2017-05-15 2017-05-18    6.236284
# AA/ LN      2015-03-25 2015-04-21    9.556820
# DC/ LN      2010-09-17 2010-09-17    1.179306
# TALK LN     2017-10-12 2017-10-13    4.547574
# JLG LN      2015-10-22 2015-10-22    2.018722
# CRN LN      2015-12-01 2015-12-02    2.085273
# EQN LN      2016-12-12 2016-12-13    1.594171
# JLG LN      2016-04-20 2016-04-20    1.470002
# TBCG LN     2017-06-27 2017-06-28    3.799286
# BAVA DC     2015-01-26 2015-01-26    3.826746
# RCH LN      2015-10-28 2015-10-30    1.384651
# JST GR      2019-06-25 2019-06-26    1.011655
# MONI LN     2014-06-10 2014-06-11   23.370951
# NDX SS      2016-11-14 2016-11-15    1.571508
# SANN SW     2015-12-01 2015-12-03    2.202898
# ACX SM      2013-09-16 2013-09-17    9.332444
# LTG LN      2018-10-08 2018-10-08    4.330283
# SMP LN      2014-04-02 2014-04-03    1.684062
# 1684417D LN 2010-10-22 2010-10-22   10.704570
# HOC LN      2017-03-16 2017-03-17    6.992275
# TALK LN     2011-11-23 2011-11-23    1.971493
# GRG LN      2014-07-07 2014-07-08    1.452572
# IMG LN      2015-02-12 2015-02-12    2.438057
# CPI LN      2018-05-25 2018-05-25   22.606145
#
#                                                                           Bookrunner  \
# SAN SM      2015-01-08 2015-01-13                               [Goldman Sachs, UBS]
# LLOY LN     2014-03-25 2014-03-26  [Bank of America Merrill Lynch, JP Morgan, Mor...
#             2013-09-16 2013-09-17    [Bank of America Merrill Lynch, JP Morgan, UBS]
# VOLVB SS    2010-10-06 2010-10-07                                    [Goldman Sachs]
# ELE SM      2014-11-05 2014-11-21  [Banco Bilbao Vizcaya Argentaria, Banco Santan...
# DBK GR      2013-04-29 2013-04-30                                    [Deutsche Bank]
# RBI AV      2014-01-21 2014-01-23  [Raiffeisen Bank International Group, UBS, Deu...
# AZN LN      2019-03-28 2019-03-29                    [Goldman Sachs, Morgan Stanley]
# 1657599D SS 2013-09-24 2013-09-25  [Bank of America Merrill Lynch, Carnegie, Gold...
# RBS LN      2018-06-04 2018-06-05   [Citi, Goldman Sachs, JP Morgan, Morgan Stanley]
#             2015-08-03 2015-08-04         [Citi, Goldman Sachs, Morgan Stanley, UBS]
# 1657599D SS 2013-06-18 2013-06-19               [Credit Suisse, Morgan Stanley, SEB]
# AIR FP      2013-04-16 2013-04-17                    [Goldman Sachs, Morgan Stanley]
#             2013-04-08 2013-04-09  [Bank of America Merrill Lynch, Credit Agricol...
# 1657599D SS 2011-02-03 2011-02-04                      [Morgan Stanley, Nomura, SEB]
# REP SM      2014-06-03 2014-06-04                              [Citi, Deutsche Bank]
# 1COV GR     2018-05-03 2018-05-04         [Bank of America Merrill Lynch, JP Morgan]
# CON GR      2011-03-28 2011-03-28                                    [Goldman Sachs]
# BBVA SM     2014-11-19 2014-11-24    [Bank of America Merrill Lynch, Morgan Stanley]
# GLEN LN     2015-09-07 2015-09-21                             [Citi, Morgan Stanley]
# ADEN SW     2014-03-12 2014-03-13                                    [Goldman Sachs]
# ENEL IM     2015-02-25 2015-02-26  [Bank of America Merrill Lynch, Goldman Sachs,...
# TKA GR      2011-07-07 2011-07-07                 [Commerzbank, Deutsche Bank, HSBC]
# SKY LN      2014-07-25 2014-07-30                         [Barclays, Morgan Stanley]
# HEIA NA     2017-09-18 2017-09-19                   [JP Morgan, Morgan Stanley, UBS]
# BNP FP      2017-05-03 2017-05-04  [BNP Paribas, Citi, Goldman Sachs, Bank of Ame...
# 1COV GR     2018-01-10 2018-01-11                     [Credit Suisse, Goldman Sachs]
# AIR FP      2012-12-06 2012-12-06                    [Goldman Sachs, Morgan Stanley]
# IBE SM      2014-04-09 2014-04-10                                        [Citi, UBS]
# CON GR      2012-09-24 2012-09-25                                    [Goldman Sachs]
# ...                                                                              ...
# CRN LN      2016-03-21 2016-04-19    [Bank of America Merrill Lynch, Davy, Goodbody]
# ACTI SS     2011-01-26 2011-01-27                              [Carnegie, Jefferies]
# MONY LN     2015-07-30 2015-07-31                                    [Credit Suisse]
# TPZ SM      2017-05-18 2017-05-19                  [Barclays, Fidentiis Equities SA]
# JE/ LN      2014-11-12 2014-11-12                                        [Jefferies]
# BME SM      2010-02-22 2010-02-22                   [Banco Santander, Credit Suisse]
# CRN LN      2017-05-15 2017-05-18          [Bank of America Merrill Lynch, Goodbody]
# AA/ LN      2015-03-25 2015-04-21  [Cenkos Securities, Credit Suisse, Morgan Stan...
# DC/ LN      2010-09-17 2010-09-17                                             [Citi]
# TALK LN     2017-10-12 2017-10-13                                        [Jefferies]
# JLG LN      2015-10-22 2015-10-22                                         [Barclays]
# CRN LN      2015-12-01 2015-12-02                          [Credit Suisse, Goodbody]
# EQN LN      2016-12-12 2016-12-13                                         [Barclays]
# JLG LN      2016-04-20 2016-04-20                                         [Barclays]
# TBCG LN     2017-06-27 2017-06-28            [Barclays, Renaissance Capital Pty Ltd]
# BAVA DC     2015-01-26 2015-01-26                       [Jefferies, Nordea Bank Abp]
# RCH LN      2015-10-28 2015-10-30                                  [Barclays, Numis]
# JST GR      2019-06-25 2019-06-26                           [Commerzbank, JP Morgan]
# MONI LN     2014-06-10 2014-06-11                                    [Credit Suisse]
# NDX SS      2016-11-14 2016-11-15                         [Carnegie, Morgan Stanley]
# SANN SW     2015-12-01 2015-12-03                                    [Credit Suisse]
# ACX SM      2013-09-16 2013-09-17                                              [UBS]
# LTG LN      2018-10-08 2018-10-08  [Goldman Sachs, Joh Berenberg Gossler & Co KG,...
# SMP LN      2014-04-02 2014-04-03                                 [JP Morgan, Numis]
# 1684417D LN 2010-10-22 2010-10-22                         [Deutsche Bank, JP Morgan]
# HOC LN      2017-03-16 2017-03-17                                        [JP Morgan]
# TALK LN     2011-11-23 2011-11-23                                         [Barclays]
# GRG LN      2014-07-07 2014-07-08                                              [UBS]
# IMG LN      2015-02-12 2015-02-12                                        [JP Morgan]
# CPI LN      2018-05-25 2018-05-25  [Barclays, Citi, Goldman Sachs, Banco Santande...
#
#                                    listing_price  announce_price  discount  \
# SAN SM      2015-01-08 2015-01-13         6.1127           6.856 -0.098600
# LLOY LN     2014-03-25 2014-03-26        75.4255          79.110 -0.045633
#             2013-09-16 2013-09-17        75.3435          77.360 -0.030507
# VOLVB SS    2010-10-06 2010-10-07        93.0120          97.050 -0.041731
# ELE SM      2014-11-05 2014-11-21        14.1844          14.620 -0.076607
# DBK GR      2013-04-29 2013-04-30        35.0715          33.600 -0.020833
# RBI AV      2014-01-21 2014-01-23        32.4178          29.900 -0.046823
# AZN LN      2019-03-28 2019-03-29      6141.7047        6496.000 -0.068658
# 1657599D SS 2013-09-24 2013-09-25        77.1340          79.200 -0.040404
# RBS LN      2018-06-04 2018-06-05       268.9912         280.900 -0.035244
#             2015-08-03 2015-08-04       330.7483         337.600 -0.022512
# 1657599D SS 2013-06-18 2013-06-19        75.5477          78.750 -0.047619
# AIR FP      2013-04-16 2013-04-17        38.8716          37.195 -0.005243
#             2013-04-08 2013-04-09        37.6091          38.710 -0.035133
# 1657599D SS 2011-02-03 2011-02-04        75.0875          78.400 -0.049745
# REP SM      2014-06-03 2014-06-04        20.0849          20.865 -0.036664
# 1COV GR     2018-05-03 2018-05-04        75.3888          76.240 -0.009706
# CON GR      2011-03-28 2011-03-28        62.2760          63.130 -0.049580
# BBVA SM     2014-11-19 2014-11-24         8.5017           8.643 -0.045470
# GLEN LN     2015-09-07 2015-09-21       120.3247         131.800 -0.051593
# ADEN SW     2014-03-12 2014-03-13        72.8681          78.600 -0.090331
# ENEL IM     2015-02-25 2015-02-26         4.0097           4.048 -0.011858
# TKA GR      2011-07-07 2011-07-07        32.8902          32.900  0.001520
# SKY LN      2014-07-25 2014-07-30       879.5228         874.500 -0.005146
# HEIA NA     2017-09-18 2017-09-19        84.3004          87.590 -0.035278
# BNP FP      2017-05-03 2017-05-04        65.9354          66.150 -0.015873
# 1COV GR     2018-01-10 2018-01-11        87.8091          86.780 -0.006107
# AIR FP      2012-12-06 2012-12-06        29.2046          29.400 -0.073810
# IBE SM      2014-04-09 2014-04-10         4.8386           5.002 -0.030388
# CON GR      2012-09-24 2012-09-25        78.0529          78.390 -0.011353
# ...                                          ...             ...       ...
# CRN LN      2016-03-21 2016-04-19         1.1545           1.190 -0.058824
# ACTI SS     2011-01-26 2011-01-27       153.3662         159.000 -0.056604
# MONY LN     2015-07-30 2015-07-31       281.0537         296.000 -0.054054
# TPZ SM      2017-05-18 2017-05-19         4.7675           4.818 -0.045247
# JE/ LN      2014-11-12 2014-11-12       294.5629         321.000 -0.087227
# BME SM      2010-02-22 2010-02-22        20.8716          20.765 -0.036841
# CRN LN      2017-05-15 2017-05-18         1.5498           1.585 -0.028391
# AA/ LN      2015-03-25 2015-04-21       392.1923         425.200 -0.094544
# DC/ LN      2010-09-17 2010-09-17       239.8337         239.250 -0.005225
# TALK LN     2017-10-12 2017-10-13       204.1975         218.000 -0.034404
# JLG LN      2015-10-22 2015-10-22       191.0172         190.500  0.000000
# CRN LN      2015-12-01 2015-12-02         1.1630           1.130 -0.017699
# EQN LN      2016-12-12 2016-12-13       186.9946         194.250 -0.057915
# JLG LN      2016-04-20 2016-04-20       217.8481         216.500 -0.006928
# TBCG LN     2017-06-27 2017-06-28      1553.7359        1632.000 -0.065564
# BAVA DC     2015-01-26 2015-01-26       213.3697         215.000 -0.069767
# RCH LN      2015-10-28 2015-10-30       169.1614         172.250 -0.082729
# JST GR      2019-06-25 2019-06-26        30.5797          32.400 -0.043210
# MONI LN     2014-06-10 2014-06-11        65.3566          67.500 -0.029630
# NDX SS      2016-11-14 2016-11-15        49.6564          51.750 -0.053140
# SANN SW     2015-12-01 2015-12-03        94.4746          98.000 -0.051020
# ACX SM      2013-09-16 2013-09-17         8.1836           8.250 -0.012121
# LTG LN      2018-10-08 2018-10-08       130.2644         136.000 -0.044118
# SMP LN      2014-04-02 2014-04-03       382.5418         397.000 -0.042821
# 1684417D LN 2010-10-22 2010-10-22       666.9366         667.500 -0.011236
# HOC LN      2017-03-16 2017-03-17       268.4618         291.400 -0.073439
# TALK LN     2011-11-23 2011-11-23       128.5473         127.700 -0.013312
# GRG LN      2014-07-07 2014-07-08       537.0761         564.500 -0.049601
# IMG LN      2015-02-12 2015-02-12       263.6115         265.000 -0.075472
# CPI LN      2018-05-25 2018-05-25       142.5344         146.900 -0.067393
#
#                                    firstday_return  Broker_broad  Broker_core
# SAN SM      2015-01-08 2015-01-13        -0.010890          True         True
# LLOY LN     2014-03-25 2014-03-26        -0.000987          True         True
#             2013-09-16 2013-09-17         0.004580          True         True
# VOLVB SS    2010-10-06 2010-10-07         0.000129          True         True
# ELE SM      2014-11-05 2014-11-21         0.050696          True         True
# DBK GR      2013-04-29 2013-04-30         0.066003          True        False
# RBI AV      2014-01-21 2014-01-23         0.137467          True        False
# AZN LN      2019-03-28 2019-03-29         0.015158          True         True
# 1657599D SS 2013-09-24 2013-09-25         0.014921          True         True
# RBS LN      2018-06-04 2018-06-05        -0.007413          True         True
#             2015-08-03 2015-08-04         0.002268          True         True
# 1657599D SS 2013-06-18 2013-06-19         0.007303          True         True
# AIR FP      2013-04-16 2013-04-17         0.050584          True         True
#             2013-04-08 2013-04-09         0.006937          True        False
# 1657599D SS 2011-02-03 2011-02-04         0.007886          True         True
# REP SM      2014-06-03 2014-06-04        -0.000751          True        False
# 1COV GR     2018-05-03 2018-05-04        -0.001473          True         True
# CON GR      2011-03-28 2011-03-28         0.037933          True         True
# BBVA SM     2014-11-19 2014-11-24         0.030509          True         True
# GLEN LN     2015-09-07 2015-09-21        -0.037402          True         True
# ADEN SW     2014-03-12 2014-03-13         0.019134          True         True
# ENEL IM     2015-02-25 2015-02-26         0.002425          True         True
# TKA GR      2011-07-07 2011-07-07        -0.001815          True        False
# SKY LN      2014-07-25 2014-07-30         0.010946          True         True
# HEIA NA     2017-09-18 2017-09-19        -0.002362          True         True
# BNP FP      2017-05-03 2017-05-04         0.012833          True         True
# 1COV GR     2018-01-10 2018-01-11         0.018077          True         True
# AIR FP      2012-12-06 2012-12-06         0.072516          True         True
# IBE SM      2014-04-09 2014-04-10        -0.002351          True        False
# CON GR      2012-09-24 2012-09-25         0.007134          True         True
# ...                                            ...           ...          ...
# CRN LN      2016-03-21 2016-04-19         0.030804          True        False
# ACTI SS     2011-01-26 2011-01-27         0.022441          True        False
# MONY LN     2015-07-30 2015-07-31         0.003763          True        False
# TPZ SM      2017-05-18 2017-05-19         0.036413          True        False
# JE/ LN      2014-11-12 2014-11-12         0.005334          True        False
# BME SM      2010-02-22 2010-02-22         0.043580          True        False
# CRN LN      2017-05-15 2017-05-18         0.006364          True        False
# AA/ LN      2015-03-25 2015-04-21         0.018681          True         True
# DC/ LN      2010-09-17 2010-09-17         0.007705          True        False
# TALK LN     2017-10-12 2017-10-13        -0.029941          True        False
# JLG LN      2015-10-22 2015-10-22         0.002715          True        False
# CRN LN      2015-12-01 2015-12-02         0.047748          True        False
# EQN LN      2016-12-12 2016-12-13         0.021828          True        False
# JLG LN      2016-04-20 2016-04-20         0.013247          True        False
# TBCG LN     2017-06-27 2017-06-28         0.018843          True        False
# BAVA DC     2015-01-26 2015-01-26         0.066848          True        False
# RCH LN      2015-10-28 2015-10-30         0.070642          True        False
# JST GR      2019-06-25 2019-06-26        -0.013558          True         True
# MONI LN     2014-06-10 2014-06-11        -0.002189          True        False
# NDX SS      2016-11-14 2016-11-15         0.013396          True         True
# SANN SW     2015-12-01 2015-12-03         0.015856          True        False
# ACX SM      2013-09-16 2013-09-17         0.004123          True        False
# LTG LN      2018-10-08 2018-10-08         0.002034          True         True
# SMP LN      2014-04-02 2014-04-03         0.006689          True         True
# 1684417D LN 2010-10-22 2010-10-22         0.010510          True         True
# HOC LN      2017-03-16 2017-03-17        -0.005697          True         True
# TALK LN     2011-11-23 2011-11-23         0.020217          True        False
# GRG LN      2014-07-07 2014-07-08         0.001074          True        False
# IMG LN      2015-02-12 2015-02-12         0.075965          True         True
# CPI LN      2018-05-25 2018-05-25         0.040397          True         True
#
# [1010 rows x 20 columns]

# %%
def placing_follow_return(signal,price_orig_df,price_df,abs_return_df,index_df,evaluate_period,offer_price,return_period):
    ''' 
    calculate abs and rel return following the placing
    '''
    try:
        listing_price=price_orig_df.loc[:,signal[0]][signal[2]]

        firstday_abs_return=listing_price/offer_price-1
        firstday_rel_return=listing_price/offer_price-1-index_df.loc[signal[2]]

        rel_return_df=abs_return_df.sub(index_df,axis=0)

        target_abs_return_df=abs_return_df.loc[signal[2]:,signal[0]][:evaluate_period]
        target_rel_return_df=rel_return_df.loc[signal[2]:,signal[0]][:evaluate_period]

        target_abs_return_df.iloc[0]=firstday_abs_return
        target_rel_return_df.iloc[0]=firstday_rel_return

        evaluate_abs_return=((1+target_abs_return_df).cumprod()-1).iloc[-1]
        evaluate_rel_return=((1+target_rel_return_df).cumprod()-1).iloc[-1]

        follow_abs_return=((1+abs_return_df.loc[signal[2]:,signal[0]][evaluate_period:evaluate_period+return_period]).\
        cumprod()-1)
        follow_abs_return.index=list(range(1,follow_abs_return.shape[0]+1))
        
        follow_rel_return=((1+rel_return_df.loc[signal[2]:,signal[0]][evaluate_period:evaluate_period+return_period]).\
        cumprod()-1)
        follow_rel_return.index=list(range(1,follow_rel_return.shape[0]+1))
    except:
        evaluate_abs_return=None
        evaluate_rel_return=None
        follow_abs_return=None
        follow_rel_return=None
    return evaluate_abs_return,evaluate_rel_return,follow_abs_return,follow_rel_return

# %%
five_day_rel_return_Europe=Europe_ABO_df.apply(lambda x: placing_follow_return(x.name,Europe_dict['price_orig_df'],\
                                                                       Europe_dict['price_df'],Europe_dict['abs_return_df'],\
                                                                      Europe_dict['abs_return_df']['SX5E Index'],5,\
                                                                       x['Offer price'],40)[1],axis=1)

# %%
five_day_follow_rel_return_Europe=Europe_ABO_df.apply(lambda x: placing_follow_return(x.name,Europe_dict['price_orig_df'],\
                                                                       Europe_dict['price_df'],Europe_dict['abs_return_df'],\
                                                                      Europe_dict['abs_return_df']['SX5E Index'],5,\
                                                                       x['Offer price'],40)[3],axis=1)

# %%
five_day_follow_rel_return_Europe.mean(axis=0).plot()

# %%
five_day_follow_rel_return_Europe.loc[five_day_rel_return_Europe[five_day_rel_return_Europe<-0.05].index].mean(axis=0).plot()

# %%
five_day_follow_rel_return_Europe.loc[five_day_rel_return_Europe[five_day_rel_return_Europe<-0.1].index].mean(axis=0).plot()

# %%
ten_day_rel_return_Europe=Europe_ABO_df.apply(lambda x: placing_follow_return(x.name,Europe_dict['price_orig_df'],\
                                                                       Europe_dict['price_df'],Europe_dict['abs_return_df'],\
                                                                      Europe_dict['abs_return_df']['SX5E Index'],10,\
                                                                       x['Offer price'],40)[1],axis=1)

# %%
ten_day_follow_rel_return_Europe=Europe_ABO_df.apply(lambda x: placing_follow_return(x.name,Europe_dict['price_orig_df'],\
                                                                       Europe_dict['price_df'],Europe_dict['abs_return_df'],\
                                                                      Europe_dict['abs_return_df']['SX5E Index'],10,\
                                                                       x['Offer price'],40)[3],axis=1)

# %%
ten_day_follow_rel_return_Europe.mean(axis=0).plot()

# %%
ten_day_follow_rel_return_Europe.loc[ten_day_rel_return_Europe[ten_day_rel_return_Europe<-0.05].index].mean(axis=0).plot()

# %%
ten_day_follow_rel_return_Europe.loc[ten_day_rel_return_Europe[ten_day_rel_return_Europe<-0.1].index].mean(axis=0).plot()

# %%
twenty_day_rel_return_Europe=Europe_ABO_df.apply(lambda x: placing_follow_return(x.name,Europe_dict['price_orig_df'],\
                                                                       Europe_dict['price_df'],Europe_dict['abs_return_df'],\
                                                                      Europe_dict['abs_return_df']['SX5E Index'],20,\
                                                                       x['Offer price'],40)[1],axis=1)

# %%
twenty_day_follow_rel_return_Europe=Europe_ABO_df.apply(lambda x: placing_follow_return(x.name,Europe_dict['price_orig_df'],\
                                                                       Europe_dict['price_df'],Europe_dict['abs_return_df'],\
                                                                      Europe_dict['abs_return_df']['SX5E Index'],20,\
                                                                       x['Offer price'],40)[3],axis=1)

# %%
twenty_day_follow_rel_return_Europe.mean(axis=0).plot()

# %%
twenty_day_follow_rel_return_Europe.loc[twenty_day_rel_return_Europe[twenty_day_rel_return_Europe<-0.05].index].mean(axis=0).plot()

# %%
twenty_day_follow_rel_return_Europe.loc[twenty_day_rel_return_Europe[twenty_day_rel_return_Europe<-0.1].index].mean(axis=0).plot()

# %%
five_day_rel_return_US=US_ABO_df.apply(lambda x: placing_follow_return(x.name,US_dict['price_orig_df'],\
                                                                       US_dict['price_df'],US_dict['abs_return_df'],\
                                                                      US_dict['abs_return_df']['SPX Index'],5,\
                                                                       x['Offer price'],40)[1],axis=1)

# %%
five_day_follow_rel_return_US=US_ABO_df.apply(lambda x: placing_follow_return(x.name,US_dict['price_orig_df'],\
                                                                       US_dict['price_df'],US_dict['abs_return_df'],\
                                                                      US_dict['abs_return_df']['SPX Index'],5,\
                                                                       x['Offer price'],40)[3],axis=1)

# %%
five_day_follow_rel_return_US.mean(axis=0).plot()

# %%
five_day_follow_rel_return_US.loc[five_day_rel_return_US[five_day_rel_return_US<-0.05].index].mean(axis=0).plot()

# %%
five_day_follow_rel_return_US.loc[five_day_rel_return_US[five_day_rel_return_US<-0.1].index].mean(axis=0).plot()

# %%
ten_day_rel_return_US=US_ABO_df.apply(lambda x: placing_follow_return(x.name,US_dict['price_orig_df'],\
                                                                       US_dict['price_df'],US_dict['abs_return_df'],\
                                                                      US_dict['abs_return_df']['SPX Index'],10,\
                                                                       x['Offer price'],40)[1],axis=1)

# %%
ten_day_follow_rel_return_US=US_ABO_df.apply(lambda x: placing_follow_return(x.name,US_dict['price_orig_df'],\
                                                                       US_dict['price_df'],US_dict['abs_return_df'],\
                                                                      US_dict['abs_return_df']['SPX Index'],10,\
                                                                       x['Offer price'],40)[3],axis=1)

# %%
ten_day_follow_rel_return_US.mean(axis=0).plot()

# %%
ten_day_follow_rel_return_US.loc[ten_day_rel_return_US[ten_day_rel_return_US<-0.05].index].mean(axis=0).plot()

# %%
ten_day_follow_rel_return_US.loc[ten_day_rel_return_US[ten_day_rel_return_US<-0.1].index].mean(axis=0).plot()

# %%
twenty_day_rel_return_US=US_ABO_df.apply(lambda x: placing_follow_return(x.name,US_dict['price_orig_df'],\
                                                                       US_dict['price_df'],US_dict['abs_return_df'],\
                                                                      US_dict['abs_return_df']['SPX Index'],20,\
                                                                       x['Offer price'],40)[1],axis=1)

# %%
twenty_day_follow_rel_return_US=US_ABO_df.apply(lambda x: placing_follow_return(x.name,US_dict['price_orig_df'],\
                                                                       US_dict['price_df'],US_dict['abs_return_df'],\
                                                                      US_dict['abs_return_df']['SPX Index'],20,\
                                                                       x['Offer price'],40)[3],axis=1)

# %%
twenty_day_follow_rel_return_US.loc[twenty_day_rel_return_US[twenty_day_rel_return_US<-0.05].index].mean(axis=0).plot()

# %%
twenty_day_follow_rel_return_US.loc[twenty_day_rel_return_US[twenty_day_rel_return_US<-0.1].index].mean(axis=0).plot()

# %%
Europe_BTD=pd.concat([ten_day_abs_return,ten_day_rel_return,twenty_day_follow_abs_return,twenty_day_follow_rel_return],axis=1)

# %%
Europe_BTD.columns=['evaluate_abs','evaluate_rel','follow_abs','follow_rel']

# %%
Europe_BTD[Europe_BTD['evaluate_rel']<-0.1].mean()
# Out:
# evaluate_abs   -0.142652
# evaluate_rel   -0.155117
# follow_abs      0.004969
# follow_rel      0.002163
# dtype: float64

# %% [markdown]
# # Spot check with extra details

# %%
def spot_check(fundamental_df,size_df,adj_signal_df,index_df,capital):
    ''' 
    Crete a dataframe to spot check the backtest
    '''
    new_df=fundamental_df.copy()
    
    new_df['abs_return']=new_df.apply(lambda x:(1+(adj_signal_df[x.name]).dropna()).\
                                                      cumprod().iloc[-1]-1 if len(adj_signal_df[x.name].dropna())>0 \
                                      else None,axis=1)
    
    new_df['rel_return']=new_df.apply(lambda x:(1+(adj_signal_df[x.name]-index_df).dropna()).\
                                                      cumprod().iloc[-1]-1 if len(adj_signal_df[x.name].dropna())>0 \
                                      else None,axis=1)
    
    new_df['holding']=new_df.apply(lambda x:len((adj_signal_df[x.name]).dropna()),axis=1)
    
    new_df['size']=new_df.apply(lambda x:size_df[x.name].dropna().iloc[0]*capital if len(size_df[x.name].dropna())>0 \
                                else None,axis=1)
    
    new_df['abs_pnl']=new_df['abs_return']*new_df['size']
    new_df['rel_pnl']=new_df['rel_return']*new_df['size']
    
    
    return new_df
