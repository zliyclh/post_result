# %% [markdown]
# # Use bloomberg download data to get me started

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline

# %%
#initial cleaning function
def clean_sheet(dataframe):
    adj=dataframe.dropna(axis=1,how='all')
    adj=dataframe.set_index(adj.columns[0]) #use stock tickers as the index
    return adj

# %%
#pull the data from excel, form a dictionary of tab names and dataframes
tabs_to_grab=['Quarter','Date','Revision','Market cap','Property']

data_dict={}

for s in tabs_to_grab:
    df=clean_sheet(pd.read_excel(r'C:\Users\Eric.Li\Documents\Post result data\Europe 2007-2018.xlsx',sheet_name=s))
    data_dict[s]=df.dropna(axis=0,how='all')

# %%
# get the price dataframe for certain years; form the price and return datetime from the data from all the years 
def return_from_excel(path, start_year,end_year):
    
    year_range=range(start_year,end_year+1)

    price_list=[]
    rel_price_list=[]
    abs_return_list=[]
    rel_return_list=[]
    for year in year_range:
        price_year=clean_sheet(pd.read_excel(path,sheet_name=str(year))).dropna(how='all',axis=0)
        rel_price=price_year/price_year.loc["SXXP Index"]
        rel_price=rel_price.dropna(how='all',axis=0)
        abs_return=price_year.diff(1,axis=1)/price_year.shift(1,axis=1)
        abs_return=abs_return.dropna(how='all',axis=0)
        rel_return=abs_return - abs_return.loc["SXXP Index"]
        rel_return=rel_return.dropna(how='all',axis=0)
        price_list.append(price_year)
        rel_price_list.append(rel_price)
        abs_return_list.append(abs_return)
        rel_return_list.append(rel_return)

    price=pd.concat(price_list,axis=1).dropna(axis=1,how='all').dropna(axis=0,how='all')
    rel_price=pd.concat(rel_price_list,axis=1).dropna(axis=1,how='all').dropna(axis=0,how='all')
    abs_return=pd.concat(abs_return_list,axis=1).dropna(axis=1,how='all').dropna(axis=0,how='all')
    rel_return=pd.concat(rel_return_list,axis=1).dropna(axis=1,how='all').dropna(axis=0,how='all')

    # transform the datetime to the common timestamp format
    price_column=[i.strftime("%d/%b/%Y") for i in price.columns.tolist() if type(i)!=str]
    rel_price_column=[i.strftime("%d/%b/%Y") for i in rel_price.columns.tolist() if type(i)!=str]
    abs_return_column=[i.strftime("%d/%b/%Y") for i in abs_return.columns.tolist() if type(i)!=str]
    rel_return_column=[i.strftime("%d/%b/%Y") for i in rel_return.columns.tolist() if type(i)!=str]

    price.columns=price_column
    rel_price.columns=rel_price_column
    abs_return.columns=abs_return_column
    rel_return.columns=rel_return_column
    
    return price, rel_price, abs_return,rel_return 


price,rel_price,abs_return,rel_return=return_from_excel(r'C:\Users\Eric.Li\Documents\Post result data\Europe price.xlsx', 2007,2018)

# %%
# utility function to get volatility from return series
def vol_calc(return_series, vol_lookback):
    hist=len(return_series)
    if hist<=vol_lookback:
        vol=return_series[-hist+1:].std()
    else:
        vol=return_series[-vol_lookback-1:-1].std()
    return vol

# %%
# utility function to obtain announcement return (as a multiplier of vol) as a result of day 0 and return dataframe
def ann_ret(single_date,return_series,EAR_period,vol_lookback):
    if type(single_date)==pd._libs.tslib.Timestamp:
        date_series=return_series.index.tolist()
        if single_date.strftime("%d/%b/%Y") in date_series:
            day0=date_series.index(single_date.strftime("%d/%b/%Y"))
            vol=vol_calc(return_series,vol_lookback)
            if len(return_series.iloc[day0:])<EAR_period:
                ret=return_series[day0:].sum()
                nmove=ret/vol
            else:
                ret=return_series.iloc[day0:day0+EAR_period].sum()
                nmove=ret/vol
            return nmove
        else:
            return None
    else:
        return single_date

# %%
# obtain the announcement return dataframe from price return and date dataframe
def EAR(date_df,return_df,EAR_period,vol_lookback):
    EAR_list=[]
    for ticker, date_row in date_df.iterrows():
        if type(ticker)==str: #deal with 
            return_row=return_df.loc[ticker]
            ret_series=date_row.apply(lambda x: ann_ret(x,return_row,EAR_period,vol_lookback))
            EAR_list.append(ret_series)
        else:
            pass
    EAR_df=pd.concat(EAR_list,axis=1).T
    return EAR_df

# %% [markdown]
# ## Signal 1 - absolute signal

# %%
#signal formation (number 1) and use the date as the base dataframe
def signal1_formation(date_df,return_df,EAR_period,vol_lookback,return_criteria,revision_df, revision_criteria):
    EAR_return=EAR(date_df,return_df,EAR_period,vol_lookback).fillna(0.0).loc[revision_df.index.tolist()]
    signal1_evaluate=(EAR_return>return_criteria) & (revision_df>revision_criteria)
    signal1=date_df[signal1_evaluate]
    signal1_next=date_df.shift(1,axis=1)[signal1_evaluate]
    return signal1,signal1_next

signal1,signal1_next=signal1_formation(data_dict['Date'],rel_return,3,30,2,data_dict['Revision'],0.02)

# %%
#Stack signals into a list of tuples (stocks, dates), convert dates into a common format of datetime
def signal1_stacking(signal1,signal1_next):
    signal1_list=[]
    for ticker, row in signal1.iterrows():
        for idx in range(len(row)):
            date=row.iloc[idx]
            date_next=signal1_next.loc[ticker].iloc[idx]
            if type(date)==pd._libs.tslib.Timestamp:
                ts=(date - np.datetime64('1970-01-01T00:00:00Z')) / np.timedelta64(1, 's') 
                adj_date=datetime.utcfromtimestamp(ts).strftime("%d/%b/%Y") #transform the datetime into a common format
                if type(date_next)==pd._libs.tslib.NaTType:
                    adj_next_date=date_next
                else:
                    ts_next=(date_next - np.datetime64('1970-01-01T00:00:00Z')) / np.timedelta64(1, 's')
                    adj_next_date=datetime.utcfromtimestamp(ts_next).strftime("%d/%b/%Y")                      
                signal1_list.append((row.name,adj_date,adj_next_date))
            else:
                pass
    return signal1_list

# %%
# create a dictionary to have signal information (tuple) as keys and return data time series as values to make it easier to check
#; replace datetime with number of days post announcement to make it more comparable 
def signal1_return_dict(signal1_list,return_df,holding,earning):#if we hold them through next earning
    signal1_dict={}
    for s in signal1_list:
        return_series=return_df.loc[s[0]]
        if s[1] in return_series.index:          
            day0=return_series.index.tolist().index(s[1]) #index of day 0
            if earning is True:
                period=holding
            elif type(s[2])==pd._libs.tslib.NaTType:
                period=holding
            else:
                period=min(holding,np.busday_count(datetime.strptime(s[1],"%d/%b/%Y"),datetime.strptime(s[2],"%d/%b/%Y")))
            target_series=return_series.iloc[day0:day0+min(period, len(return_series[day0:]))]
            target_series.index=range(min(period, len(return_series[day0:]))) #replace datetime with number of days post announcement
            target_series.name=(s[0],s[1])
            signal1_dict[s]=target_series
        else:
            pass          
    return signal1_dict

# %%
# obtain the dataframe of return time series for the signal stocks, take the signal_return_dict function
def signal1_return_df(signal1,signal1_next,return_df,holding,earning):
    return_series_list=[]
    return_dict=signal1_return_dict(signal1_stacking(signal1,signal1_next),return_df,holding,earning)
    for index,key in return_dict.items():
        return_series_list.append(key)
    try:
        signal1_return_df=pd.concat(return_series_list,axis=1)
        if earning is True:
            signal1_return_df=signal1_return_df.dropna(how='any',axis=1) #drop stocks with limited history to make it more comparable
        else:
            signal1_return_df=signal1_return_df.dropna(how='all',axis=1).dropna(how='all',axis=0)
        return signal1_return_df
    except ValueError:
        return None

# %%
## obtain the resulting signal dataframe with return series
signal1_abs_df=signal1_return_df(signal1,signal1_next,abs_return,130,True)
signal1_rel_df=signal1_return_df(signal1,signal1_next,rel_return,130,True)

# List of signals and cumulative returns
signal1_list_abs=signal1_abs_df.iloc[3:].cumsum(axis=0).iloc[-1]
signal1_list_abs

signal1_list_rel=signal1_rel_df.iloc[3:].cumsum(axis=0).iloc[-1]
signal1_list_rel.sort_values()
# Out:
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   if __name__ == '__main__':
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
# UNI IM     15/Mar/2012   -0.825670
# TOM2 NA    24/Oct/2007   -0.780509
# SWEDA SS   17/Jul/2008   -0.737593
# BKT SM     19/Jan/2012   -0.716197
# BOL SS     19/Jul/2007   -0.708439
#            08/May/2008   -0.658539
# YIT FH     25/Apr/2008   -0.652582
# OTE1V FH   23/Apr/2008   -0.589709
# SDF GR     14/Mar/2013   -0.568142
# NRE1V FH   07/May/2008   -0.559881
# SSABB SS   23/Jul/2014   -0.554888
# SUBC NO    31/Jul/2014   -0.553013
# YAR NO     18/Apr/2008   -0.551237
# SSABA SS   23/Jul/2014   -0.546551
# NOKIA FH   20/Oct/2011   -0.545587
# KBC BB     12/May/2011   -0.504590
# BEKB BB    25/Feb/2011   -0.499143
# MTGB SS    22/Jul/2008   -0.483832
# AF FP      18/Feb/2016   -0.483105
# ELUXB SS   17/Jul/2007   -0.476609
# NHY NO     22/Apr/2008   -0.463499
# AAL LN     25/Jul/2014   -0.459695
# UG FP      23/Jul/2008   -0.450731
# NHY NO     11/Feb/2015   -0.450458
# REN NA     19/Feb/2009   -0.444504
# EBS AV     30/Apr/2008   -0.426701
# BOKA NA    21/Aug/2008   -0.422921
# REL LN     19/Feb/2009   -0.415565
# STERV FH   23/Oct/2008   -0.408201
# BKIA SM    28/Oct/2011   -0.404936
#                             ...
# WAF GR     27/Oct/2016    0.566007
# SEBA SS    05/Feb/2009    0.579385
# SOI FP     08/Dec/2016    0.584947
# LEON SW    26/Feb/2015    0.605091
# AKERBP NO  29/Apr/2016    0.622866
# AIXA GR    30/Jul/2009    0.641945
# EVT GR     10/Nov/2016    0.656416
# JD/ LN     15/Apr/2015    0.658396
# HSX LN     18/Aug/2008    0.663387
# FINGB SS   22/Oct/2015    0.680774
# LOGN SW    25/Jul/2013    0.701409
# AF FP      16/Feb/2017    0.701669
# KAZ LN     31/Mar/2009    0.716931
# NDX1 GR    11/Mar/2013    0.780782
# INDV LN    18/Feb/2016    0.784098
# EVT GR     28/Mar/2017    0.790349
# AKERBP NO  16/Aug/2011    0.799413
# AAL LN     16/Feb/2016    0.803953
# INCH LN    19/Mar/2009    0.843786
# PSM GR     14/May/2009    0.859035
# VWS DC     08/May/2013    0.903166
# YAR NO     19/Oct/2007    0.931520
# MBTN SW    03/Apr/2007    0.952940
# DLG GR     28/Jul/2009    0.992797
# AIXA GR    07/May/2009    1.022987
# BOL SS     13/Feb/2009    1.032315
# NAS NO     23/Apr/2009    1.068776
# KAZ LN     18/Aug/2016    1.079519
# GLPG NA    06/Mar/2015    1.099974
# S92 GR     13/May/2015    1.154156
# Name: 129, Length: 2143, dtype: float64

# %%
# Performance analytics
# 1. trading analytics
def trading_analytics(return_df):
    ind_return=return_df.cumsum().ffill().iloc[-1]
    signal1_count=len(ind_return)
    if signal1_count==0:
        return None
    else:
        mean_return=ind_return.mean()
        hit_rate=len(ind_return[ind_return>0])/len(ind_return)*1.0
        payoff_ratio=ind_return[ind_return>0].mean()/ind_return[ind_return<0].mean()*-1.0
        return mean_return,signal1_count, hit_rate,payoff_ratio

# %%
# 2. aggregate abs/rel performance over time
def perf_chart(signal_df,xlabel,ylabel,title,figsize,quantile_list):
    quantile_columns=[str(int(i*100))+' percentile' for i in quantile_list]
    cum_return=signal_df.cumsum().ffill().mean(axis=1)
    perf_df=signal_df.cumsum().ffill().apply(lambda row: row.quantile(quantile_list),axis=1)
    perf_df.columns=quantile_columns
    perf_df["Mean"]=cum_return
    
    ax=perf_df.plot(figsize=figsize)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    
    vals=ax.get_yticks()
    start=vals[0]
    end=vals[-1]
    ax.set_yticks(np.arange(start,end,0.05))  
    adj_vals=ax.get_yticks()
    ax.set_yticklabels(["{:.0%}".format(x) for x in adj_vals])
    
    mean_return,count,hit, payoff=trading_analytics(signal_df)
    
    plt.title('mean_return='+str("{:.1%}".format(mean_return)+
              ',count='+str(count)+
              ',hit rate='+str("{:.0%}".format(hit))+
              ',payoff='+str(round(payoff,2))),fontsize=10)
    
    plt.suptitle(title,fontsize=14)
    plt.legend(fontsize=8)
    plt.grid(linestyle='dashed')
    plt.axhline(y=0,color='k')

    plt.show()

# %%
perf_chart(signal1_return_df(signal1,signal1_next,abs_return,130,True)[3:],"Days post announcement",
           "Return","Abs return of signal 1 - Europe 2007-2018",[7,5],
          [0.1,0.25,0.5,0.75,0.9])
# Out:
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   if __name__ == '__main__':
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future

# %%
perf_chart(signal1_return_df(signal1,signal1_next,rel_return,130,True)[3:],"Days post announcement",
           "Return","Rel return of signal 1 - Europe 2007-2018",[7,5],
          [0.1,0.25,0.5,0.75,0.9])
# Out:
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   if __name__ == '__main__':
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future

# %%
trading_analytics(without_number[3:])
# Out:
# (0.036872587735872014, 2304, 0.6254340277777778, 1.2462715910930444)

# %%
without_number[3:].cumsum().ffill().mean(axis=1).plot()

# %%
# plot the performance for different holding period 
def plot_by_holding(period_list,figsize,fontsize,title,signal1,signal1_next,abs_return,rel_return,earning):    
    fig=plt.figure(figsize=figsize)
    fig.suptitle(title, fontsize=fontsize)
    for idx, val in enumerate(period_list):
        ax1=fig.add_subplot(len(period_list),2,idx*2+1)
        abs_return_df=signal1_return_df(signal1,signal1_next,abs_return,val,earning)
        abs_cum_return=abs_return_df[3:].mean(axis=1).cumsum()
        ax1.plot(abs_cum_return)

        val1=ax1.get_yticks()
        ax1.set_yticklabels(["{:.2%}".format(x) for x in val1])
    
        ax1.set_title("Abs return in "+str(val)+" days")
        mean1,count1,hit1,payoff1=trading_analytics(abs_return_df[3:])
        ax1.legend(['mean_return='+str("{:.1%}".format(mean1))+
                    'count='+str(count1)+
                    ',hit rate='+str("{:.0%}".format(hit1))+
                    ',payoff='+str(round(payoff1,2))])

        ax2=fig.add_subplot(len(period_list),2,idx*2+2)
        rel_return_df=signal1_return_df(signal1_list,signal1_list_next,rel_return,val,earning)
        rel_cum_return=rel_return_df[3:].mean(axis=1).cumsum()
        ax2.plot(rel_cum_return)
        
        val2=ax2.get_yticks()
        ax2.set_yticklabels(["{:.2%}".format(x) for x in val2])
        
        ax2.set_title("Rel return in "+str(val)+" days")
        mean2,count2,hit2,payoff2=trading_analytics(rel_return_df[3:])
        ax2.legend(['mean_return='+str("{:.1%}".format(mean2))+
                    ',count='+str(count2)+
                    ',hit rate='+str("{:.0%}".format(hit2))+
                    ',payoff='+str(round(payoff2,2))],loc='best')
    plt.show()

    
plot_by_holding([30,60],(14,8),18,"Performance of signal 1 for Europe 2007-2018",signal1,signal1_next,abs_return,rel_return,True)
# Out:
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   if __name__ == '__main__':
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future

# %% [markdown]
# ## Signal performance by years

# %%
# plot the performance for different year
def plot_by_year(start_year,end_year,figsize,fontsize,title,signal1,signal1_next,abs_return,rel_return,holding_period,earning):    
    year_range=range(start_year,end_year+1)
    fig=plt.figure(figsize=figsize)
    fig.suptitle(title, fontsize=fontsize)
    for idx, val in enumerate(year_range):
        signal1_year=signal1[signal1.apply(lambda x: (x>=pd.Timestamp(val,1,1))&(x<=pd.Timestamp(val,12,31)))]
        signal1_year_next=signal1_next[signal1_next.apply(lambda x: (x>=pd.Timestamp(val,1,1))&(x<=pd.Timestamp(val,12,31)))]
        
        ax1=fig.add_subplot(len(year_range),2,idx*2+1)
        abs_return_df=signal1_return_df(signal1_year,signal1_year_next,abs_return,holding_period,earning)
        abs_cum_return=abs_return_df[3:].mean(axis=1).cumsum()
        ax1.plot(abs_cum_return)
        ax1.set_title("Abs return in "+str(val))
        count,hit, payoff=trading_analytics(abs_return_df[3:])
        ax1.legend(['count='+str(count)+
                    ',hit rate='+str("{:.0%}".format(hit))+
                    ',payoff='+str(round(payoff,2))])

        ax2=fig.add_subplot(len(year_range),2,idx*2+2)
        rel_return_df=signal1_return_df(signal1_year,signal1_year_next,rel_return,holding_period,earning)
        rel_cum_return=rel_return_df[3:].mean(axis=1).cumsum()
        ax2.plot(rel_cum_return)
        ax2.set_title("Rel return in "+str(val))
        count,hit, payoff=trading_analytics(rel_return_df[3:])
        ax2.legend(['count='+str(count)+
                    ',hit rate='+str("{:.0%}".format(hit))+
                    ',payoff='+str(round(payoff,2))])
    plt.show()

# %%
plot_by_year(2007, 2018,(15,40),18,
             "Performance of signal 1 for Europe 2007-2018",signal1,signal1_next,abs_return,rel_return, 120,True)
# Out:
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   if __name__ == '__main__':
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future

# %% [markdown]
# ## by sector

# %%
## sector mapping and unique sector list, add the sector column to the signal
def sector_mapping(ticker,mapping_df):
    mapping=mapping_df.dropna()
    if ticker in mapping.index:
        sector=mapping[ticker]
    else:
        sector=None
    return sector
    
unique_sector=list(set(data_dict["Property"]["Sector"].dropna().values))
signal1_with_sector=signal1.copy()
signal1_next_with_sector=signal1_next.copy()
signal1_with_sector["sector"]=[sector_mapping(i,data_dict["Property"]["Sector"]) for i in signal1_with_sector.index]
signal1_next_with_sector["sector"]=[sector_mapping(i,data_dict["Property"]["Sector"]) for i in signal1_next_with_sector.index]

# %%
# plot the performance for different sectors
def plot_by_sector(sector_list,figsize,fontsize,title,signal1,signal1_next,abs_return,rel_return,holding_period,earning):    
    fig=plt.figure(figsize=figsize)
    fig.suptitle(title, fontsize=fontsize)
    for idx, sector in enumerate(sector_list):
        signal1_sector=signal1[signal1["sector"]==sector].iloc[:,:-1]
        signal1_next_sector=signal1_next[signal1_next["sector"]==sector].iloc[:,:-1]
        
        ax1=fig.add_subplot(len(sector_list),2,idx*2+1)
        abs_return_df=signal1_return_df(signal1_sector,signal1_next_sector,abs_return,holding_period,earning)
        abs_cum_return=abs_return_df[3:].mean(axis=1).cumsum()
        ax1.plot(abs_cum_return)
        ax1.set_title("Abs return in "+str(sector))
        count,hit, payoff=trading_analytics(abs_return_df[3:])
        ax1.legend(['count='+str(count)+
                    ',hit rate='+str("{:.0%}".format(hit))+
                    ',payoff='+str(round(payoff,2))])

        ax2=fig.add_subplot(len(sector_list),2,idx*2+2)
        rel_return_df=signal1_return_df(signal1_sector,signal1_next_sector,rel_return,holding_period,earning)
        rel_cum_return=rel_return_df[3:].mean(axis=1).cumsum()
        ax2.plot(rel_cum_return)
        ax2.set_title("Rel return in "+str(sector))
        count,hit, payoff=trading_analytics(rel_return_df[3:])
        ax2.legend(['count='+str(count)+
                    ',hit rate='+str("{:.0%}".format(hit))+
                    ',payoff='+str(round(payoff,2))])
    
    plt.show()

# %%
plot_by_sector(unique_sector,(15,60),18,
             "Performance of signal 1 for Europe 2007-2018",signal1_with_sector,signal1_next_with_sector,abs_return,rel_return, 120,True)
# Out:
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   if __name__ == '__main__':
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future

# %% [markdown]
# ## Signal performance by country

# %%
## unique country list, add the country column to the signal
signal1_with_country=signal1.copy()
signal1_with_country["country"]=[i[-2:] for i in signal1_with_country.index]
signal1_next_with_country=signal1_next.copy()
signal1_next_with_country["country"]=[i[-2:] for i in signal1_next_with_country.index]

unique_country=list(set(signal1_with_country["country"]))

# %%
# plot the performance by countries
def plot_by_country(country_list,figsize,fontsize,title,signal1,signal1_next,abs_return,rel_return,holding_period,earning):    
    fig=plt.figure(figsize=figsize)
    fig.suptitle(title, fontsize=fontsize)
    for idx, country in enumerate(country_list):
        signal1_country=signal1[signal1["country"]==country].iloc[:,:-1]
        signal1_next_country=signal1_next[signal1_next["country"]==country].iloc[:,:-1]
        
        ax1=fig.add_subplot(len(country_list),2,idx*2+1)
        #print(signal1_country,signal1_next_country)
        abs_return_df=signal1_return_df(signal1_country,signal1_next_country,abs_return,holding_period,earning)
        if abs_return_df is not None:
            abs_cum_return=abs_return_df[3:].mean(axis=1).cumsum()
            ax1.plot(abs_cum_return)
            ax1.set_title("Abs return in "+str(country))
            count,hit, payoff=trading_analytics(abs_return_df[3:])
            ax1.legend(['count='+str(count)+
                        ',hit rate='+str("{:.0%}".format(hit))+
                        ',payoff='+str(round(payoff,2))])
        else:
            pass
        
        ax2=fig.add_subplot(len(country_list),2,idx*2+2)
        rel_return_df=signal1_return_df(signal1_country,signal1_next_country,rel_return,holding_period,earning)
        if rel_return_df is not None:  
            rel_cum_return=rel_return_df[3:].mean(axis=1).cumsum()
            ax2.plot(rel_cum_return)
            ax2.set_title("Rel return in "+str(country))
            count,hit, payoff=trading_analytics(rel_return_df[3:])
            ax2.legend(['count='+str(count)+
                        ',hit rate='+str("{:.0%}".format(hit))+
                        ',payoff='+str(round(payoff,2))])
        else:
            pass
    plt.show()

# %%
plot_by_country(unique_country,(15,50),18,
             "Performance of signal 1 for Europe 2007-2018",signal1_with_country,signal1_next_with_country,abs_return,rel_return, 120,True)
# Out:
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   if __name__ == '__main__':
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future

# %% [markdown]
# ## Avoid holding through numbers

# %%
# Hold through numbers
perf_chart(signal1,signal1_next,rel_return,130,True,"Days post announcement",
           "Return","Rel return of signal 1 through numbers - Europe 2007-2018",[7,5],
          [0.1,0.25,0.5,0.75,0.9])
# Out:
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   if __name__ == '__main__':
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future

# %%
# Not through numbers
perf_chart(signal1,signal1_next,rel_return,130,False,"Days post announcement",
           "Return","Rel return of signal 1 without next numbers - Europe 2007-2018",[7,5],
          [0.1,0.25,0.5,0.75,0.9])
# Out:
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   if __name__ == '__main__':
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future

# %% [markdown]
# ## Impact of size on the profit

# %%
## grab market cap data
market_cap=data_dict["Market cap"]

## function to grab market cap
def get_market_cap(signal_tuple,market_cap_df,date_df):
    ticker=signal_tuple[0]
    date_series=date_df.loc[ticker]
    cap_series=market_cap_df.loc[ticker]
    timestamp=pd.Timestamp(datetime.strptime(signal_tuple[1],"%d/%b/%Y").year,
                           datetime.strptime(signal_tuple[1],"%d/%b/%Y").month,
                           datetime.strptime(signal_tuple[1],"%d/%b/%Y").day)
    location=date_series.tolist().index(timestamp)
    return cap_series.iloc[location]

# %%
# add market cap data to signal dataframe and separate 
size_row=signal1_rel_return_df.apply(lambda column: get_market_cap(column.name,market_cap,data_dict["Date"]),axis=0)

signal_abs_size_df=signal1_abs_return_df.copy()
signal_size_df=signal1_rel_return_df.copy()
 
small_cap_abs=signal_abs_size_df.loc[:,size_row<3300]
mid_cap_abs=signal_abs_size_df.loc[:,(size_row>3300)&(size_row<9000)]
large_cap_abs=signal_abs_size_df.loc[:,size_row>9000]

small_cap=signal_size_df.loc[:,size_row<3300]
mid_cap=signal_size_df.loc[:,(size_row>3300)&(size_row<9000)]
large_cap=signal_size_df.loc[:,size_row>9000]

# %%
perf_chart(large_cap[3:],"Days post announcement",
           "Return","Rel return of large cap - Europe 2007-2018",[6,4],
          [0.1,0.25,0.5,0.75,0.9])

# %%
perf_chart(mid_cap[3:],"Days post announcement",
           "Return","Rel return of mid cap - Europe 2007-2018",[6,4],
          [0.1,0.25,0.5,0.75,0.9])

# %%
perf_chart(small_cap[3:],"Days post announcement",
           "Return","Rel return of small cap - Europe 2007-2018",[6,4],
          [0.1,0.25,0.5,0.75,0.9])

# %%
# large cap distribution
plt.figure(figsize=(6,4))
plt.hist(np.array(large_cap[3:].cumsum().iloc[-1]),bins=np.arange(-1,1,0.05),color='k',density=False)
plt.title("Large cap signals return distribution")
plt.xlabel("Rel return")
plt.ylabel("Count")
plt.grid(True)

# %%
# mid cap distribution
plt.figure(figsize=(6,4))
plt.hist(np.array(mid_cap[3:].cumsum().iloc[-1]),bins=np.arange(-1,1,0.05),color='k',density=False)
plt.title("Mid cap signals return distribution")
plt.xlabel("Rel return")
plt.ylabel("Count")
plt.grid(True)

# %%
# smal cap distribution
plt.figure(figsize=(6,4))
plt.hist(np.array(small_cap[3:].cumsum().iloc[-1]),bins=np.arange(-1,1,0.05),color='k',density=False)
plt.title("Small cap signals return distribution")
plt.xlabel("Rel return")
plt.ylabel("Count")
plt.grid(True)

# %%
def plot_by_year(start_year,end_year,figsize,fontsize,title,signal1_abs_df,signal1_rel_df):    
    year_range=range(start_year,end_year+1)
    fig=plt.figure(figsize=figsize)
    fig.suptitle(title, fontsize=fontsize)
    for idx, val in enumerate(year_range):
        ax1=fig.add_subplot(len(year_range),2,idx*2+1)
        signal1_abs_year=signal1_abs_df.loc[:,signal1_abs_df.apply(lambda x: 
                                                                       (pd.Timestamp(datetime.strptime(x.name[1],"%d/%b/%Y"))>=pd.Timestamp(val,1,1))
                                                                       &(pd.Timestamp(datetime.strptime(x.name[1],"%d/%b/%Y"))<=pd.Timestamp(val,12,31)))]
        signal1_abs_cum=signal1_abs_year.cumsum().ffill().mean(axis=1)
        ax1.plot(signal1_abs_cum)
        ax1.set_title("Abs return in "+str(val))
        mean_return,count,hit,payoff=trading_analytics(signal1_abs_year)
        ax1.legend(['mean_return='+str("{:.1%}".format(mean_return))+
                    ',count='+str(count)+
                    ',hit rate='+str("{:.0%}".format(hit))+
                    ',payoff='+str(round(payoff,2))])

        ax2=fig.add_subplot(len(year_range),2,idx*2+2)
        signal1_rel_year=signal1_rel_df.loc[:,signal1_rel_df.apply(lambda x: 
                                                                       (pd.Timestamp(datetime.strptime(x.name[1],"%d/%b/%Y"))>=pd.Timestamp(val,1,1))
                                                                       &(pd.Timestamp(datetime.strptime(x.name[1],"%d/%b/%Y"))<=pd.Timestamp(val,12,31)))]
        signal1_rel_cum=signal1_rel_year.cumsum().ffill().mean(axis=1)
        ax2.plot(signal1_rel_cum)
        ax2.set_title("Rel return in "+str(val))
        mean_return,count,hit,payoff=trading_analytics(signal1_rel_year)
        ax2.legend(['mean_return='+str("{:.1%}".format(mean_return))+
                    ',count='+str(count)+
                    ',hit rate='+str("{:.0%}".format(hit))+
                    ',payoff='+str(round(payoff,2))])

    plt.show()

# %%
plot_by_year(2007,2018,(10,20),18,
             "Performance of signal 1 for Europe 2007-2018",small_cap_abs,small_cap)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1238-4f9492a3f513> in <module>()
#       1 plot_by_year(2007,2018,(10,20),18,
# ----> 2              "Performance of signal 1 for Europe 2007-2018",small_cap_abs,small_cap)
#
# <ipython-input-1236-9e685d899485> in plot_by_year(start_year, end_year, figsize, fontsize, title, signal1_abs_df, signal1_rel_df)
#      11         ax1.plot(signal1_abs_cum)
#      12         ax1.set_title("Abs return in "+str(val))
# ---> 13         mean_return,count,hit,payoff=trading_analytics(signal1_abs_year)
#      14         ax1.legend(['mean_return='+str("{:.1%}".format(mean_return))+
#      15                     ',count='+str(count)+
#
# <ipython-input-938-715da2e28948> in trading_analytics(return_df)
#       5     mean_return=ind_return.mean()
#       6     signal1_count=len(ind_return)
# ----> 7     hit_rate=len(ind_return[ind_return>0])/len(ind_return)*1.0
#       8     payoff_ratio=ind_return[ind_return>0].mean()/ind_return[ind_return<0].mean()*-1.0
#       9     return mean_return,signal1_count, hit_rate,payoff_ratio
#
# ZeroDivisionError: division by zero

# %%
large_cap.loc[:,large_cap.apply(lambda column: pd.Timestamp(datetime.strptime(column.name[1],"%d/%b/%Y"))>pd.Timestamp(2017,1,1))]
# Out:
#          BNP FP                  REP SM      SIK SW      NHY NO      STM IM  \
#     28/Jul/2017 03/May/2017 27/Jul/2017 24/Feb/2017 09/Feb/2017 26/Jan/2017
# 0      0.011925    0.006188    0.008240    0.035115   -0.015990    0.078913
# 1     -0.006723   -0.003377    0.013247    0.015597    0.017137    0.039441
# 2      0.012228    0.016220    0.002710   -0.007226    0.028774    0.006463
# 3      0.000843   -0.014054    0.008452   -0.023562   -0.009979   -0.017336
# 4      0.009124   -0.007185    0.005678   -0.000679   -0.017757    0.025930
# 5      0.003888    0.000183    0.000598   -0.000774    0.005735    0.053442
# 6      0.007672   -0.000344    0.000215    0.006118   -0.006453   -0.001322
# 7      0.003285   -0.000885    0.002047    0.010722   -0.000571   -0.002997
# 8     -0.016172    0.006803    0.001072    0.009806    0.006157    0.012805
# 9      0.001356    0.002239   -0.004300   -0.002586   -0.010891   -0.027990
# 10    -0.004597   -0.019197    0.002008    0.010512   -0.005753   -0.022402
# 11     0.004421   -0.006534   -0.008464    0.011861   -0.032631   -0.010196
# 12     0.006594    0.014393   -0.001190   -0.001127    0.004765    0.008241
# 13    -0.006135   -0.002253   -0.004783    0.001622    0.015411    0.002902
# 14    -0.009611    0.008749    0.002324   -0.002742    0.017511    0.008126
# 15     0.003912    0.009080   -0.002913   -0.002412    0.007152    0.021205
# 16    -0.015896   -0.003603    0.001777    0.006798   -0.011352   -0.004815
signal_return.apply(lambda row: row.quantile([0.1,0.35,0.5,0.75,0.9]),axis=1).plot()

# %%
## try to get the vol from the signal_df
def signal_vol(signal_column,return_df,vol_lookback):
    signal_tuple=signal_column.name
    signal_series=abs_return.loc[signal_tuple[0]]
    location=signal_series.index.tolist().index(signal_tuple[1])
    vol_range=min(vol_lookback,len(signal_series[:location]))
    signal_vol=signal_series[location-vol_range-1:location].std()
    return signal_vol

# %%
## obtain the signal cumsum nmove from return
vol_series=signal_return.apply(lambda column:signal_vol(column,abs_return,30),axis=0)
signal_nmove=signal_return/vol_series
signal_nmove.apply(lambda row: row.quantile([0.1,0.3,0.5,0.75,0.9]),axis=1).plot()

# %%
def stop_loss(signal_df,stop_loss):
    return signal_df[-(signal_df.expanding().min().shift(1,axis=0)<stop_loss)].ffill()

signal_with_stop=stop_loss(signal_nmove,-3)
signal_with_stop.apply(lambda row: row.quantile([0.1,0.3,0.5,0.75,0.9]),axis=1).plot()

# %%
plt.figure()
plt.plot(signal_nmove.mean(axis=1))
plt.show()

# %%
trading_analytics(signal_nmove)
# Out:
# (2142, 0.5957049486461251, 1.1820453705434735)

# %%
trading_analytics(signal_with_stop)
# Out:
# (2142, 0.4495798319327731, 2.0492294417014176)

# %%
plt.figure()
plt.plot(signal_with_stop.mean(axis=1))
plt.show()

# %% [markdown]
# ## add relative high

# %%
# abs high and rel high evaluation and filtering functions
def evalaute_high(ticker,timestamp,high_df):
    if type(timestamp)==pd._libs.tslib.NaTType:
        return False
    else:
        adj_timestamp=timestamp.strftime("%d/%b/%Y")
        row_series=high_df.loc[ticker]
        location=row_series.index.tolist().index(adj_timestamp)
        if row_series.iloc[location] or row_series.iloc[location+1]:
            return True
        else:
            return False

def signal_filter_high(signal1,signal1_next,price_df,rolling_window):
    abs_high_evaluation=signal1.copy()
    rel_high_evaluation=signal1.copy()
    abs_high_df=price_df.rolling(window=rolling_window,axis=1).max()==price_df
    rel_price=price_df-price_df.loc["SXXP Index"]
    rel_high_df=rel_price.rolling(window=rolling_window,axis=1).max()==rel_price
    for ticker1, row1 in abs_high_evaluation.iterrows():
        abs_high_evaluation.loc[ticker1]=row1.apply(lambda x: evalaute_high(row1.name,x,abs_high_df))
    for ticker2, row2 in rel_high_evaluation.iterrows():
        rel_high_evaluation.loc[ticker2]=row2.apply(lambda x: evalaute_high(row2.name,x,rel_high_df))
    abs_high_signal=signal1[abs_high_evaluation==True]
    abs_high_signal_next=signal1_next[abs_high_evaluation==True]
    rel_high_signal=signal1[rel_high_evaluation==True]
    rel_high_signal_next=signal1_next[rel_high_evaluation==True]
    
    return abs_high_signal,abs_high_signal_next,rel_high_signal,rel_high_signal_next

# %%
signal1_abs_high,signal1_next_abs_high,signal1_rel_high,signal1_next_rel_high=signal_filter_high(signal1,signal1_next,price,120)

# %%
signal1_abs_high_abs_return_df=signal1_return_df(signal1_abs_high,signal1_next_abs_high,abs_return,130,True)
signal1_abs_high_rel_return_df=signal1_return_df(signal1_abs_high,signal1_next_abs_high,rel_return,130,True)
signal1_rel_high_abs_return_df=signal1_return_df(signal1_rel_high,signal1_next_rel_high,abs_return,130,True)
signal1_rel_high_rel_return_df=signal1_return_df(signal1_rel_high,signal1_next_rel_high,rel_return,130,True)
# Out:
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   if __name__ == '__main__':
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future

# %%
signal1_rel_high_rel_return_df[3:].cumsum().iloc[-1]
# Out:
# BOKA NA   20/Aug/2015   -0.166859
# GKN LN    28/Feb/2017   -0.145360
# FLS DC    09/Feb/2017    0.050009
#           18/Nov/2010   -0.167510
#           17/Nov/2009    0.219689
#           20/Aug/2009    0.219561
#           22/Aug/2007    0.153318
# HAS LN    31/Aug/2017    0.038814
# PNN LN    24/May/2017   -0.177313
#           28/Nov/2014   -0.197245
# SIK SW    24/Feb/2017    0.170763
#           29/Jul/2016    0.045035
#           31/Jul/2009    0.139637
# DNO NO    11/Feb/2016    0.245651
# FI/N SW   19/Jul/2017    0.217834
#           25/Feb/2014   -0.108202
#           17/Jul/2013    0.201285
#           26/Feb/2013    0.170438
#           28/Feb/2012   -0.172043
# ALFA SS   31/Jan/2017    0.039330
#           23/Oct/2007   -0.053020
# CFR SW    16/May/2012    0.059516
#           16/Nov/2007   -0.004735
# ABF LN    20/Apr/2010    0.021493
# UDG LN    23/May/2017    0.067457
# SAABB SS  26/Apr/2017   -0.014586
# VIFN SW   11/Aug/2015    0.204268
# ISAT LN   03/Aug/2012    0.114432
# BATS LN   28/Feb/2013   -0.121502
# CAST SS   23/Jan/2008    0.027816
#                            ...
# DGE LN    27/Jul/2017   -0.014697
# BIM FP    30/Aug/2017   -0.069989
# BALDB SS  21/Aug/2015    0.370842
# BDEV LN   27/Feb/2014   -0.178329
#           22/Feb/2012    0.095432
# BKG LN    04/Dec/2015   -0.015247
#           06/Dec/2013   -0.150804
# SPX LN    09/Aug/2017   -0.025019
#           09/Aug/2016   -0.030407
# AKE FP    05/May/2011   -0.297526
# SGE LN    03/Dec/2014    0.110930
# KGX GR    26/Jul/2017    0.005405
# SRCG SW   24/Aug/2017    0.106801
# SSPG LN   18/May/2017    0.246846
# DLG LN    01/Aug/2017   -0.119855
#           01/Aug/2014   -0.071793
# LEON SW   20/Jul/2017    0.107374
# CCH LN    10/Aug/2017   -0.128271
#           16/Feb/2017    0.254400
# FNAC FP   25/Jul/2017    0.093198
# PLUS LN   07/Aug/2017    0.319657
# BOO LN    27/Sep/2016    0.386411
# JE/ LN    28/Jul/2016   -0.050260
# WIZZ LN   25/May/2017    0.375837
# FEVR LN   25/Jul/2017    0.154318
# INDV LN   02/Nov/2016   -0.221325
#           29/Jul/2016   -0.046672
# EVO SS    20/Jul/2017    0.193340
# MRO LN    02/Mar/2017    0.001134
# ABI BB    05/Mar/2009    0.045123
# Name: 129, Length: 334, dtype: float64

# %%
signal1_rel_high_rel_return_df[3:].cumsum().mean(axis=1).plot()

# %%
signal1_rel_return_df[3:].cumsum().mean(axis=1).plot()
