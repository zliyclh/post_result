# %% [markdown]
# # Use bloomberg download data to get me started

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#initial cleaning function
def clean_sheet(dataframe):
    adj=dataframe.dropna(axis=1,how='all')
    adj=dataframe.set_index(adj.columns[0]) #use stock tickers as the index
    return adj

# %%
#pull the data from excel, form a dictionary of tab names and dataframes
tabs_to_grab=['Quarter','Date','Revision','Property']

data_dict={}

for s in tabs_to_grab:
    df=clean_sheet(pd.read_excel(r'C:\Users\Eric.Li\Documents\Post result data\Europe 2007-2018.xlsx',sheet_name=s))
    data_dict[s]=df.dropna(axis=0,how='all')

# %%
for i in range(2016,2017):
    print(i)
# Out:
# 2016

# %%
# get the price dataframe for certain years; form the price and return datetime from the data from all the years 
def return_from_excel(path, start_year,end_year)
    year_range=range(start_year,end_year+1)

    price_list=[]
    abs_return_list=[]
    rel_return_list=[]
    for year in year_range:
        price_year=clean_sheet(pd.read_excel(path,sheet_name=str(year))).dropna(how='all',axis=0)
        abs_return=price_year.diff(1,axis=1)/price_year.shift(1,axis=1)
        abs_return=abs_return.dropna(how='all',axis=0)
        rel_return=abs_return - abs_return.loc["SXXP Index"]
        rel_return=rel_return.dropna(how='all',axis=0)
        price_list.append(price_year)
        abs_return_list.append(abs_return)
        rel_return_list.append(rel_return)

    price=pd.concat(price_list,axis=1).dropna(axis=1,how='all').dropna(axis=0,how='all')
    abs_return=pd.concat(abs_return_list,axis=1).dropna(axis=1,how='all').dropna(axis=0,how='all')
    rel_return=pd.concat(rel_return_list,axis=1).dropna(axis=1,how='all').dropna(axis=0,how='all')

    # transform the datetime to the common timestamp format
    price_column=[i.strftime("%d/%b/%Y") for i in price.columns.tolist() if type(i)!=str]
    abs_return_column=[i.strftime("%d/%b/%Y") for i in abs_return.columns.tolist() if type(i)!=str]
    rel_return_column=[i.strftime("%d/%b/%Y") for i in rel_return.columns.tolist() if type(i)!=str]

    price.columns=price_column
    abs_return.columns=abs_return_column
    rel_return.columns=rel_return_column
    
    return price, abs_return,rel_return 


r'C:\Users\Eric.Li\Documents\Post result data\Europe price.xlsx'

# %%
# utility function to get volatility from return series
def vol_calc(return_series, vol_lookback):
    hist=len(return_series)
    if hist<=vol_lookback:
        vol=return_series[-hist+1:].std()
    else:
        vol=return_series[-period-1:-1].std()
    return vol

# %%
# utility function to obtain announcement return (as a multiplier of vol) as a result of day 0 and return dataframe
def ann_ret(single_date,return_series,EAR_period,vol_lookback):
    if type(single_date)==pd._libs.tslib.Timestamp:
        date_series=return_series.index.tolist()
        if single_date.strftime("%d/%b/%Y") in date_series:
            day0=date_series.index(single_date.strftime("%d/%b/%Y"))
            vol=vol_calc(return_series,vol_lookback)
            if len(return_series.iloc[day0:])<EAR_period:
                ret=return_series[day0:].sum()
                nmove=ret/vol
            else:
                ret=return_series.iloc[day0:day0+EAR_period].sum()
                nmove=ret/vol
            return nmove
        else:
            return None
    else:
        return single_date

# %%
# obtain the announcement return dataframe from price return and date dataframe
def EAR(date_df,return_df,EAR_period,vol_lookback):
    EAR_list=[]
    for ticker, date_row in date_df.iterrows():
        if type(ticker)==str: #deal with 
            return_row=return_df.loc[ticker]
            ret_series=date_row.apply(lambda x: ann_ret(x,return_row,EAR_period,vol_lookback))
            EAR_list.append(ret_series)
        else:
            pass
    EAR_df=pd.concat(EAR_list,axis=1).T
    return EAR_df

# %% [markdown]
# ## Signal 1 - absolute signal

# %%
#signal formation (number 1) and use the date as the base dataframe
def signal1_formation(date_df,return_df,EAR_period,vol_lookback,return_criteria,revision_df, revision_criteria):
    EAR_return=EAR(date_df,return_df,EAR_period,vol_lookback).fillna(0.0).loc[revision_df.index.tolist()]
    signal1_evaluate=(EAR_return>return_criteria) & (revision_df>revision_criteria)
    signal1=date_df[signal1_evaluate].dropna(axis=0,how='all').dropna(axis=1,how='all')
    return signal1

rel_signal1=signal1_formation(data_dict['Date'],abs_return,3,30,2,data_dict['Revision'],0.02)

# %%
#Stack signals into a list of tuples (stocks, dates), convert dates into a common format of datetime
def signal1_stacking(signal1):
    signal1_list=[]
    for index, row in signal1.iterrows():
        adj_row=row.dropna()
        for s in adj_row.values:
            ts=(s - np.datetime64('1970-01-01T00:00:00Z')) / np.timedelta64(1, 's') 
            adj_time=datetime.utcfromtimestamp(ts).strftime("%d/%b/%Y") #transform the datetime into a common format
            signal1_list.append((adj_row.name,adj_time))
    return signal1_list

# %%
# create a dictionary to have signal information (tuple) as keys and return data time series as values to make it easier to check
#; replace datetime with number of days post announcement to make it more comparable 
def signal1_return_dict(signal1_list,return_dataframe,holding):
    signal1_dict={}
    for s in signal1_list:
        return_series=return_dataframe.loc[s[0]]
        if s[1] in return_series.index:          
            day0=return_series.index.tolist().index(s[1]) #index of day 0
        else:
            pass
        target_series=return_series.iloc[day0:day0+min(holding, len(return_series[day0:]))]
        target_series.index=range(min(holding, len(return_series[day0:]))) #replace datetime with number of days post announcement
        target_series.name=s
        signal1_dict[s]=target_series
    return signal1_dict

# %%
# obtain the dataframe of return time series for the signal stocks, take the signal_return_dict function
def signal1_return_df(signal1,return_df,holding):
    return_series_list=[]
    return_dict=signal1_return_dict(signal1_stacking(signal1),return_df,holding)
    for index,key in return_dict.items():
        return_series_list.append(key)
    signal1_return_df=pd.concat(return_series_list,axis=1)
    signal1_return_df=signal1_return_df.dropna(how='any',axis=1) #drop stocks with limited history to make it more comparable
    return signal1_return_df

rel_signal1_abs_return_df=signal1_return_df(rel_signal1,abs_return,130)
rel_signal1_rel_return_df=signal1_return_df(rel_signal1,rel_return,130)
# Out:
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   import sys

# %%
rel_signal1_rel_return_df.iloc[:,5]
# Out:
# 0        0.0282879
# 1      -0.00369875
# 2       0.00525387
# 3      -0.00144441
# 4        0.0118012
# 5       0.00197279
# 6      -0.00360623
# 7       0.00213249
# 8      -0.00169101
# 9       0.00345846
# 10     -0.00803716
# 11       0.0140402
# 12      0.00147469
# 13       0.0108306
# 14        0.001637
# 15     -0.00617879
# 16      0.00421974
# 17      0.00799486
# 18      0.00988533
# 19      -0.0077684
# 20     -0.00101963
# 21     -0.00535903
# 22     -0.00221211
# 23      0.00219542
# 24     -0.00108693
# 25     -0.00384062
# 26     -0.00463084
# 27      0.00745692
# 28      0.00291471
# 29      -0.0030567
#           ...
# 100     0.00836836
# 101    1.44271e-05
# 102     0.00287564
# 103     -0.0075113
# 104    -0.00733336
# 105              0
# 106     -0.0127491
# 107   -0.000106148
# 108    -0.00424854
# 109    -0.00170535
# 110     0.00567544
# 111   -0.000953037
# 112    -0.00660443
# 113     0.00014482
# 114      -0.013252
# 115     0.00119776
# 116      0.0130281
# 117    -0.00594695
# 118     -0.0209073
# 119    -0.00819114
# 120     -0.0194998
# 121     -0.0164375
# 122     0.00174138
# 123    -0.00669582
# 124    -0.00543621
# 125     -0.0225071
# 126      0.0114373
# 127   -0.000455072
# 128     -0.0124687
# 129    -0.00316257
# Name: (BNP FP, 31/Jul/2015), Length: 130, dtype: object

# %%
# List of signals and cumulative returns
rel_signal1_ind_abs_return=rel_signal1_abs_return_df.iloc[3:].cumsum(axis=0).iloc[-1]
rel_signal1_ind_abs_return

rel_signal1_ind_rel_return=rel_signal1_rel_return_df.iloc[3:].cumsum(axis=0).iloc[-1]
rel_signal1_ind_rel_return.sort_values()
# Out:
# SWEDA SS   17/Jul/2008    -0.76948
# TOM2 NA    24/Oct/2007   -0.723195
# BKT SM     19/Jan/2012   -0.716197
# BOL SS     19/Jul/2007     -0.7062
#            08/May/2008   -0.658539
# MHG NO     09/Feb/2011   -0.654099
# YIT FH     25/Apr/2008   -0.652582
# NOKIA FH   20/Oct/2011   -0.596503
# SSABB SS   23/Jul/2014   -0.593165
# OTE1V FH   23/Apr/2008   -0.589709
# SSABA SS   23/Jul/2014    -0.58081
# NRE1V FH   07/May/2008   -0.559881
# YAR NO     18/Apr/2008   -0.551237
# KCO GR     01/Apr/2008   -0.526482
# UG FP      23/Jul/2008   -0.513388
# KBC BB     12/May/2011    -0.50459
# AF FP      18/Feb/2016   -0.483105
# ELUXB SS   17/Jul/2007   -0.480958
# DBK GR     30/Jul/2015   -0.475466
# NHY NO     22/Apr/2008   -0.463499
# MTGB SS    22/Jul/2008   -0.458993
# SCYR SM    30/Jul/2009   -0.452369
# NHY NO     11/Feb/2015   -0.450458
# CLN SW     06/May/2011   -0.444035
# IFX GR     30/Apr/2008   -0.432385
# EBS AV     30/Apr/2008   -0.426701
# MTGB SS    22/Apr/2008   -0.420582
# BOKA NA    21/Aug/2008   -0.405629
# SSABA SS   27/Apr/2012   -0.399731
# A2A IM     10/May/2012   -0.398876
#                             ...
# STM IM     27/Jul/2016    0.575166
# SEBA SS    05/Feb/2009    0.579385
# RMS FP     28/Apr/2011    0.584484
# LEON SW    26/Feb/2015    0.605091
# WAF GR     27/Oct/2016    0.606934
# AIXA GR    30/Jul/2009    0.615861
# EVT GR     10/Nov/2016     0.64782
# SOI FP     08/Dec/2016    0.649356
# JD/ LN     15/Apr/2015    0.658396
# FINGB SS   22/Oct/2015    0.680774
# HSX LN     18/Aug/2008    0.689046
# LOGN SW    25/Jul/2013    0.690261
# AF FP      16/Feb/2017    0.701669
# KAZ LN     31/Mar/2009    0.716931
# NDX1 GR    11/Mar/2013    0.780782
# INDV LN    18/Feb/2016    0.784098
# EVT GR     28/Mar/2017    0.790349
# AAL LN     16/Feb/2016    0.803953
# AKERBP NO  16/Aug/2011    0.820777
# INCH LN    19/Mar/2009    0.843786
# PSM GR     14/May/2009    0.859035
# VWS DC     08/May/2013    0.903166
# YAR NO     19/Oct/2007    0.936916
# MBTN SW    03/Apr/2007     0.95294
# DLG GR     28/Jul/2009    0.953789
# AIXA GR    07/May/2009     1.02299
# BOL SS     13/Feb/2009     1.03232
# KAZ LN     18/Aug/2016     1.05905
# NAS NO     23/Apr/2009     1.06878
# S92 GR     13/May/2015     1.15416
# Name: 129, Length: 1877, dtype: object

# %%
# Performance analytics
# 1. aggregate abs/rel performance over time
def perf_chart(return_df,xlabel,ylabel,title):
    cum_return=return_df.mean(axis=1).cumsum()
    plt.plot(cum_return)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()
    
perf_chart(abs_signal1_abs_return_df.iloc[3:], xlabel="Days post announcement",
           ylabel="Average accumulated absolute return",title="Absolute performance of signal 1 - Europe 2007-2018")

# %%
perf_chart(abs_signal1_rel_return_df.iloc[3:], xlabel="Days post announcement",
           ylabel="Average accumulated rel return",title="Rel performance of signal 1 - Europe 2007-2018")

# %%
# 2. trading analytics
def trading_analytics(return_df):
    ind_return=return_df.cumsum(axis=0).iloc[-1]
    signal1_count=len(ind_return)
    hit_rate=len(ind_return[ind_return>0])/len(ind_return)*1.0
    payoff_ratio=ind_return[ind_return>0].mean()/ind_return[ind_return<0].mean()*-1.0
    #annualised_return=return_df.mean(axis=1).cumsum().iloc[-1]*260/(len(return_df))
    #annualised_vol=return_df.mean(axis=1).std()*((260/(len(return_df)))**0.5)
    #annualised_sharpe=annualised_return/annualised_vol*1.0
    return signal1_count, hit_rate,payoff_ratio
    
trading_analytics(abs_signal1_rel_return_df[3:])
# Out:
# (554, 0.6498194945848376, 1.3600545261759656)

# %%
# plot the performance for different holding period 
def plot_by_holding(period_list,figsize,fontsize,title,signal1_list,abs_return,rel_return):    
    fig=plt.figure(figsize=figsize)
    fig.suptitle("Performance of signal 1 for Europe 2016-2018", fontsize=fontsize)
    for idx, val in enumerate(period_list):
        ax1=fig.add_subplot(len(period_list),2,idx*2+1)
        abs_return_df=signal1_return_df(signal1_list,abs_return,val)
        abs_cum_return=abs_return_df[3:].mean(axis=1).cumsum()
        ax1.plot(abs_cum_return)
        ax1.set_title("Abs return in "+str(val)+" days")
        count,hit, payoff=trading_analytics(abs_return_df[3:])
        ax1.legend(['count='+str(count)+
                    ',hit rate='+str("{:.0%}".format(hit))+
                    ',payoff='+str(round(payoff,2))])

        ax2=fig.add_subplot(len(period_list),2,idx*2+2)
        rel_return_df=signal1_return_df(signal1_list,rel_return,val)
        rel_cum_return=rel_return_df[3:].mean(axis=1).cumsum()
        ax2.plot(rel_cum_return)
        ax2.set_title("Rel return in "+str(val)+" days")
        count,hit, payoff=trading_analytics(rel_return_df[3:])
        ax2.legend(['count='+str(count)+
                    ',hit rate='+str("{:.0%}".format(hit))+
                    ',payoff='+str(round(payoff,2))])
    plt.show()

    
plot_by_holding([30,60,120,260,320,520,720],(15,20),18,"Performance of signal 1 for Europe 2007-2018",rel_signal1,abs_return,rel_return)
# Out:
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   import sys

# %% [markdown]
# ## Signal performance by years

# %%
##Separate the signals

# %%
# plot the performance for different year
def plot_by_year(period_list,figsize,fontsize,title,signal1_list,abs_return,rel_return):    

    fig=plt.figure(figsize=figsize)
    fig.suptitle("Performance of signal 1 for Europe 2016-2018", fontsize=fontsize)
    for idx, val in enumerate(period_list):
        ax1=fig.add_subplot(len(period_list),2,idx*2+1)
        abs_return_df=signal1_return_df(signal1_list,abs_return,val)
        abs_cum_return=abs_return_df[3:].mean(axis=1).cumsum()
        ax1.plot(abs_cum_return)
        ax1.set_title("Abs return in "+str(val)+" days")
        count,hit, payoff=trading_analytics(abs_return_df[3:])
        ax1.legend(['count='+str(count)+
                    ',hit rate='+str("{:.0%}".format(hit))+
                    ',payoff='+str(round(payoff,2))])

        ax2=fig.add_subplot(len(period_list),2,idx*2+2)
        rel_return_df=signal1_return_df(signal1_list,rel_return,val)
        rel_cum_return=rel_return_df[3:].mean(axis=1).cumsum()
        ax2.plot(rel_cum_return)
        ax2.set_title("Rel return in "+str(val)+" days")
        count,hit, payoff=trading_analytics(rel_return_df[3:])
        ax2.legend(['count='+str(count)+
                    ',hit rate='+str("{:.0%}".format(hit))+
                    ',payoff='+str(round(payoff,2))])
    plt.show()

# %%
datetime(2016,1,1).strftime("%d/%b/%Y")
# Out:
# '01/Jan/2016'

# %%
abs_return.columns[0].strptime
# Out:
# '02/Jan/2007'

# %%
datetime.strptime('02/Jan/2007',"%d/%b/%Y").year
# Out:
# 2007

# %%
year_list=abs_return.columns.tolist()

# %%
start_date=year_list[1]
end_date=year_list[-1]
start_year=datetime.strptime(start_date,"%d/%b/%Y").year
end_year=datetime.strptime(end_date,"%d/%b/%Y").year

# %%
start_date
# Out:
# '04/Jan/2007'

# %%
end_year
# Out:
# 2018

# %%
date_range=pd.date_range(start_date, end_date, freq='BY')

# %%
abs_return.loc[:,date_range[0].strftime("%d/%b/%Y"):date_range[1].strftime("%d/%b/%Y")]
# Out:
#              31/Dec/2007  02/Jan/2008  04/Jan/2008  07/Jan/2008  08/Jan/2008  \
# 0663735D ID     0.000000          NaN          NaN          NaN          NaN
# 0735547D LN    -0.000660          NaN          NaN          NaN          NaN
# 1041486D NA    -0.001120    -0.023925    -0.019916     0.001563    -0.003512
# 1254900D NO     0.000000          NaN          NaN          NaN          NaN
# 1334987D LN     0.033613          NaN          NaN          NaN          NaN
# 1343467D LN          NaN          NaN          NaN          NaN          NaN
# 1448841D LN    -0.014190          NaN          NaN          NaN          NaN
# 1474732D IM          NaN          NaN          NaN          NaN          NaN
# 1508262D LN    -0.005085          NaN          NaN          NaN          NaN
# 1519026D LN    -0.000806          NaN          NaN          NaN          NaN
# 1522106D SW          NaN          NaN          NaN          NaN          NaN
# 1561649D LN          NaN          NaN          NaN          NaN          NaN
# 1572241D SM     0.000000          NaN          NaN          NaN          NaN
# 1COV GR              NaN          NaN          NaN          NaN          NaN
# 2764557Q LN     0.001572          NaN          NaN          NaN          NaN
# 2989577Q LN    -0.014134          NaN          NaN          NaN          NaN
# 3123739Q LN     0.001406          NaN          NaN          NaN          NaN
# 3403721Q VX     0.000000     0.000000    -0.099359    -0.036180     0.052923
# 3426724Q LN    -0.001641          NaN          NaN          NaN          NaN
# 3465593Q SM     0.000000    -0.032003    -0.032417    -0.035722     0.000230
# 3564296Q LN     0.006592          NaN          NaN          NaN          NaN
# 3572335Q LN     0.003642          NaN          NaN          NaN          NaN
# 3577044Z NA     0.000000          NaN          NaN          NaN          NaN
# 63DU GR              NaN          NaN          NaN          NaN          NaN
# 8185832Q NO     0.000000          NaN          NaN          NaN          NaN
# 8190169Q LN    -0.004937    -0.011025     0.021739     0.010366    -0.002160
# 8209360Q LN     0.003300          NaN          NaN          NaN          NaN
# 9408593Q LN     0.000000     0.000000    -0.023899    -0.020619    -0.036184
# A2A IM          0.000000    -0.020714    -0.006508     0.014085    -0.012274
# A3M SM          0.000000          NaN          NaN          NaN          NaN
# ...                  ...          ...          ...          ...          ...
# WDF IM               NaN          NaN          NaN          NaN          NaN
# WDH DC          0.000000          NaN          NaN          NaN          NaN
# WDI GR          0.000000          NaN          NaN          NaN          NaN
# WEIR LN        -0.013406    -0.012971    -0.045056    -0.047837    -0.022023
# WG/ LN         -0.017026    -0.006928     0.006976    -0.016166    -0.015844
# WIE AV          0.000000          NaN          NaN          NaN          NaN
# WIN GR          0.000000    -0.009924    -0.012999    -0.012218     0.009960
# WIZZ LN              NaN          NaN          NaN          NaN          NaN
# WKL NA          0.015816    -0.016459    -0.011759     0.000458     0.003660
# WMH LN          0.022419    -0.047665    -0.047046    -0.048846    -0.014357
# WPG LN               NaN          NaN          NaN          NaN          NaN
# WPP LN          0.001548    -0.021638    -0.042654    -0.012376     0.000000
# WRT1V FH        0.000000    -0.016518    -0.058161    -0.057413     0.003734
# WRTAV FH        0.000000          NaN          NaN          NaN          NaN
# WSM LN          0.047389          NaN          NaN          NaN          NaN
# WTB LN          0.018923    -0.035714    -0.088889    -0.043902     0.012755
# WTG LN               NaN          NaN          NaN          NaN          NaN
# XCH LN         -0.002671          NaN          NaN          NaN          NaN
# XTA LN         -0.011967    -0.023944     0.016450    -0.059625     0.016002
# YAR NO          0.000000     0.013917     0.035294     0.026515     0.027675
# YIT FH          0.000000     0.001338    -0.069955    -0.020056     0.016076
# YNAP IM              NaN          NaN          NaN          NaN          NaN
# ZAG AV          0.000000          NaN          NaN          NaN          NaN
# ZAL GR               NaN          NaN          NaN          NaN          NaN
# ZC FP           0.011563    -0.018519    -0.044724    -0.032187    -0.009322
# ZEL SM          0.000000          NaN          NaN          NaN          NaN
# ZIGGO NA             NaN          NaN          NaN          NaN          NaN
# ZIL2 GR              NaN          NaN          NaN          NaN          NaN
# ZOT SM          0.000000          NaN          NaN          NaN          NaN
# ZURN SW         0.000000     0.000000    -0.040602    -0.014107     0.007154
#
#              09/Jan/2008  10/Jan/2008  11/Jan/2008  14/Jan/2008  15/Jan/2008  \
# 0663735D ID          NaN          NaN          NaN          NaN          NaN
# 0735547D LN          NaN          NaN          NaN          NaN          NaN
# 1041486D NA    -0.004307     0.000786     0.015717     0.013926    -0.026326
# 1254900D NO          NaN          NaN          NaN          NaN          NaN
# 1334987D LN          NaN          NaN          NaN          NaN          NaN
# 1343467D LN          NaN          NaN          NaN          NaN          NaN
# 1448841D LN          NaN          NaN          NaN          NaN          NaN
# 1474732D IM          NaN          NaN          NaN          NaN          NaN
# 1508262D LN          NaN          NaN          NaN          NaN          NaN
# 1519026D LN          NaN          NaN          NaN          NaN          NaN
# 1522106D SW          NaN          NaN          NaN          NaN          NaN
# 1561649D LN          NaN          NaN          NaN          NaN          NaN
# 1572241D SM          NaN          NaN          NaN          NaN          NaN
# 1COV GR              NaN          NaN          NaN          NaN          NaN
# 2764557Q LN          NaN          NaN          NaN          NaN          NaN
# 2989577Q LN          NaN          NaN          NaN          NaN          NaN
# 3123739Q LN          NaN          NaN          NaN          NaN          NaN
# 3403721Q VX    -0.034483    -0.009685    -0.001222     0.025092    -0.050746
# 3426724Q LN          NaN          NaN          NaN          NaN          NaN
# 3465593Q SM    -0.036347     0.034614     0.051223     0.010975    -0.065132
# 3564296Q LN          NaN          NaN          NaN          NaN          NaN
# 3572335Q LN          NaN          NaN          NaN          NaN          NaN
# 3577044Z NA          NaN          NaN          NaN          NaN          NaN
# 63DU GR              NaN          NaN          NaN          NaN          NaN
# 8185832Q NO          NaN          NaN          NaN          NaN          NaN
# 8190169Q LN    -0.005411    -0.003808    -0.050792     0.006329    -0.016581
# 8209360Q LN          NaN          NaN          NaN          NaN          NaN
# 9408593Q LN    -0.004096    -0.022618     0.004208     0.006983    -0.023578
# A2A IM          0.004905    -0.001952    -0.024780    -0.022401    -0.005814
# A3M SM               NaN          NaN          NaN          NaN          NaN
# ...                  ...          ...          ...          ...          ...
# WDF IM               NaN          NaN          NaN          NaN          NaN
# WDH DC               NaN          NaN          NaN          NaN          NaN
# WDI GR               NaN          NaN          NaN          NaN          NaN
# WEIR LN        -0.018297    -0.017921     0.045985     0.012561    -0.015851
# WG/ LN         -0.030412    -0.057810    -0.003265     0.024231    -0.015345
# WIE AV               NaN          NaN          NaN          NaN          NaN
# WIN GR         -0.052171    -0.028696    -0.011576    -0.030065    -0.044873
# WIZZ LN              NaN          NaN          NaN          NaN          NaN
# WKL NA         -0.026436    -0.008895    -0.001889     0.000947    -0.021749
# WMH LN         -0.029132    -0.074435    -0.029305     0.058449    -0.044904
# WPG LN               NaN          NaN          NaN          NaN          NaN
# WPP LN         -0.022556    -0.009402     0.023296     0.012648    -0.033306
# WRT1V FH       -0.023658    -0.039484     0.011451     0.037178    -0.060561
# WRTAV FH             NaN          NaN          NaN          NaN          NaN
# WSM LN               NaN          NaN          NaN          NaN          NaN
# WTB LN         -0.052057    -0.041630     0.025878     0.036036    -0.040000
# WTG LN               NaN          NaN          NaN          NaN          NaN
# XCH LN               NaN          NaN          NaN          NaN          NaN
# XTA LN         -0.029123    -0.003367     0.058968     0.012181    -0.020630
# YAR NO          0.028725    -0.057592    -0.024074     0.036053    -0.009158
# YIT FH         -0.035973    -0.038803     0.046581     0.014096    -0.041692
# YNAP IM              NaN          NaN          NaN          NaN          NaN
# ZAG AV               NaN          NaN          NaN          NaN          NaN
# ZAL GR               NaN          NaN          NaN          NaN          NaN
# ZC FP          -0.034079    -0.026856    -0.001894     0.017891    -0.043675
# ZEL SM               NaN          NaN          NaN          NaN          NaN
# ZIGGO NA             NaN          NaN          NaN          NaN          NaN
# ZIL2 GR              NaN          NaN          NaN          NaN          NaN
# ZOT SM               NaN          NaN          NaN          NaN          NaN
# ZURN SW         0.001579     0.011032     0.007015     0.017802    -0.016730
#
#                 ...       18/Dec/2008  19/Dec/2008  22/Dec/2008  23/Dec/2008  \
# 0663735D ID     ...               NaN          NaN          NaN          NaN
# 0735547D LN     ...               NaN          NaN          NaN          NaN
# 1041486D NA     ...          0.023126    -0.017268     0.004286     0.006970
# 1254900D NO     ...               NaN          NaN          NaN          NaN
# 1334987D LN     ...               NaN          NaN          NaN          NaN
# 1343467D LN     ...               NaN          NaN          NaN          NaN
# 1448841D LN     ...               NaN          NaN          NaN          NaN
# 1474732D IM     ...               NaN          NaN          NaN          NaN
# 1508262D LN     ...               NaN          NaN          NaN          NaN
# 1519026D LN     ...               NaN          NaN          NaN          NaN
# 1522106D SW     ...               NaN          NaN          NaN          NaN
# 1561649D LN     ...               NaN          NaN          NaN          NaN
# 1572241D SM     ...               NaN          NaN          NaN          NaN
# 1COV GR         ...               NaN          NaN          NaN          NaN
# 2764557Q LN     ...               NaN          NaN          NaN          NaN
# 2989577Q LN     ...               NaN          NaN          NaN          NaN
# 3123739Q LN     ...               NaN          NaN          NaN          NaN
# 3403721Q VX     ...         -0.024390    -0.025000    -0.007692    -0.018088
# 3426724Q LN     ...               NaN          NaN          NaN          NaN
# 3465593Q SM     ...          0.021688    -0.001846    -0.052242    -0.019512
# 3564296Q LN     ...               NaN          NaN          NaN          NaN
# 3572335Q LN     ...               NaN          NaN          NaN          NaN
# 3577044Z NA     ...               NaN          NaN          NaN          NaN
# 63DU GR         ...               NaN          NaN          NaN          NaN
# 8185832Q NO     ...               NaN          NaN          NaN          NaN
# 8190169Q LN     ...          0.026853    -0.023013    -0.007495     0.028047
# 8209360Q LN     ...               NaN          NaN          NaN          NaN
# 9408593Q LN     ...          0.052102     0.000000     0.008688    -0.012920
# A2A IM          ...          0.049634     0.010078     0.001535    -0.039080
# A3M SM          ...               NaN          NaN          NaN          NaN
# ...             ...               ...          ...          ...          ...
# WDF IM          ...               NaN          NaN          NaN          NaN
# WDH DC          ...               NaN          NaN          NaN          NaN
# WDI GR          ...               NaN          NaN          NaN          NaN
# WEIR LN         ...          0.078676    -0.063395    -0.116448     0.057661
# WG/ LN          ...          0.008552    -0.031421     0.006692    -0.003835
# WIE AV          ...               NaN          NaN          NaN          NaN
# WIN GR          ...          0.028078    -0.039616    -0.006563    -0.009751
# WIZZ LN         ...               NaN          NaN          NaN          NaN
# WKL NA          ...          0.006627     0.011339    -0.032188     0.018685
# WMH LN          ...          0.033570    -0.009282    -0.009369     0.005913
# WPG LN          ...               NaN          NaN          NaN          NaN
# WPP LN          ...          0.015903     0.033187    -0.066667     0.031169
# WRT1V FH        ...         -0.003587     0.012831    -0.004557    -0.005097
# WRTAV FH        ...               NaN          NaN          NaN          NaN
# WSM LN          ...               NaN          NaN          NaN          NaN
# WTB LN          ...          0.001633    -0.004348    -0.027293     0.030303
# WTG LN          ...               NaN          NaN          NaN          NaN
# XCH LN          ...               NaN          NaN          NaN          NaN
# XTA LN          ...          0.020322    -0.113324    -0.075135     0.007537
# YAR NO          ...          0.010695    -0.031746    -0.009107     0.016544
# YIT FH          ...         -0.006733    -0.015808     0.000000     0.025235
# YNAP IM         ...               NaN          NaN          NaN          NaN
# ZAG AV          ...               NaN          NaN          NaN          NaN
# ZAL GR          ...               NaN          NaN          NaN          NaN
# ZC FP           ...         -0.053782     0.010855    -0.021281     0.009176
# ZEL SM          ...               NaN          NaN          NaN          NaN
# ZIGGO NA        ...               NaN          NaN          NaN          NaN
# ZIL2 GR         ...               NaN          NaN          NaN          NaN
# ZOT SM          ...               NaN          NaN          NaN          NaN
# ZURN SW         ...         -0.010540    -0.041329    -0.013778     0.001803
#
#              24/Dec/2008  25/Dec/2008  26/Dec/2008  29/Dec/2008  30/Dec/2008  \
# 0663735D ID          NaN          NaN          NaN          NaN          NaN
# 0735547D LN          NaN          NaN          NaN          NaN          NaN
# 1041486D NA     0.010030          0.0          0.0     0.005594     0.072740
# 1254900D NO          NaN          NaN          NaN          NaN          NaN
# 1334987D LN          NaN          NaN          NaN          NaN          NaN
# 1343467D LN          NaN          NaN          NaN          NaN          NaN
# 1448841D LN          NaN          NaN          NaN          NaN          NaN
# 1474732D IM          NaN          NaN          NaN          NaN          NaN
# 1508262D LN          NaN          NaN          NaN          NaN          NaN
# 1519026D LN          NaN          NaN          NaN          NaN          NaN
# 1522106D SW          NaN          NaN          NaN          NaN          NaN
# 1561649D LN          NaN          NaN          NaN          NaN          NaN
# 1572241D SM          NaN          NaN          NaN          NaN          NaN
# 1COV GR              NaN          NaN          NaN          NaN          NaN
# 2764557Q LN          NaN          NaN          NaN          NaN          NaN
# 2989577Q LN          NaN          NaN          NaN          NaN          NaN
# 3123739Q LN          NaN          NaN          NaN          NaN          NaN
# 3403721Q VX     0.000000          0.0          0.0     0.039474     0.012152
# 3426724Q LN          NaN          NaN          NaN          NaN          NaN
# 3465593Q SM     0.000000          0.0          0.0    -0.019900    -0.006091
# 3564296Q LN          NaN          NaN          NaN          NaN          NaN
# 3572335Q LN          NaN          NaN          NaN          NaN          NaN
# 3577044Z NA          NaN          NaN          NaN          NaN          NaN
# 63DU GR              NaN          NaN          NaN          NaN          NaN
# 8185832Q NO          NaN          NaN          NaN          NaN          NaN
# 8190169Q LN    -0.028332          0.0          0.0     0.023758    -0.006329
# 8209360Q LN          NaN          NaN          NaN          NaN          NaN
# 9408593Q LN     0.061955          0.0          0.0    -0.036154     0.010230
# A2A IM          0.000000          0.0          0.0    -0.003987     0.017614
# A3M SM               NaN          NaN          NaN          NaN          NaN
# ...                  ...          ...          ...          ...          ...
# WDF IM               NaN          NaN          NaN          NaN          NaN
# WDH DC               NaN          NaN          NaN          NaN          NaN
# WDI GR               NaN          NaN          NaN          NaN          NaN
# WEIR LN        -0.017913          0.0          0.0     0.028549     0.005397
# WG/ LN         -0.037229          0.0          0.0     0.016004     0.022309
# WIE AV               NaN          NaN          NaN          NaN          NaN
# WIN GR          0.000000          0.0          0.0     0.045108     0.024620
# WIZZ LN              NaN          NaN          NaN          NaN          NaN
# WKL NA         -0.019809          0.0          0.0     0.012725     0.021064
# WMH LN         -0.021151          0.0          0.0     0.027613    -0.001170
# WPG LN               NaN          NaN          NaN          NaN          NaN
# WPP LN         -0.010076          0.0          0.0    -0.002545     0.010842
# WRT1V FH        0.000000          0.0          0.0     0.036810     0.036006
# WRTAV FH             NaN          NaN          NaN          NaN          NaN
# WSM LN               NaN          NaN          NaN          NaN          NaN
# WTB LN         -0.019608          0.0          0.0    -0.003333     0.022854
# WTG LN               NaN          NaN          NaN          NaN          NaN
# XCH LN               NaN          NaN          NaN          NaN          NaN
# XTA LN          0.014132          0.0          0.0     0.036885     0.011856
# YAR NO          0.000000          0.0          0.0     0.052441     0.022337
# YIT FH          0.000000          0.0          0.0     0.033562    -0.008657
# YNAP IM              NaN          NaN          NaN          NaN          NaN
# ZAG AV               NaN          NaN          NaN          NaN          NaN
# ZAL GR               NaN          NaN          NaN          NaN          NaN
# ZC FP          -0.002174          0.0          0.0     0.036252     0.012426
# ZEL SM               NaN          NaN          NaN          NaN          NaN
# ZIGGO NA             NaN          NaN          NaN          NaN          NaN
# ZIL2 GR              NaN          NaN          NaN          NaN          NaN
# ZOT SM               NaN          NaN          NaN          NaN          NaN
# ZURN SW         0.000000          0.0          0.0     0.003599     0.017481
#
#              31/Dec/2008
# 0663735D ID          NaN
# 0735547D LN          NaN
# 1041486D NA    -0.049656
# 1254900D NO          NaN
# 1334987D LN          NaN
# 1343467D LN          NaN
# 1448841D LN          NaN
# 1474732D IM          NaN
# 1508262D LN          NaN
# 1519026D LN          NaN
# 1522106D SW          NaN
# 1561649D LN          NaN
# 1572241D SM          NaN
# 1COV GR              NaN
# 2764557Q LN          NaN
# 2989577Q LN          NaN
# 3123739Q LN          NaN
# 3403721Q VX     0.000000
# 3426724Q LN          NaN
# 3465593Q SM     0.000000
# 3564296Q LN          NaN
# 3572335Q LN          NaN
# 3577044Z NA          NaN
# 63DU GR              NaN
# 8185832Q NO          NaN
# 8190169Q LN     0.020170
# 8209360Q LN          NaN
# 9408593Q LN     0.015190
# A2A IM          0.000000
# A3M SM               NaN
# ...                  ...
# WDF IM               NaN
# WDH DC               NaN
# WDI GR               NaN
# WEIR LN        -0.049080
# WG/ LN         -0.033376
# WIE AV               NaN
# WIN GR          0.000000
# WIZZ LN              NaN
# WKL NA         -0.019906
# WMH LN          0.005843
# WPG LN               NaN
# WPP LN          0.015773
# WRT1V FH        0.000000
# WRTAV FH             NaN
# WSM LN               NaN
# WTB LN         -0.000545
# WTG LN               NaN
# XCH LN               NaN
# XTA LN          0.000000
# YAR NO          0.000000
# YIT FH          0.000000
# YNAP IM              NaN
# ZAG AV               NaN
# ZAL GR               NaN
# ZC FP          -0.018127
# ZEL SM               NaN
# ZIGGO NA             NaN
# ZIL2 GR              NaN
# ZOT SM               NaN
# ZURN SW         0.000000
#
# [1304 rows x 261 columns]
