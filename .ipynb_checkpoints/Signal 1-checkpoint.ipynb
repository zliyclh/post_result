# %% [markdown]
# # Use bloomberg download data to get me started

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#initial cleaning function
def clean_sheet(dataframe):
    adj=dataframe.dropna(axis=1,how='all')
    adj=dataframe.set_index(adj.columns[0]) #use stock tickers as the index
    return adj

# %%
#pull the data from excel, form a dictionary of tab names and dataframes
tabs_to_grab=['Quarter','Date','Revision','Market cap','Property']

data_dict={}

for s in tabs_to_grab:
    df=clean_sheet(pd.read_excel(r'C:\Users\Eric.Li\Documents\Post result data\Europe 2007-2018.xlsx',sheet_name=s))
    data_dict[s]=df.dropna(axis=0,how='all')

# %%
# get the price dataframe for certain years; form the price and return datetime from the data from all the years 
def return_from_excel(path, start_year,end_year):
    
    year_range=range(start_year,end_year+1)

    price_list=[]
    abs_return_list=[]
    rel_return_list=[]
    for year in year_range:
        price_year=clean_sheet(pd.read_excel(path,sheet_name=str(year))).dropna(how='all',axis=0)
        abs_return=price_year.diff(1,axis=1)/price_year.shift(1,axis=1)
        abs_return=abs_return.dropna(how='all',axis=0)
        rel_return=abs_return - abs_return.loc["SXXP Index"]
        rel_return=rel_return.dropna(how='all',axis=0)
        price_list.append(price_year)
        abs_return_list.append(abs_return)
        rel_return_list.append(rel_return)

    price=pd.concat(price_list,axis=1).dropna(axis=1,how='all').dropna(axis=0,how='all')
    abs_return=pd.concat(abs_return_list,axis=1).dropna(axis=1,how='all').dropna(axis=0,how='all')
    rel_return=pd.concat(rel_return_list,axis=1).dropna(axis=1,how='all').dropna(axis=0,how='all')

    # transform the datetime to the common timestamp format
    price_column=[i.strftime("%d/%b/%Y") for i in price.columns.tolist() if type(i)!=str]
    abs_return_column=[i.strftime("%d/%b/%Y") for i in abs_return.columns.tolist() if type(i)!=str]
    rel_return_column=[i.strftime("%d/%b/%Y") for i in rel_return.columns.tolist() if type(i)!=str]

    price.columns=price_column
    abs_return.columns=abs_return_column
    rel_return.columns=rel_return_column
    
    return price, abs_return,rel_return 


price,abs_return,rel_return=return_from_excel(r'C:\Users\Eric.Li\Documents\Post result data\Europe price.xlsx', 2007,2018)

# %%
# utility function to get volatility from return series
def vol_calc(return_series, vol_lookback):
    hist=len(return_series)
    if hist<=vol_lookback:
        vol=return_series[-hist+1:].std()
    else:
        vol=return_series[-vol_lookback-1:-1].std()
    return vol

# %%
# utility function to obtain announcement return (as a multiplier of vol) as a result of day 0 and return dataframe
def ann_ret(single_date,return_series,EAR_period,vol_lookback):
    if type(single_date)==pd._libs.tslib.Timestamp:
        date_series=return_series.index.tolist()
        if single_date.strftime("%d/%b/%Y") in date_series:
            day0=date_series.index(single_date.strftime("%d/%b/%Y"))
            vol=vol_calc(return_series,vol_lookback)
            if len(return_series.iloc[day0:])<EAR_period:
                ret=return_series[day0:].sum()
                nmove=ret/vol
            else:
                ret=return_series.iloc[day0:day0+EAR_period].sum()
                nmove=ret/vol
            return nmove
        else:
            return None
    else:
        return single_date

# %%
# obtain the announcement return dataframe from price return and date dataframe
def EAR(date_df,return_df,EAR_period,vol_lookback):
    EAR_list=[]
    for ticker, date_row in date_df.iterrows():
        if type(ticker)==str: #deal with 
            return_row=return_df.loc[ticker]
            ret_series=date_row.apply(lambda x: ann_ret(x,return_row,EAR_period,vol_lookback))
            EAR_list.append(ret_series)
        else:
            pass
    EAR_df=pd.concat(EAR_list,axis=1).T
    return EAR_df

# %% [markdown]
# ## Signal 1 - absolute signal

# %%
#signal formation (number 1) and use the date as the base dataframe
def signal1_formation(date_df,return_df,EAR_period,vol_lookback,return_criteria,revision_df, revision_criteria):
    EAR_return=EAR(date_df,return_df,EAR_period,vol_lookback).fillna(0.0).loc[revision_df.index.tolist()]
    signal1_evaluate=(EAR_return>return_criteria) & (revision_df>revision_criteria)
    signal1=date_df[signal1_evaluate]
    signal1_next=date_df.shift(1,axis=1)[signal1_evaluate]
    return signal1,signal1_next

rel_signal1,rel_signal1_next=signal1_formation(data_dict['Date'],rel_return,3,30,2,data_dict['Revision'],0.02)

# %%
#Stack signals into a list of tuples (stocks, dates), convert dates into a common format of datetime
def signal1_stacking(signal1,signal1_next):
    signal1_list=[]
    for ticker, row in signal1.iterrows():
        for idx in range(len(row)):
            date=row.iloc[idx]
            date_next=signal1_next.loc[ticker].iloc[idx]
            if type(date)==pd._libs.tslib.Timestamp:
                ts=(date - np.datetime64('1970-01-01T00:00:00Z')) / np.timedelta64(1, 's') 
                adj_date=datetime.utcfromtimestamp(ts).strftime("%d/%b/%Y") #transform the datetime into a common format
                if type(date_next)==pd._libs.tslib.NaTType:
                    adj_next_date=date_next
                else:
                    ts_next=(date_next - np.datetime64('1970-01-01T00:00:00Z')) / np.timedelta64(1, 's')
                    adj_next_date=datetime.utcfromtimestamp(ts_next).strftime("%d/%b/%Y")                      
                signal1_list.append((row.name,adj_date,adj_next_date))
            else:
                pass
    return signal1_list

# %%
# create a dictionary to have signal information (tuple) as keys and return data time series as values to make it easier to check
#; replace datetime with number of days post announcement to make it more comparable 
def signal1_return_dict(signal1_list,return_df,holding,earning):#if we hold them through next earning
    signal1_dict={}
    for s in signal1_list:
        return_series=return_df.loc[s[0]]
        if s[1] in return_series.index:          
            day0=return_series.index.tolist().index(s[1]) #index of day 0
            if earning is True:
                period=holding
            elif type(s[2])==pd._libs.tslib.NaTType:
                period=holding
            else:
                period=min(holding,np.busday_count(datetime.strptime(s[1],"%d/%b/%Y"),datetime.strptime(s[2],"%d/%b/%Y")))
            target_series=return_series.iloc[day0:day0+min(period, len(return_series[day0:]))]
            target_series.index=range(min(period, len(return_series[day0:]))) #replace datetime with number of days post announcement
            target_series.name=(s[0],s[1])
            signal1_dict[s]=target_series
        else:
            pass          
    return signal1_dict

# %%
# obtain the dataframe of return time series for the signal stocks, take the signal_return_dict function
def signal1_return_df(signal1,signal1_next,return_df,holding,earning):
    return_series_list=[]
    return_dict=signal1_return_dict(signal1_stacking(signal1,signal1_next),return_df,holding,earning)
    for index,key in return_dict.items():
        return_series_list.append(key)
    try:
        signal1_return_df=pd.concat(return_series_list,axis=1)
        if earning is True:
            signal1_return_df=signal1_return_df.dropna(how='any',axis=1) #drop stocks with limited history to make it more comparable
        else:
            signal1_return_df=signal1_return_df.dropna(how='all',axis=1).dropna(how='all',axis=0)
        return signal1_return_df
    except ValueError:
        return None


rel_signal1_abs_return_df=signal1_return_df(rel_signal1,rel_signal1_next,abs_return,130,True)
rel_signal1_rel_return_df=signal1_return_df(rel_signal1,rel_signal1_next,rel_return,130,True)
# Out:
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   if __name__ == '__main__':
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future

# %%
# List of signals and cumulative returns
rel_signal1_ind_abs_return=rel_signal1_abs_return_df.iloc[3:].cumsum(axis=0).iloc[-1]
rel_signal1_ind_abs_return

rel_signal1_ind_rel_return=rel_signal1_rel_return_df.iloc[3:].cumsum(axis=0).iloc[-1]
rel_signal1_ind_rel_return.sort_values()
# Out:
# UNI IM     15/Mar/2012    -0.82567
# SWEDA SS   17/Jul/2008    -0.76948
# TOM2 NA    24/Oct/2007   -0.723195
# BKT SM     19/Jan/2012   -0.716197
# BOL SS     19/Jul/2007     -0.7062
#            08/May/2008   -0.658539
# YIT FH     25/Apr/2008   -0.652582
# NOKIA FH   20/Oct/2011   -0.596503
# SSABB SS   23/Jul/2014   -0.593165
# OTE1V FH   23/Apr/2008   -0.589709
# SSABA SS   23/Jul/2014    -0.58081
# SDF GR     14/Mar/2013   -0.568142
# NRE1V FH   07/May/2008   -0.559881
# YAR NO     18/Apr/2008   -0.551237
# SUBC NO    31/Jul/2014   -0.535267
# UG FP      23/Jul/2008   -0.513388
# KBC BB     12/May/2011    -0.50459
# BEKB BB    25/Feb/2011   -0.499143
# AF FP      18/Feb/2016   -0.483105
# ELUXB SS   17/Jul/2007   -0.480958
# NHY NO     22/Apr/2008   -0.463499
# MTGB SS    22/Jul/2008   -0.458993
# AAL LN     25/Jul/2014   -0.453865
# NHY NO     11/Feb/2015   -0.450458
# MT NA      30/Jul/2008   -0.445148
# REN NA     19/Feb/2009   -0.444504
# EBS AV     30/Apr/2008   -0.426701
# REL LN     19/Feb/2009   -0.415565
# BOKA NA    21/Aug/2008   -0.405629
# SSABA SS   27/Apr/2012   -0.399731
#                             ...
# SEBA SS    05/Feb/2009    0.579385
# LEON SW    26/Feb/2015    0.605091
# WAF GR     27/Oct/2016    0.606934
# AIXA GR    30/Jul/2009    0.615861
# AKERBP NO  29/Apr/2016    0.622866
# EVT GR     10/Nov/2016     0.64782
# SOI FP     08/Dec/2016    0.649356
# JD/ LN     15/Apr/2015    0.658396
# FINGB SS   22/Oct/2015    0.680774
# HSX LN     18/Aug/2008    0.689046
# LOGN SW    25/Jul/2013    0.690261
# AF FP      16/Feb/2017    0.701669
# KAZ LN     31/Mar/2009    0.716931
# NDX1 GR    11/Mar/2013    0.780782
# INDV LN    18/Feb/2016    0.784098
# EVT GR     28/Mar/2017    0.790349
# AAL LN     16/Feb/2016    0.803953
# AKERBP NO  16/Aug/2011    0.820777
# INCH LN    19/Mar/2009    0.843786
# PSM GR     14/May/2009    0.859035
# VWS DC     08/May/2013    0.903166
# YAR NO     19/Oct/2007    0.936916
# MBTN SW    03/Apr/2007     0.95294
# DLG GR     28/Jul/2009    0.953789
# AIXA GR    07/May/2009     1.02299
# BOL SS     13/Feb/2009     1.03232
# KAZ LN     18/Aug/2016     1.05905
# NAS NO     23/Apr/2009     1.06878
# GLPG NA    06/Mar/2015     1.09997
# S92 GR     13/May/2015     1.15416
# Name: 129, Length: 2142, dtype: object

# %%
# Performance analytics
# 1. aggregate abs/rel performance over time
def perf_chart(return_df,xlabel,ylabel,title):
    cum_return=return_df.mean(axis=1).cumsum()
    plt.plot(cum_return)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()
    
perf_chart(rel_signal1_abs_return_df.iloc[3:], xlabel="Days post announcement",
           ylabel="Average accumulated absolute return",title="Absolute performance of signal 1 - Europe 2007-2018")

# %%
perf_chart(rel_signal1_rel_return_df.iloc[3:], xlabel="Days post announcement",
           ylabel="Average accumulated rel return",title="Rel performance of signal 1 - Europe 2007-2018")

# %%
# 2. trading analytics
def trading_analytics(return_df):
    ind_return=return_df.cumsum(axis=0).ffill().iloc[-1]
    signal1_count=len(ind_return)
    hit_rate=len(ind_return[ind_return>0])/len(ind_return)*1.0
    payoff_ratio=ind_return[ind_return>0].mean()/ind_return[ind_return<0].mean()*-1.0
    #annualised_return=return_df.mean(axis=1).cumsum().iloc[-1]*260/(len(return_df))
    #annualised_vol=return_df.mean(axis=1).std()*((260/(len(return_df)))**0.5)
    #annualised_sharpe=annualised_return/annualised_vol*1.0
    return signal1_count, hit_rate,payoff_ratio
    
trading_analytics(rel_signal1_rel_return_df[3:])
# Out:
# (2142, 0.6251167133520075, 1.2082914356340333)

# %%
# plot the performance for different holding period 
def plot_by_holding(period_list,figsize,fontsize,title,signal1_list,signal1_list_next,abs_return,rel_return,earning):    
    fig=plt.figure(figsize=figsize)
    fig.suptitle("Performance of signal 1 for Europe 2016-2018", fontsize=fontsize)
    for idx, val in enumerate(period_list):
        ax1=fig.add_subplot(len(period_list),2,idx*2+1)
        abs_return_df=signal1_return_df(signal1_list,signal1_list_next,abs_return,val,earning)
        abs_cum_return=abs_return_df[3:].mean(axis=1).cumsum()
        ax1.plot(abs_cum_return)
        ax1.set_title("Abs return in "+str(val)+" days")
        count,hit, payoff=trading_analytics(abs_return_df[3:])
        ax1.legend(['count='+str(count)+
                    ',hit rate='+str("{:.0%}".format(hit))+
                    ',payoff='+str(round(payoff,2))])

        ax2=fig.add_subplot(len(period_list),2,idx*2+2)
        rel_return_df=signal1_return_df(signal1_list,signal1_list_next,rel_return,val,earning)
        rel_cum_return=rel_return_df[3:].mean(axis=1).cumsum()
        ax2.plot(rel_cum_return)
        ax2.set_title("Rel return in "+str(val)+" days")
        count,hit, payoff=trading_analytics(rel_return_df[3:])
        ax2.legend(['count='+str(count)+
                    ',hit rate='+str("{:.0%}".format(hit))+
                    ',payoff='+str(round(payoff,2))])
    plt.show()

    
plot_by_holding([30,60,120,260,320,520,720],(15,20),18,"Performance of signal 1 for Europe 2007-2018",rel_signal1,rel_signal1_next,abs_return,rel_return,True)
# Out:
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   if __name__ == '__main__':
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future

# %% [markdown]
# ## Signal performance by years

# %%
# plot the performance for different year
def plot_by_year(start_year,end_year,figsize,fontsize,title,signal1,signal1_next,abs_return,rel_return,holding_period,earning):    
    year_range=range(start_year,end_year+1)
    fig=plt.figure(figsize=figsize)
    fig.suptitle(title, fontsize=fontsize)
    for idx, val in enumerate(year_range):
        signal1_year=signal1[signal1.apply(lambda x: (x>=pd.Timestamp(val,1,1))&(x<=pd.Timestamp(val,12,31)))]
        signal1_year_next=signal1_next[signal1_next.apply(lambda x: (x>=pd.Timestamp(val,1,1))&(x<=pd.Timestamp(val,12,31)))]
        
        ax1=fig.add_subplot(len(year_range),2,idx*2+1)
        abs_return_df=signal1_return_df(signal1_year,signal1_year_next,abs_return,holding_period,earning)
        abs_cum_return=abs_return_df[3:].mean(axis=1).cumsum()
        ax1.plot(abs_cum_return)
        ax1.set_title("Abs return in "+str(val))
        count,hit, payoff=trading_analytics(abs_return_df[3:])
        ax1.legend(['count='+str(count)+
                    ',hit rate='+str("{:.0%}".format(hit))+
                    ',payoff='+str(round(payoff,2))])

        ax2=fig.add_subplot(len(year_range),2,idx*2+2)
        rel_return_df=signal1_return_df(signal1_year,signal1_year_next,rel_return,holding_period,earning)
        rel_cum_return=rel_return_df[3:].mean(axis=1).cumsum()
        ax2.plot(rel_cum_return)
        ax2.set_title("Rel return in "+str(val))
        count,hit, payoff=trading_analytics(rel_return_df[3:])
        ax2.legend(['count='+str(count)+
                    ',hit rate='+str("{:.0%}".format(hit))+
                    ',payoff='+str(round(payoff,2))])
    plt.show()

# %%
plot_by_year(2007, 2018,(15,40),18,
             "Performance of signal 1 for Europe 2007-2018",rel_signal1,rel_signal1_next,abs_return,rel_return, 120,True)
# Out:
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   if __name__ == '__main__':
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future

# %%
signal_2017=rel_signal1[rel_signal1.apply(lambda x: x>pd.Timestamp(2017,1,1))]
signal_2017_next=rel_signal1_next[rel_signal1_next.apply(lambda x: x>pd.Timestamp(2017,1,1))]
signal1_return_df(signal_2017,rel_signal1_next,rel_return,130,True).iloc[3:].cumsum().iloc[-1].sort_values()
# Out:
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   if __name__ == '__main__':
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
# SZU GR     12/Jan/2017   -0.322352
# OUT1V FH   02/Feb/2017   -0.288823
# AKER NO    28/Feb/2017   -0.264156
# NCCB SS    28/Apr/2017   -0.258373
# LNZ AV     22/Mar/2017   -0.225634
# BWLPG NO   27/Feb/2017   -0.224411
# RWE GR     14/Aug/2017   -0.199864
# JD/ LN     11/Apr/2017   -0.197144
# RNO FP     10/Feb/2017   -0.185901
# SVT LN     23/May/2017   -0.180572
# APAM NA    09/Feb/2017   -0.179521
# PNN LN     24/May/2017   -0.177313
# MS IM      19/Apr/2017    -0.17109
# TIT IM     03/May/2017   -0.166177
# DEC FP     02/Mar/2017    -0.15019
# INTRUM SS  26/Jan/2017    -0.14872
# INCH LN    27/Jul/2017   -0.148333
# GKN LN     28/Feb/2017    -0.14536
# RAND NA    14/Feb/2017   -0.144433
# BEKB BB    01/Mar/2017   -0.134529
# DLG LN     01/Aug/2017   -0.127037
# CCH LN     10/Aug/2017   -0.120991
# KPN NA     26/Jul/2017   -0.120071
# AKERBP NO  06/Feb/2017   -0.116069
# MT IM      27/Jul/2017    -0.11163
# BOL SS     10/Feb/2017    -0.11148
# MT NA      10/Feb/2017   -0.103986
# ULVR LN    20/Jul/2017    -0.10337
# AZM IM     04/May/2017   -0.102577
# ISS DC     23/Feb/2017   -0.100574
#                             ...
# RBI AV     10/Aug/2017    0.255377
# STMN SW    16/Feb/2017    0.258467
# ASRNL NA   22/Feb/2017    0.265528
# OMV AV     16/Feb/2017    0.274158
# SAB SM     27/Jan/2017     0.28578
# FORTUM FH  27/Apr/2017    0.288344
# TGYM IM    06/Mar/2017    0.289842
# RBI AV     17/May/2017    0.299334
# BESI NA    25/Apr/2017    0.303288
# IPN FP     23/Feb/2017    0.308242
# BESI NA    27/Jul/2017    0.316344
# EVO SS     20/Apr/2017    0.326904
# PLUS LN    07/Aug/2017    0.328773
# DBG FP     22/May/2017    0.347988
# BUR LN     14/Mar/2017    0.348109
# RWE GR     15/May/2017     0.36335
# VCP LN     25/Jul/2017    0.371689
# WIZZ LN    25/May/2017    0.375837
# AMBUB DC   02/May/2017    0.411946
# EVO SS     16/Feb/2017    0.418415
# FKR IM     31/Jul/2017    0.425181
# SANT GR    06/Apr/2017    0.439258
# BESI NA    23/Feb/2017    0.447783
# EVT GR     10/May/2017    0.468667
# FCT IM     29/Mar/2017    0.477065
# AMS SW     07/Feb/2017    0.477573
# AF FP      04/May/2017    0.527439
# MT IM      15/Mar/2017    0.528325
# AF FP      16/Feb/2017    0.701669
# EVT GR     28/Mar/2017    0.790349
# Name: 129, Length: 256, dtype: object

# %% [markdown]
# ## by sector

# %%
## sector mapping and unique sector list, add the sector column to the signal
def sector_mapping(ticker,mapping_df):
    mapping=mapping_df.dropna()
    if ticker in mapping.index:
        sector=mapping[ticker]
    else:
        sector=None
    return sector
    
unique_sector=list(set(data_dict["Property"]["Sector"].dropna().values))
rel_signal1_with_sector=rel_signal1.copy()
rel_signal1_next_with_sector=rel_signal1_next.copy()
rel_signal1_with_sector["sector"]=[sector_mapping(i,data_dict["Property"]["Sector"]) for i in rel_signal1_with_sector.index]
rel_signal1_next_with_sector["sector"]=[sector_mapping(i,data_dict["Property"]["Sector"]) for i in rel_signal1_next_with_sector.index]

# %%
# plot the performance for different sectors
def plot_by_sector(sector_list,figsize,fontsize,title,signal1,signal1_next,abs_return,rel_return,holding_period,earning):    
    fig=plt.figure(figsize=figsize)
    fig.suptitle(title, fontsize=fontsize)
    for idx, sector in enumerate(sector_list):
        signal1_sector=signal1[signal1["sector"]==sector].iloc[:,:-1]
        signal1_next_sector=signal1_next[signal1_next["sector"]==sector].iloc[:,:-1]
        
        ax1=fig.add_subplot(len(sector_list),2,idx*2+1)
        abs_return_df=signal1_return_df(signal1_sector,signal1_next_sector,abs_return,holding_period,earning)
        abs_cum_return=abs_return_df[3:].mean(axis=1).cumsum()
        ax1.plot(abs_cum_return)
        ax1.set_title("Abs return in "+str(sector))
        count,hit, payoff=trading_analytics(abs_return_df[3:])
        ax1.legend(['count='+str(count)+
                    ',hit rate='+str("{:.0%}".format(hit))+
                    ',payoff='+str(round(payoff,2))])

        ax2=fig.add_subplot(len(sector_list),2,idx*2+2)
        rel_return_df=signal1_return_df(signal1_sector,signal1_next_sector,rel_return,holding_period,earning)
        rel_cum_return=rel_return_df[3:].mean(axis=1).cumsum()
        ax2.plot(rel_cum_return)
        ax2.set_title("Rel return in "+str(sector))
        count,hit, payoff=trading_analytics(rel_return_df[3:])
        ax2.legend(['count='+str(count)+
                    ',hit rate='+str("{:.0%}".format(hit))+
                    ',payoff='+str(round(payoff,2))])
    
    plt.show()

# %%
plot_by_sector(unique_sector,(15,60),18,
             "Performance of signal 1 for Europe 2007-2018",rel_signal1_with_sector,rel_signal1_next_with_sector,abs_return,rel_return, 120,True)
# Out:
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   if __name__ == '__main__':
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future

# %% [markdown]
# ## Signal performance by country

# %%
## unique country list, add the country column to the signal
rel_signal1_with_country=rel_signal1.copy()
rel_signal1_with_country["country"]=[i[-2:] for i in rel_signal1_with_country.index]
rel_signal1_next_with_country=rel_signal1_next.copy()
rel_signal1_next_with_country["country"]=[i[-2:] for i in rel_signal1_next_with_country.index]

unique_country=list(set(rel_signal1_with_country["country"]))

# %%
rel_signal1_with_country[rel_signal1_with_country.country=='VX']
# Out:
#             2018-03-07 00:00:00 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# Unnamed: 0
# SYST VX                     NaT        NaT        NaT        NaT        NaT
# RUKN VX                     NaT        NaT        NaT        NaT        NaT
# 3403721Q VX                 NaT        NaT        NaT        NaT        NaT
# CIBNE VX                    NaT        NaT        NaT        NaT        NaT
# CIBN VX                     NaT        NaT        NaT        NaT        NaT
#
#             Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10   ...    \
# Unnamed: 0                                                            ...
# SYST VX            NaT        NaT        NaT        NaT         NaT   ...
# RUKN VX            NaT        NaT        NaT        NaT         NaT   ...
# 3403721Q VX        NaT        NaT        NaT        NaT         NaT   ...
# CIBNE VX           NaT        NaT        NaT        NaT         NaT   ...
# CIBN VX            NaT        NaT        NaT        NaT         NaT   ...
#
#             Unnamed: 56 Unnamed: 57 Unnamed: 58 Unnamed: 59 Unnamed: 60  \
# Unnamed: 0
# SYST VX             NaT         NaT         NaT         NaT         NaT
# RUKN VX             NaT         NaT         NaT         NaT         NaT
# 3403721Q VX         NaT         NaT         NaT         NaT         NaT
# CIBNE VX            NaT         NaT         NaT         NaT         NaT
# CIBN VX             NaT         NaT         NaT         NaT         NaT
#
#             Unnamed: 61 Unnamed: 62 Unnamed: 63 Unnamed: 64 country
# Unnamed: 0
# SYST VX             NaT         NaT         NaT         NaT      VX
# RUKN VX             NaT         NaT         NaT         NaT      VX
# 3403721Q VX         NaT         NaT         NaT         NaT      VX
# CIBNE VX            NaT         NaT         NaT         NaT      VX
# CIBN VX             NaT         NaT         NaT         NaT      VX
#
# [5 rows x 65 columns]

# %%
# plot the performance by countries
def plot_by_country(country_list,figsize,fontsize,title,signal1,signal1_next,abs_return,rel_return,holding_period,earning):    
    fig=plt.figure(figsize=figsize)
    fig.suptitle(title, fontsize=fontsize)
    for idx, country in enumerate(country_list):
        signal1_country=signal1[signal1["country"]==country].iloc[:,:-1]
        signal1_next_country=signal1_next[signal1_next["country"]==country].iloc[:,:-1]
        
        ax1=fig.add_subplot(len(country_list),2,idx*2+1)
        #print(signal1_country,signal1_next_country)
        abs_return_df=signal1_return_df(signal1_country,signal1_next_country,abs_return,holding_period,earning)
        if abs_return_df is not None:
            abs_cum_return=abs_return_df[3:].mean(axis=1).cumsum()
            ax1.plot(abs_cum_return)
            ax1.set_title("Abs return in "+str(country))
            count,hit, payoff=trading_analytics(abs_return_df[3:])
            ax1.legend(['count='+str(count)+
                        ',hit rate='+str("{:.0%}".format(hit))+
                        ',payoff='+str(round(payoff,2))])
        else:
            pass
        
        ax2=fig.add_subplot(len(country_list),2,idx*2+2)
        rel_return_df=signal1_return_df(signal1_country,signal1_next_country,rel_return,holding_period,earning)
        if rel_return_df is not None:  
            rel_cum_return=rel_return_df[3:].mean(axis=1).cumsum()
            ax2.plot(rel_cum_return)
            ax2.set_title("Rel return in "+str(country))
            count,hit, payoff=trading_analytics(rel_return_df[3:])
            ax2.legend(['count='+str(count)+
                        ',hit rate='+str("{:.0%}".format(hit))+
                        ',payoff='+str(round(payoff,2))])
        else:
            pass
    plt.show()

# %%
plot_by_country(unique_country,(15,50),18,
             "Performance of signal 1 for Europe 2007-2018",rel_signal1_with_country,rel_signal1_next_with_country,abs_return,rel_return, 120,True)
# Out:
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   if __name__ == '__main__':
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future

# %% [markdown]
# ## Avoid holding through numbers

# %%
plot_by_holding([30,60,150],(15,20),18,
                "Performance of signal 1 for Europe 2007-2018 without next earning",rel_signal1,rel_signal1_next,abs_return,rel_return,False)
# Out:
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   if __name__ == '__main__':
# C:\Users\Eric.Li\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future

# %% [markdown]
# ## Impact of size on the profit

# %%
market_cap=data_dict["Market cap"]

# %%
market_cap[-rel_signal1.isnull()]
# Out:
#            2018-03-07 00:00:00  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# Unnamed: 0
# CPR IM                     NaN         NaN         NaN   6708.2399
# BNP FP                     NaN         NaN  82521.4202  82550.9768
# RF FP                      NaN   4194.7924         NaN         NaN
# BOKA NA                    NaN         NaN         NaN         NaN
# GKN LN                     NaN         NaN   7223.1123         NaN
# GLE FP                     NaN         NaN         NaN         NaN
# TLW LN                     NaN         NaN         NaN         NaN
# ROR LN                     NaN         NaN         NaN         NaN
# CSGN SW                    NaN         NaN         NaN         NaN
# STB NO                     NaN         NaN         NaN         NaN
# WPP LN                     NaN         NaN         NaN         NaN
# REP SM                     NaN         NaN  21536.2835         NaN
# HSX LN                     NaN         NaN         NaN         NaN
# GBF GR                     NaN         NaN         NaN         NaN
# G1A GR                     NaN         NaN         NaN         NaN
# POM FP                     NaN         NaN         NaN         NaN
# TIG BB                     NaN         NaN         NaN         NaN
# FLS DC                 2560.05         NaN         NaN         NaN
# CA FP                      NaN         NaN         NaN         NaN
# LNZ AV                     NaN         NaN         NaN   4107.2849
# MKS LN                     NaN         NaN         NaN         NaN
# SK FP                      NaN         NaN         NaN         NaN
# HAS LN                     NaN   2865.9940         NaN         NaN
# ANTO LN                    NaN   8903.5292   6369.3621         NaN
# PNN LN                     NaN   4430.0481         NaN         NaN
# FERG LN                    NaN         NaN         NaN         NaN
# ORK NO                     NaN         NaN         NaN         NaN
# SIK SW                     NaN         NaN         NaN  13065.2976
# RYA ID                     NaN         NaN         NaN         NaN
# TEN IM                 15996.3  13965.7526         NaN         NaN
# ...                        ...         ...         ...         ...
# SMIT NA                    NaN         NaN         NaN         NaN
# SNI NO                     NaN         NaN         NaN         NaN
# SOLA LN                    NaN         NaN         NaN         NaN
# SONI PL                    NaN         NaN         NaN         NaN
# SOO1 GR                    NaN         NaN         NaN         NaN
# STHR LN                    NaN         NaN         NaN         NaN
# STR AV                     NaN         NaN         NaN         NaN
# STRB IR                    NaN         NaN         NaN         NaN
# STXEUR NO                  NaN         NaN         NaN         NaN
# SZE FP                     NaN         NaN         NaN         NaN
# TA NA                      NaN         NaN         NaN         NaN
# TAN LN                     NaN         NaN         NaN         NaN
# TCHNR FP                   NaN         NaN         NaN         NaN
# TEONR FP                   NaN         NaN         NaN         NaN
# TESB BB                    NaN         NaN         NaN         NaN
# TIE1V FH                   NaN         NaN         NaN         NaN
# TIS IM                     NaN         NaN         NaN         NaN
# TNI LN                     NaN         NaN         NaN         NaN
# TNS LN                     NaN         NaN         NaN         NaN
# TORMA DC                   NaN         NaN         NaN         NaN
# TRAD LN                    NaN         NaN         NaN         NaN
# UMB LN                     NaN         NaN         NaN         NaN
# UPONOR FH                  NaN         NaN         NaN         NaN
# VCT FP                     NaN         NaN         NaN         NaN
# VPC LN                     NaN         NaN         NaN         NaN
# VTW GR                     NaN         NaN         NaN         NaN
# WRTAV FH                   NaN         NaN         NaN         NaN
# XCH LN                     NaN         NaN         NaN         NaN
# ZAG AV                     NaN         NaN         NaN         NaN
# ZEL SM                     NaN         NaN         NaN         NaN
#
#             Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# Unnamed: 0
# CPR IM             NaN         NaN         NaN         NaN   4358.9039
# BNP FP             NaN         NaN         NaN         NaN         NaN
# RF FP              NaN         NaN         NaN         NaN         NaN
# BOKA NA      6008.7423         NaN   5107.4517         NaN         NaN
# GKN LN             NaN         NaN         NaN         NaN         NaN
# GLE FP             NaN  29131.9650  23757.0488         NaN         NaN
# TLW LN             NaN         NaN         NaN         NaN         NaN
# ROR LN             NaN         NaN         NaN         NaN         NaN
# CSGN SW            NaN         NaN         NaN         NaN         NaN
# STB NO             NaN         NaN         NaN   1676.0904         NaN
# WPP LN             NaN         NaN         NaN         NaN         NaN
# REP SM             NaN         NaN         NaN         NaN         NaN
# HSX LN             NaN         NaN         NaN         NaN         NaN
# GBF GR             NaN         NaN         NaN         NaN         NaN
# G1A GR             NaN         NaN         NaN         NaN         NaN
# POM FP             NaN         NaN         NaN         NaN         NaN
# TIG BB             NaN         NaN         NaN         NaN         NaN
# FLS DC       2347.3388         NaN         NaN         NaN         NaN
# CA FP              NaN         NaN         NaN         NaN         NaN
# LNZ AV             NaN         NaN         NaN         NaN         NaN
# MKS LN      12402.7675         NaN         NaN         NaN         NaN
# SK FP              NaN         NaN         NaN         NaN         NaN
# HAS LN             NaN         NaN         NaN         NaN   2376.6943
# ANTO LN            NaN         NaN         NaN         NaN         NaN
# PNN LN             NaN         NaN   4480.4328         NaN         NaN
# FERG LN            NaN         NaN         NaN  10841.8100         NaN
# ORK NO             NaN         NaN   8512.7520   7809.4739         NaN
# SIK SW             NaN  10599.7989         NaN         NaN   7992.8410
# RYA ID             NaN         NaN         NaN         NaN         NaN
# TEN IM             NaN  14508.7981         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# SMIT NA            NaN         NaN         NaN         NaN         NaN
# SNI NO             NaN         NaN         NaN         NaN         NaN
# SOLA LN            NaN         NaN         NaN         NaN         NaN
# SONI PL            NaN         NaN         NaN         NaN         NaN
# SOO1 GR            NaN         NaN         NaN         NaN         NaN
# STHR LN            NaN         NaN         NaN         NaN         NaN
# STR AV             NaN         NaN         NaN         NaN         NaN
# STRB IR            NaN         NaN         NaN         NaN         NaN
# STXEUR NO          NaN         NaN         NaN         NaN         NaN
# SZE FP             NaN         NaN         NaN         NaN         NaN
# TA NA              NaN         NaN         NaN         NaN         NaN
# TAN LN             NaN         NaN         NaN         NaN         NaN
# TCHNR FP           NaN         NaN         NaN         NaN         NaN
# TEONR FP           NaN         NaN         NaN         NaN         NaN
# TESB BB            NaN         NaN         NaN         NaN         NaN
# TIE1V FH           NaN         NaN         NaN         NaN         NaN
# TIS IM             NaN         NaN         NaN         NaN         NaN
# TNI LN             NaN         NaN         NaN         NaN         NaN
# TNS LN             NaN         NaN         NaN         NaN         NaN
# TORMA DC           NaN         NaN         NaN         NaN         NaN
# TRAD LN            NaN         NaN         NaN         NaN         NaN
# UMB LN             NaN         NaN         NaN         NaN         NaN
# UPONOR FH          NaN         NaN         NaN         NaN         NaN
# VCT FP             NaN         NaN         NaN         NaN         NaN
# VPC LN             NaN         NaN         NaN         NaN         NaN
# VTW GR             NaN         NaN         NaN         NaN         NaN
# WRTAV FH           NaN         NaN         NaN         NaN         NaN
# XCH LN             NaN         NaN         NaN         NaN         NaN
# ZAG AV             NaN         NaN         NaN         NaN         NaN
# ZEL SM             NaN         NaN         NaN         NaN         NaN
#
#             Unnamed: 10     ...       Unnamed: 55  Unnamed: 56  Unnamed: 57  \
# Unnamed: 0                  ...
# CPR IM              NaN     ...               NaN          NaN          NaN
# BNP FP              NaN     ...               NaN          NaN          NaN
# RF FP               NaN     ...               NaN          NaN          NaN
# BOKA NA             NaN     ...               NaN          NaN          NaN
# GKN LN              NaN     ...               NaN          NaN          NaN
# GLE FP       35589.6295     ...               NaN          NaN          NaN
# TLW LN              NaN     ...               NaN          NaN          NaN
# ROR LN              NaN     ...               NaN          NaN          NaN
# CSGN SW             NaN     ...               NaN          NaN          NaN
# STB NO              NaN     ...               NaN          NaN          NaN
# WPP LN              NaN     ...               NaN          NaN          NaN
# REP SM              NaN     ...               NaN          NaN          NaN
# HSX LN              NaN     ...               NaN          NaN          NaN
# GBF GR              NaN     ...               NaN          NaN          NaN
# G1A GR              NaN     ...               NaN          NaN          NaN
# POM FP        3798.4868     ...               NaN          NaN          NaN
# TIG BB              NaN     ...               NaN          NaN          NaN
# FLS DC              NaN     ...               NaN          NaN          NaN
# CA FP               NaN     ...               NaN          NaN          NaN
# LNZ AV              NaN     ...               NaN          NaN          NaN
# MKS LN              NaN     ...               NaN          NaN          NaN
# SK FP               NaN     ...               NaN          NaN          NaN
# HAS LN              NaN     ...               NaN          NaN          NaN
# ANTO LN             NaN     ...               NaN          NaN          NaN
# PNN LN              NaN     ...               NaN          NaN          NaN
# FERG LN             NaN     ...               NaN          NaN          NaN
# ORK NO              NaN     ...               NaN          NaN          NaN
# SIK SW              NaN     ...               NaN          NaN          NaN
# RYA ID              NaN     ...               NaN          NaN          NaN
# TEN IM              NaN     ...               NaN          NaN          NaN
# ...                 ...     ...               ...          ...          ...
# SMIT NA             NaN     ...               NaN          NaN          NaN
# SNI NO              NaN     ...               NaN          NaN          NaN
# SOLA LN             NaN     ...               NaN          NaN          NaN
# SONI PL             NaN     ...               NaN          NaN          NaN
# SOO1 GR             NaN     ...               NaN          NaN          NaN
# STHR LN             NaN     ...               NaN          NaN          NaN
# STR AV              NaN     ...               NaN          NaN          NaN
# STRB IR             NaN     ...               NaN          NaN          NaN
# STXEUR NO           NaN     ...               NaN          NaN          NaN
# SZE FP              NaN     ...               NaN          NaN          NaN
# TA NA               NaN     ...               NaN          NaN          NaN
# TAN LN              NaN     ...               NaN          NaN          NaN
# TCHNR FP            NaN     ...               NaN          NaN          NaN
# TEONR FP            NaN     ...               NaN          NaN          NaN
# TESB BB             NaN     ...               NaN          NaN          NaN
# TIE1V FH            NaN     ...               NaN          NaN          NaN
# TIS IM              NaN     ...               NaN          NaN          NaN
# TNI LN              NaN     ...               NaN          NaN          NaN
# TNS LN              NaN     ...               NaN          NaN          NaN
# TORMA DC            NaN     ...               NaN          NaN          NaN
# TRAD LN             NaN     ...               NaN          NaN          NaN
# UMB LN              NaN     ...               NaN          NaN          NaN
# UPONOR FH           NaN     ...               NaN          NaN          NaN
# VCT FP              NaN     ...               NaN          NaN          NaN
# VPC LN              NaN     ...               NaN          NaN          NaN
# VTW GR              NaN     ...               NaN          NaN          NaN
# WRTAV FH            NaN     ...               NaN          NaN          NaN
# XCH LN              NaN     ...               NaN          NaN          NaN
# ZAG AV              NaN     ...               NaN          NaN          NaN
# ZEL SM              NaN     ...               NaN          NaN          NaN
#
#             Unnamed: 58  Unnamed: 59  Unnamed: 60  Unnamed: 61  Unnamed: 62  \
# Unnamed: 0
# CPR IM              NaN          NaN          NaN          NaN          NaN
# BNP FP              NaN          NaN          NaN          NaN          NaN
# RF FP               NaN          NaN          NaN          NaN          NaN
# BOKA NA             NaN          NaN          NaN          NaN          NaN
# GKN LN              NaN          NaN          NaN          NaN          NaN
# GLE FP              NaN          NaN          NaN          NaN          NaN
# TLW LN              NaN          NaN          NaN          NaN          NaN
# ROR LN              NaN          NaN          NaN          NaN          NaN
# CSGN SW             NaN          NaN          NaN          NaN          NaN
# STB NO              NaN          NaN          NaN          NaN          NaN
# WPP LN              NaN          NaN          NaN          NaN          NaN
# REP SM              NaN          NaN          NaN          NaN          NaN
# HSX LN              NaN          NaN          NaN          NaN          NaN
# GBF GR              NaN          NaN          NaN          NaN          NaN
# G1A GR              NaN          NaN          NaN          NaN          NaN
# POM FP              NaN          NaN          NaN          NaN          NaN
# TIG BB              NaN          NaN          NaN          NaN          NaN
# FLS DC              NaN          NaN          NaN          NaN          NaN
# CA FP               NaN          NaN          NaN          NaN          NaN
# LNZ AV              NaN          NaN          NaN          NaN          NaN
# MKS LN              NaN          NaN          NaN          NaN          NaN
# SK FP               NaN          NaN          NaN          NaN          NaN
# HAS LN              NaN          NaN          NaN          NaN          NaN
# ANTO LN             NaN          NaN          NaN          NaN          NaN
# PNN LN              NaN          NaN          NaN          NaN          NaN
# FERG LN             NaN          NaN          NaN          NaN          NaN
# ORK NO              NaN          NaN          NaN          NaN          NaN
# SIK SW              NaN          NaN          NaN          NaN          NaN
# RYA ID              NaN          NaN          NaN          NaN          NaN
# TEN IM              NaN          NaN          NaN          NaN          NaN
# ...                 ...          ...          ...          ...          ...
# SMIT NA             NaN          NaN          NaN          NaN          NaN
# SNI NO              NaN          NaN          NaN          NaN          NaN
# SOLA LN             NaN          NaN          NaN          NaN          NaN
# SONI PL             NaN          NaN          NaN          NaN          NaN
# SOO1 GR             NaN          NaN          NaN          NaN          NaN
# STHR LN             NaN          NaN          NaN          NaN          NaN
# STR AV              NaN          NaN          NaN          NaN          NaN
# STRB IR             NaN          NaN          NaN          NaN          NaN
# STXEUR NO           NaN          NaN          NaN          NaN          NaN
# SZE FP              NaN          NaN          NaN          NaN          NaN
# TA NA               NaN          NaN          NaN          NaN          NaN
# TAN LN              NaN          NaN          NaN          NaN          NaN
# TCHNR FP            NaN          NaN          NaN          NaN          NaN
# TEONR FP            NaN          NaN          NaN          NaN          NaN
# TESB BB             NaN          NaN          NaN          NaN          NaN
# TIE1V FH            NaN          NaN          NaN          NaN          NaN
# TIS IM              NaN          NaN          NaN          NaN          NaN
# TNI LN              NaN          NaN          NaN          NaN          NaN
# TNS LN              NaN          NaN          NaN          NaN          NaN
# TORMA DC            NaN          NaN          NaN          NaN          NaN
# TRAD LN             NaN          NaN          NaN          NaN          NaN
# UMB LN              NaN          NaN          NaN          NaN          NaN
# UPONOR FH           NaN          NaN          NaN          NaN          NaN
# VCT FP              NaN          NaN          NaN          NaN          NaN
# VPC LN              NaN          NaN          NaN          NaN          NaN
# VTW GR              NaN          NaN          NaN          NaN          NaN
# WRTAV FH            NaN          NaN          NaN          NaN          NaN
# XCH LN              NaN          NaN          NaN          NaN          NaN
# ZAG AV              NaN          NaN          NaN          NaN          NaN
# ZEL SM              NaN          NaN          NaN          NaN          NaN
#
#             Unnamed: 63  Unnamed: 64
# Unnamed: 0
# CPR IM              NaN          NaN
# BNP FP              NaN          NaN
# RF FP               NaN          NaN
# BOKA NA             NaN          NaN
# GKN LN              NaN          NaN
# GLE FP              NaN          NaN
# TLW LN              NaN          NaN
# ROR LN              NaN          NaN
# CSGN SW             NaN          NaN
# STB NO              NaN          NaN
# WPP LN              NaN          NaN
# REP SM              NaN          NaN
# HSX LN              NaN          NaN
# GBF GR              NaN          NaN
# G1A GR              NaN          NaN
# POM FP              NaN          NaN
# TIG BB              NaN          NaN
# FLS DC              NaN          NaN
# CA FP               NaN          NaN
# LNZ AV              NaN          NaN
# MKS LN              NaN          NaN
# SK FP               NaN          NaN
# HAS LN              NaN          NaN
# ANTO LN             NaN          NaN
# PNN LN              NaN          NaN
# FERG LN             NaN          NaN
# ORK NO              NaN          NaN
# SIK SW              NaN          NaN
# RYA ID              NaN          NaN
# TEN IM              NaN          NaN
# ...                 ...          ...
# SMIT NA             NaN          NaN
# SNI NO              NaN          NaN
# SOLA LN             NaN          NaN
# SONI PL             NaN          NaN
# SOO1 GR             NaN          NaN
# STHR LN             NaN          NaN
# STR AV              NaN          NaN
# STRB IR             NaN          NaN
# STXEUR NO           NaN          NaN
# SZE FP              NaN          NaN
# TA NA               NaN          NaN
# TAN LN              NaN          NaN
# TCHNR FP            NaN          NaN
# TEONR FP            NaN          NaN
# TESB BB             NaN          NaN
# TIE1V FH            NaN          NaN
# TIS IM              NaN          NaN
# TNI LN              NaN          NaN
# TNS LN              NaN          NaN
# TORMA DC            NaN          NaN
# TRAD LN             NaN          NaN
# UMB LN              NaN          NaN
# UPONOR FH           NaN          NaN
# VCT FP              NaN          NaN
# VPC LN              NaN          NaN
# VTW GR              NaN          NaN
# WRTAV FH            NaN          NaN
# XCH LN              NaN          NaN
# ZAG AV              NaN          NaN
# ZEL SM              NaN          NaN
#
# [1301 rows x 64 columns]

# %%
rel_signal1
# Out:
#            2018-03-07 00:00:00 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# Unnamed: 0
# CPR IM                     NaT        NaT        NaT 2017-05-09        NaT
# BNP FP                     NaT        NaT 2017-07-28 2017-05-03        NaT
# RF FP                      NaT 2017-03-17        NaT        NaT        NaT
# BOKA NA                    NaT        NaT        NaT        NaT 2015-08-20
# GKN LN                     NaT        NaT 2017-02-28        NaT        NaT
# GLE FP                     NaT        NaT        NaT        NaT        NaT
# TLW LN                     NaT        NaT        NaT        NaT        NaT
# ROR LN                     NaT        NaT        NaT        NaT        NaT
# CSGN SW                    NaT        NaT        NaT        NaT        NaT
# STB NO                     NaT        NaT        NaT        NaT        NaT
# WPP LN                     NaT        NaT        NaT        NaT        NaT
# REP SM                     NaT        NaT 2017-07-27        NaT        NaT
# HSX LN                     NaT        NaT        NaT        NaT        NaT
# GBF GR                     NaT        NaT        NaT        NaT        NaT
# G1A GR                     NaT        NaT        NaT        NaT        NaT
# POM FP                     NaT        NaT        NaT        NaT        NaT
# TIG BB                     NaT        NaT        NaT        NaT        NaT
# FLS DC              2018-02-07        NaT        NaT        NaT 2017-02-09
# CA FP                      NaT        NaT        NaT        NaT        NaT
# LNZ AV                     NaT        NaT        NaT 2017-03-22        NaT
# MKS LN                     NaT        NaT        NaT        NaT 2015-11-04
# SK FP                      NaT        NaT        NaT        NaT        NaT
# HAS LN                     NaT 2017-08-31        NaT        NaT        NaT
# ANTO LN                    NaT 2017-03-14 2016-08-16        NaT        NaT
# PNN LN                     NaT 2017-05-24        NaT        NaT        NaT
# FERG LN                    NaT        NaT        NaT        NaT        NaT
# ORK NO                     NaT        NaT        NaT        NaT        NaT
# SIK SW                     NaT        NaT        NaT 2017-02-24        NaT
# RYA ID                     NaT        NaT        NaT        NaT        NaT
# TEN IM              2018-02-21 2017-11-01        NaT        NaT        NaT
# ...                        ...        ...        ...        ...        ...
# SMIT NA                    NaT        NaT        NaT        NaT        NaT
# SNI NO                     NaT        NaT        NaT        NaT        NaT
# SOLA LN                    NaT        NaT        NaT        NaT        NaT
# SONI PL                    NaT        NaT        NaT        NaT        NaT
# SOO1 GR                    NaT        NaT        NaT        NaT        NaT
# STHR LN                    NaT        NaT        NaT        NaT        NaT
# STR AV                     NaT        NaT        NaT        NaT        NaT
# STRB IR                    NaT        NaT        NaT        NaT        NaT
# STXEUR NO                  NaT        NaT        NaT        NaT        NaT
# SZE FP                     NaT        NaT        NaT        NaT        NaT
# TA NA                      NaT        NaT        NaT        NaT        NaT
# TAN LN                     NaT        NaT        NaT        NaT        NaT
# TCHNR FP                   NaT        NaT        NaT        NaT        NaT
# TEONR FP                   NaT        NaT        NaT        NaT        NaT
# TESB BB                    NaT        NaT        NaT        NaT        NaT
# TIE1V FH                   NaT        NaT        NaT        NaT        NaT
# TIS IM                     NaT        NaT        NaT        NaT        NaT
# TNI LN                     NaT        NaT        NaT        NaT        NaT
# TNS LN                     NaT        NaT        NaT        NaT        NaT
# TORMA DC                   NaT        NaT        NaT        NaT        NaT
# TRAD LN                    NaT        NaT        NaT        NaT        NaT
# UMB LN                     NaT        NaT        NaT        NaT        NaT
# UPONOR FH                  NaT        NaT        NaT        NaT        NaT
# VCT FP                     NaT        NaT        NaT        NaT        NaT
# VPC LN                     NaT        NaT        NaT        NaT        NaT
# VTW GR                     NaT        NaT        NaT        NaT        NaT
# WRTAV FH                   NaT        NaT        NaT        NaT        NaT
# XCH LN                     NaT        NaT        NaT        NaT        NaT
# ZAG AV                     NaT        NaT        NaT        NaT        NaT
# ZEL SM                     NaT        NaT        NaT        NaT        NaT
#
#            Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# Unnamed: 0
# CPR IM            NaT        NaT        NaT 2016-03-01         NaT
# BNP FP            NaT        NaT        NaT        NaT         NaT
# RF FP             NaT        NaT        NaT        NaT         NaT
# BOKA NA           NaT 2014-08-14        NaT        NaT         NaT
# GKN LN            NaT        NaT        NaT        NaT         NaT
# GLE FP     2016-11-03 2016-08-03        NaT        NaT  2015-11-05
# TLW LN            NaT        NaT        NaT        NaT         NaT
# ROR LN            NaT        NaT        NaT        NaT         NaT
# CSGN SW           NaT        NaT        NaT        NaT         NaT
# STB NO            NaT        NaT 2016-04-27        NaT         NaT
# WPP LN            NaT        NaT        NaT        NaT         NaT
# REP SM            NaT        NaT        NaT        NaT         NaT
# HSX LN            NaT        NaT        NaT        NaT         NaT
# GBF GR            NaT        NaT        NaT        NaT         NaT
# G1A GR            NaT        NaT        NaT        NaT         NaT
# POM FP            NaT        NaT        NaT        NaT  2014-02-27
# TIG BB            NaT        NaT        NaT        NaT         NaT
# FLS DC            NaT        NaT        NaT        NaT         NaT
# CA FP             NaT        NaT        NaT        NaT         NaT
# LNZ AV            NaT        NaT        NaT        NaT         NaT
# MKS LN            NaT        NaT        NaT        NaT         NaT
# SK FP             NaT        NaT        NaT        NaT         NaT
# HAS LN            NaT        NaT        NaT 2014-02-26         NaT
# ANTO LN           NaT        NaT        NaT        NaT         NaT
# PNN LN            NaT 2014-11-28        NaT        NaT         NaT
# FERG LN           NaT        NaT 2014-03-25        NaT         NaT
# ORK NO            NaT 2016-07-15 2016-05-03        NaT         NaT
# SIK SW     2016-07-29        NaT        NaT 2015-02-27         NaT
# RYA ID            NaT        NaT        NaT        NaT         NaT
# TEN IM     2016-11-03        NaT        NaT        NaT         NaT
# ...               ...        ...        ...        ...         ...
# SMIT NA           NaT        NaT        NaT        NaT         NaT
# SNI NO            NaT        NaT        NaT        NaT         NaT
# SOLA LN           NaT        NaT        NaT        NaT         NaT
# SONI PL           NaT        NaT        NaT        NaT         NaT
# SOO1 GR           NaT        NaT        NaT        NaT         NaT
# STHR LN           NaT        NaT        NaT        NaT         NaT
# STR AV            NaT        NaT        NaT        NaT         NaT
# STRB IR           NaT        NaT        NaT        NaT         NaT
# STXEUR NO         NaT        NaT        NaT        NaT         NaT
# SZE FP            NaT        NaT        NaT        NaT         NaT
# TA NA             NaT        NaT        NaT        NaT         NaT
# TAN LN            NaT        NaT        NaT        NaT         NaT
# TCHNR FP          NaT        NaT        NaT        NaT         NaT
# TEONR FP          NaT        NaT        NaT        NaT         NaT
# TESB BB           NaT        NaT        NaT        NaT         NaT
# TIE1V FH          NaT        NaT        NaT        NaT         NaT
# TIS IM            NaT        NaT        NaT        NaT         NaT
# TNI LN            NaT        NaT        NaT        NaT         NaT
# TNS LN            NaT        NaT        NaT        NaT         NaT
# TORMA DC          NaT        NaT        NaT        NaT         NaT
# TRAD LN           NaT        NaT        NaT        NaT         NaT
# UMB LN            NaT        NaT        NaT        NaT         NaT
# UPONOR FH         NaT        NaT        NaT        NaT         NaT
# VCT FP            NaT        NaT        NaT        NaT         NaT
# VPC LN            NaT        NaT        NaT        NaT         NaT
# VTW GR            NaT        NaT        NaT        NaT         NaT
# WRTAV FH          NaT        NaT        NaT        NaT         NaT
# XCH LN            NaT        NaT        NaT        NaT         NaT
# ZAG AV            NaT        NaT        NaT        NaT         NaT
# ZEL SM            NaT        NaT        NaT        NaT         NaT
#
#                ...     Unnamed: 55 Unnamed: 56 Unnamed: 57 Unnamed: 58  \
# Unnamed: 0     ...
# CPR IM         ...             NaT         NaT         NaT         NaT
# BNP FP         ...             NaT         NaT         NaT         NaT
# RF FP          ...             NaT         NaT         NaT         NaT
# BOKA NA        ...             NaT         NaT         NaT         NaT
# GKN LN         ...             NaT         NaT         NaT         NaT
# GLE FP         ...             NaT         NaT         NaT         NaT
# TLW LN         ...             NaT         NaT         NaT         NaT
# ROR LN         ...             NaT         NaT         NaT         NaT
# CSGN SW        ...             NaT         NaT         NaT         NaT
# STB NO         ...             NaT         NaT         NaT         NaT
# WPP LN         ...             NaT         NaT         NaT         NaT
# REP SM         ...             NaT         NaT         NaT         NaT
# HSX LN         ...             NaT         NaT         NaT         NaT
# GBF GR         ...             NaT         NaT         NaT         NaT
# G1A GR         ...             NaT         NaT         NaT         NaT
# POM FP         ...             NaT         NaT         NaT         NaT
# TIG BB         ...             NaT         NaT         NaT         NaT
# FLS DC         ...             NaT         NaT         NaT         NaT
# CA FP          ...             NaT         NaT         NaT         NaT
# LNZ AV         ...             NaT         NaT         NaT         NaT
# MKS LN         ...             NaT         NaT         NaT         NaT
# SK FP          ...             NaT         NaT         NaT         NaT
# HAS LN         ...             NaT         NaT         NaT         NaT
# ANTO LN        ...             NaT         NaT         NaT         NaT
# PNN LN         ...             NaT         NaT         NaT         NaT
# FERG LN        ...             NaT         NaT         NaT         NaT
# ORK NO         ...             NaT         NaT         NaT         NaT
# SIK SW         ...             NaT         NaT         NaT         NaT
# RYA ID         ...             NaT         NaT         NaT         NaT
# TEN IM         ...             NaT         NaT         NaT         NaT
# ...            ...             ...         ...         ...         ...
# SMIT NA        ...             NaT         NaT         NaT         NaT
# SNI NO         ...             NaT         NaT         NaT         NaT
# SOLA LN        ...             NaT         NaT         NaT         NaT
# SONI PL        ...             NaT         NaT         NaT         NaT
# SOO1 GR        ...             NaT         NaT         NaT         NaT
# STHR LN        ...             NaT         NaT         NaT         NaT
# STR AV         ...             NaT         NaT         NaT         NaT
# STRB IR        ...             NaT         NaT         NaT         NaT
# STXEUR NO      ...             NaT         NaT         NaT         NaT
# SZE FP         ...             NaT         NaT         NaT         NaT
# TA NA          ...             NaT         NaT         NaT         NaT
# TAN LN         ...             NaT         NaT         NaT         NaT
# TCHNR FP       ...             NaT         NaT         NaT         NaT
# TEONR FP       ...             NaT         NaT         NaT         NaT
# TESB BB        ...             NaT         NaT         NaT         NaT
# TIE1V FH       ...             NaT         NaT         NaT         NaT
# TIS IM         ...             NaT         NaT         NaT         NaT
# TNI LN         ...             NaT         NaT         NaT         NaT
# TNS LN         ...             NaT         NaT         NaT         NaT
# TORMA DC       ...             NaT         NaT         NaT         NaT
# TRAD LN        ...             NaT         NaT         NaT         NaT
# UMB LN         ...             NaT         NaT         NaT         NaT
# UPONOR FH      ...             NaT         NaT         NaT         NaT
# VCT FP         ...             NaT         NaT         NaT         NaT
# VPC LN         ...             NaT         NaT         NaT         NaT
# VTW GR         ...             NaT         NaT         NaT         NaT
# WRTAV FH       ...             NaT         NaT         NaT         NaT
# XCH LN         ...             NaT         NaT         NaT         NaT
# ZAG AV         ...             NaT         NaT         NaT         NaT
# ZEL SM         ...             NaT         NaT         NaT         NaT
#
#            Unnamed: 59 Unnamed: 60 Unnamed: 61 Unnamed: 62 Unnamed: 63  \
# Unnamed: 0
# CPR IM             NaT         NaT         NaT         NaT         NaT
# BNP FP             NaT         NaT         NaT         NaT         NaT
# RF FP              NaT         NaT         NaT         NaT         NaT
# BOKA NA            NaT         NaT         NaT         NaT         NaT
# GKN LN             NaT         NaT         NaT         NaT         NaT
# GLE FP             NaT         NaT         NaT         NaT         NaT
# TLW LN             NaT         NaT         NaT         NaT         NaT
# ROR LN             NaT         NaT         NaT         NaT         NaT
# CSGN SW            NaT         NaT         NaT         NaT         NaT
# STB NO             NaT         NaT         NaT         NaT         NaT
# WPP LN             NaT         NaT         NaT         NaT         NaT
# REP SM             NaT         NaT         NaT         NaT         NaT
# HSX LN             NaT         NaT         NaT         NaT         NaT
# GBF GR             NaT         NaT         NaT         NaT         NaT
# G1A GR             NaT         NaT         NaT         NaT         NaT
# POM FP             NaT         NaT         NaT         NaT         NaT
# TIG BB             NaT         NaT         NaT         NaT         NaT
# FLS DC             NaT         NaT         NaT         NaT         NaT
# CA FP              NaT         NaT         NaT         NaT         NaT
# LNZ AV             NaT         NaT         NaT         NaT         NaT
# MKS LN             NaT         NaT         NaT         NaT         NaT
# SK FP              NaT         NaT         NaT         NaT         NaT
# HAS LN             NaT         NaT         NaT         NaT         NaT
# ANTO LN            NaT         NaT         NaT         NaT         NaT
# PNN LN             NaT         NaT         NaT         NaT         NaT
# FERG LN            NaT         NaT         NaT         NaT         NaT
# ORK NO             NaT         NaT         NaT         NaT         NaT
# SIK SW             NaT         NaT         NaT         NaT         NaT
# RYA ID             NaT         NaT         NaT         NaT         NaT
# TEN IM             NaT         NaT         NaT         NaT         NaT
# ...                ...         ...         ...         ...         ...
# SMIT NA            NaT         NaT         NaT         NaT         NaT
# SNI NO             NaT         NaT         NaT         NaT         NaT
# SOLA LN            NaT         NaT         NaT         NaT         NaT
# SONI PL            NaT         NaT         NaT         NaT         NaT
# SOO1 GR            NaT         NaT         NaT         NaT         NaT
# STHR LN            NaT         NaT         NaT         NaT         NaT
# STR AV             NaT         NaT         NaT         NaT         NaT
# STRB IR            NaT         NaT         NaT         NaT         NaT
# STXEUR NO          NaT         NaT         NaT         NaT         NaT
# SZE FP             NaT         NaT         NaT         NaT         NaT
# TA NA              NaT         NaT         NaT         NaT         NaT
# TAN LN             NaT         NaT         NaT         NaT         NaT
# TCHNR FP           NaT         NaT         NaT         NaT         NaT
# TEONR FP           NaT         NaT         NaT         NaT         NaT
# TESB BB            NaT         NaT         NaT         NaT         NaT
# TIE1V FH           NaT         NaT         NaT         NaT         NaT
# TIS IM             NaT         NaT         NaT         NaT         NaT
# TNI LN             NaT         NaT         NaT         NaT         NaT
# TNS LN             NaT         NaT         NaT         NaT         NaT
# TORMA DC           NaT         NaT         NaT         NaT         NaT
# TRAD LN            NaT         NaT         NaT         NaT         NaT
# UMB LN             NaT         NaT         NaT         NaT         NaT
# UPONOR FH          NaT         NaT         NaT         NaT         NaT
# VCT FP             NaT         NaT         NaT         NaT         NaT
# VPC LN             NaT         NaT         NaT         NaT         NaT
# VTW GR             NaT         NaT         NaT         NaT         NaT
# WRTAV FH           NaT         NaT         NaT         NaT         NaT
# XCH LN             NaT         NaT         NaT         NaT         NaT
# ZAG AV             NaT         NaT         NaT         NaT         NaT
# ZEL SM             NaT         NaT         NaT         NaT         NaT
#
#            Unnamed: 64
# Unnamed: 0
# CPR IM             NaT
# BNP FP             NaT
# RF FP              NaT
# BOKA NA            NaT
# GKN LN             NaT
# GLE FP             NaT
# TLW LN             NaT
# ROR LN             NaT
# CSGN SW            NaT
# STB NO             NaT
# WPP LN             NaT
# REP SM             NaT
# HSX LN             NaT
# GBF GR             NaT
# G1A GR             NaT
# POM FP             NaT
# TIG BB             NaT
# FLS DC             NaT
# CA FP              NaT
# LNZ AV             NaT
# MKS LN             NaT
# SK FP              NaT
# HAS LN             NaT
# ANTO LN            NaT
# PNN LN             NaT
# FERG LN            NaT
# ORK NO             NaT
# SIK SW             NaT
# RYA ID             NaT
# TEN IM             NaT
# ...                ...
# SMIT NA            NaT
# SNI NO             NaT
# SOLA LN            NaT
# SONI PL            NaT
# SOO1 GR            NaT
# STHR LN            NaT
# STR AV             NaT
# STRB IR            NaT
# STXEUR NO          NaT
# SZE FP             NaT
# TA NA              NaT
# TAN LN             NaT
# TCHNR FP           NaT
# TEONR FP           NaT
# TESB BB            NaT
# TIE1V FH           NaT
# TIS IM             NaT
# TNI LN             NaT
# TNS LN             NaT
# TORMA DC           NaT
# TRAD LN            NaT
# UMB LN             NaT
# UPONOR FH          NaT
# VCT FP             NaT
# VPC LN             NaT
# VTW GR             NaT
# WRTAV FH           NaT
# XCH LN             NaT
# ZAG AV             NaT
# ZEL SM             NaT
#
# [1297 rows x 64 columns]

# %%
signal_ret=rel_signal1_ind_rel_return.to_frame()
signal_ret.index[10]
# Out:
# ('BNP FP', '04/May/2011')

# %%
date_series=data_dict["Date"].loc['BNP FP']
date_series.iloc[2]
# Out:
# Timestamp('2017-07-28 00:00:00')

# %%
datetime.strptime(signal_ret.index[10][1],"%d/%b/%Y").year
# Out:
# 2011

# %%
timestamp=pd.Timestamp(datetime.strptime(signal_ret.index[10][1],"%d/%b/%Y").year,
             datetime.strptime(signal_ret.index[10][1],"%d/%b/%Y").month,
            datetime.strptime(signal_ret.index[10][1],"%d/%b/%Y").day)
# Out:
# Timestamp('2011-05-04 00:00:00')
